# %% [markdown]
# ## Preparation work: downloading necessary files and importing necessary libraries

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
# !pip install emoji
import emoji
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('omw-1.4')   # I added this command to run lemmatizer.lemmatize() without errors
nltk.download('averaged_perceptron_tagger')   # I added this command to run lemmatizer.lemmatize() without errors
from string import punctuation
import numpy as np
import pandas as pd
import re
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=edd81bcb6bfc4b9130a1734e7cd3afadbe44f8fe70fc67f05d748e775ffaad02
#   Stored in directory: /root/.cache/pip/wheels/9a/b8/0f/f580817231cbf59f6ade9fd132ff60ada1de9f7dc85521f857
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.2.0
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ## Setting sets and functions for text pre-processing and lemmatization

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

# %%
lemmatizer = WordNetLemmatizer()

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def text_preprocessing_and_lemmatization(text):
    text = str(text).lower()

    lemmatized_words = []
    tokens = nltk.word_tokenize(text)
    processed_tokens = [remove_emojis(token) for token in tokens if token.isalpha() and token not in stop_words and token not in list(punctuation)]
    for word, tag in nltk.pos_tag(processed_tokens):
        pos = get_wordnet_pos(tag)
        lemma = lemmatizer.lemmatize(word, pos=pos)
        lemmatized_words.append(lemma)
    
    return ' '.join(lemmatized_words)

# %% [markdown]
# ## Loading and visualizing DisneyPlus reviews

# %%
disneyplus = pd.read_csv('DisneyPlus_Google_Play.csv')

# %%
disneyplus.head()
# Out:
#    Unnamed: 0                              reviewId         userName  \
# 0           0  75affb77-43d6-4ada-9d8d-576d75a89295   William Graham
# 1           1  de8a389b-d296-484b-8049-555b31436e70       Nelson Lam
# 2           2  f0b0ef9c-5db3-44d5-9b70-2984685a55a2  Denuwan Saranga
# 3           3  f9b16c2c-6bf1-4de2-acf9-25db53feccf2  Gratien ABANJYE
# 4           4  9e483f7c-c572-4e46-a47a-f579a6d230ee     Jason Parker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AGNmyx...
# 1  https://play-lh.googleusercontent.com/a/AGNmyx...
# 2  https://play-lh.googleusercontent.com/a-/ACB-R...
# 3  https://play-lh.googleusercontent.com/a-/ACB-R...
# 4  https://play-lh.googleusercontent.com/a-/ACB-R...
#
#                                              content  score  thumbsUpCount  \
# 0                               absolutely awesome 👌      5              0
# 1  I wonder the software of Disney plus have an i...      1              0
# 2          Can you give 1 month premium free❤️Please      5              0
# 3                                              Great      5              0
# 4                                       mandalorian!      5              0
#
#   reviewCreatedVersion                   at replyContent repliedAt
# 0           2.18.1-rc1  2023-04-05 11:13:22          NaN       NaN
# 1                  NaN  2023-04-05 11:10:55          NaN       NaN
# 2                  NaN  2023-04-05 10:57:42          NaN       NaN
# 3                  NaN  2023-04-05 10:40:22          NaN       NaN
# 4           2.18.1-rc1  2023-04-05 10:22:27          NaN       NaN

# %%
disneyplus.shape
# Out:
# (209186, 11)

# %%
disneyplus.score.describe()
# Out:
# count    209186.000000
# mean          3.399530
# std           1.750098
# min           1.000000
# 25%           1.000000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# Name: score, dtype: float64

# %% [markdown]
# ## Processing reviews

# %%
reviews = disneyplus['content']
processed_reviews = reviews.apply(text_preprocessing_and_lemmatization)   # function to pre-process and lemmatize the reviews

processed_reviews
# Out:
# 0                                        absolutely awesome
# 1         wonder software disney plus issue always come ...
# 2                                        give month premium
# 3                                                     great
# 4                                               mandalorian
#                                 ...
# 209181                              love disney awesome app
# 209182    crash switch kid profile authorisation require...
# 209183            love disney happy beautiful streaming app
# 209184                                      best app stream
# 209185    great app pretty polish even officially releas...
# Name: content, Length: 209186, dtype: object

# %%
disneyplus['processed_reviews'] = processed_reviews

# %%
tokenized_reviews = [nltk.word_tokenize(review) for review in processed_reviews.to_list()]
disneyplus['tokenized_reviews'] = pd.Series(tokenized_reviews)

# %%
disneyplus
# Out:
#         Unnamed: 0                              reviewId         userName  \
# 0                0  75affb77-43d6-4ada-9d8d-576d75a89295   William Graham
# 1                1  de8a389b-d296-484b-8049-555b31436e70       Nelson Lam
# 2                2  f0b0ef9c-5db3-44d5-9b70-2984685a55a2  Denuwan Saranga
# 3                3  f9b16c2c-6bf1-4de2-acf9-25db53feccf2  Gratien ABANJYE
# 4                4  9e483f7c-c572-4e46-a47a-f579a6d230ee     Jason Parker
# ...            ...                                   ...              ...
# 209181      209181  99bd5530-071c-46ae-8d65-f396a788805e    A Google user
# 209182      209182  866c928f-7d71-4b48-bb57-08dd93d3364e    A Google user
# 209183      209183  1c1eaa4c-c4c3-4742-8c77-e8af41458549    A Google user
# 209184      209184  c4d3a462-ac13-4fef-b21c-12e86223e1e5    A Google user
# 209185      209185  cde31be6-7adc-40d5-a5cd-89fed27a2942    A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a/AGNmyx...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a-/ACB-R...
# ...                                                   ...
# 209181  https://play-lh.googleusercontent.com/EGemoI2N...
# 209182  https://play-lh.googleusercontent.com/EGemoI2N...
# 209183  https://play-lh.googleusercontent.com/EGemoI2N...
# 209184  https://play-lh.googleusercontent.com/EGemoI2N...
# 209185  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0                                    absolutely awesome 👌      5
# 1       I wonder the software of Disney plus have an i...      1
# 2               Can you give 1 month premium free❤️Please      5
# 3                                                   Great      5
# 4                                            mandalorian!      5
# ...                                                   ...    ...
# 209181                        I love Disney! Awesome app!      5
# 209182  Crashes once when switching over to kids profi...      1
# 209183  I love Disney so I'm very happy with this (ver...      5
# 209184                        It's the best app streaming      5
# 209185  Great app, pretty polished for not even being ...      5
#
#         thumbsUpCount reviewCreatedVersion                   at  \
# 0                   0           2.18.1-rc1  2023-04-05 11:13:22
# 1                   0                  NaN  2023-04-05 11:10:55
# 2                   0                  NaN  2023-04-05 10:57:42
# 3                   0                  NaN  2023-04-05 10:40:22
# 4                   0           2.18.1-rc1  2023-04-05 10:22:27
# ...               ...                  ...                  ...
# 209181              6                1.0.0  2019-09-12 06:17:19
# 209182              5                1.0.0  2019-09-12 06:08:19
# 209183              3                1.0.0  2019-09-12 05:31:04
# 209184              1                1.0.0  2019-09-12 04:52:26
# 209185             17                1.0.0  2019-09-12 04:39:05
#
#                                              replyContent  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 209181                                                NaN
# 209182  Hello Rocco. Thanks for the feedback. Can you ...
# 209183                                                NaN
# 209184                                                NaN
# 209185                                                NaN
#
#                   repliedAt  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 209181                  NaN
# 209182  2019-09-21 17:32:41
# 209183                  NaN
# 209184                  NaN
# 209185                  NaN
#
#                                         processed_reviews  \
# 0                                      absolutely awesome
# 1       wonder software disney plus issue always come ...
# 2                                      give month premium
# 3                                                   great
# 4                                             mandalorian
# ...                                                   ...
# 209181                            love disney awesome app
# 209182  crash switch kid profile authorisation require...
# 209183          love disney happy beautiful streaming app
# 209184                                    best app stream
# 209185  great app pretty polish even officially releas...
#
#                                         tokenized_reviews
# 0                                   [absolutely, awesome]
# 1       [wonder, software, disney, plus, issue, always...
# 2                                  [give, month, premium]
# 3                                                 [great]
# 4                                           [mandalorian]
# ...                                                   ...
# 209181                       [love, disney, awesome, app]
# 209182  [crash, switch, kid, profile, authorisation, r...
# 209183   [love, disney, happy, beautiful, streaming, app]
# 209184                                [best, app, stream]
# 209185  [great, app, pretty, polish, even, officially,...
#
# [209186 rows x 13 columns]

# %% [markdown]
# ## Exploration of lemmatized words

# %%
lemmatized_words = []

for r in processed_reviews:
  lemmatized_words += r.split()

# %%
lemmatized_words
# Out:
# ['absolutely',
#  'awesome',
#  'wonder',
#  'software',
#  'disney',
#  'plus',
#  'issue',
#  'always',
#  'come',
#  'playing',
#  'dolby',
#  'atmos',
#  'movie',
#  'sound',
#  'system',
#  'come',
#  'thru',
#  'sound',
#  'bar',
#  'awhile',
#  'lag',
#  'abit',
#  'watch',
#  'netflix',
#  'platform',
#  'issue',
#  'sound',
#  'kindly',
#  'ple',
#  'fixed',
#  'issue',
#  'pay',
#  'monthly',
#  'give',
#  'month',
#  'premium',
#  'great',
#  'mandalorian',
#  'like',
#  'show',
#  'awesome',
#  'app',
#  'love',
#  'easy',
#  'use',
#  'awesome',
#  'movie',
#  'tv',
#  'show',
#  'horrible',
#  'app',
#  'constantly',
#  'buffer',
#  'every',
#  'netflix',
#  'hulu',
#  'run',
#  'fine',
#  'also',
#  'minimize',
#  'screen',
#  'continue',
#  'watch',
#  'new',
#  'movie',
#  'happy',
#  'nice',
#  'app',
#  'honestly',
#  'get',
#  'everyone',
#  'hate',
#  'issue',
#  'long',
#  'take',
#  'rewind',
#  'app',
#  'play',
#  'download',
#  'content',
#  'wo',
#  'open',
#  'say',
#  'update',
#  'play',
#  'fine',
#  'tv',
#  'always',
#  'buffer',
#  'say',
#  'offline',
#  'terrible',
#  'app',
#  'always',
#  'say',
#  'signal',
#  'offline',
#  'connection',
#  'late',
#  'note',
#  'bad',
#  'movie',
#  'app',
#  'ever',
#  'experience',
#  'update',
#  'horrible',
#  'make',
#  'run',
#  'smoother',
#  'take',
#  'hour',
#  'watch',
#  'min',
#  'episode',
#  'much',
#  'money',
#  'smooth',
#  'interface',
#  'drop',
#  'price',
#  'many',
#  'issue',
#  'app',
#  'never',
#  'experience',
#  'horrible',
#  'stream',
#  'platform',
#  'lame',
#  'app',
#  'like',
#  'straight',
#  'garbage',
#  'like',
#  'trash',
#  'lol',
#  'ew',
#  'really',
#  'want',
#  'like',
#  'break',
#  'every',
#  'time',
#  'turn',
#  'xbox',
#  'open',
#  'phone',
#  'log',
#  'resign',
#  'authentication',
#  'reset',
#  'password',
#  'take',
#  'current',
#  'password',
#  'reset',
#  'current',
#  'password',
#  'repeat',
#  'next',
#  'day',
#  'pay',
#  'ca',
#  'even',
#  'log',
#  'great',
#  'movie',
#  'series',
#  'recently',
#  'let',
#  'send',
#  'movie',
#  'tv',
#  'send',
#  'get',
#  'refund',
#  'tip',
#  'super',
#  'long',
#  'spring',
#  'break',
#  'since',
#  'march',
#  'load',
#  'new',
#  'film',
#  'watch',
#  'love',
#  'old',
#  'cartoon',
#  'like',
#  'gummie',
#  'bear',
#  'love',
#  'like',
#  'content',
#  'two',
#  'screen',
#  'availability',
#  'without',
#  'pay',
#  'netflix',
#  'however',
#  'get',
#  'blue',
#  'spin',
#  'ring',
#  'wait',
#  'quite',
#  'bit',
#  'canceled',
#  'disney',
#  'thing',
#  'due',
#  'behavior',
#  'toward',
#  'child',
#  'push',
#  'agenda',
#  'child',
#  'indoctrinate',
#  'dreadful',
#  'app',
#  'downloads',
#  'take',
#  'much',
#  'long',
#  'constantly',
#  'crash',
#  'sometimes',
#  'crash',
#  'delete',
#  'painstakingly',
#  'download',
#  'show',
#  'acquire',
#  'absolutely',
#  'horrific',
#  'app',
#  'lag',
#  'sound',
#  'disappears',
#  'rewind',
#  'definitely',
#  'cancel',
#  'renew',
#  'subscription',
#  'nice',
#  'app',
#  'love',
#  'nice',
#  'app',
#  'mandalorian',
#  'play',
#  'right',
#  'stop',
#  'load',
#  'time',
#  'buffer',
#  'history',
#  'designer',
#  'need',
#  'go',
#  'back',
#  'ui',
#  'school',
#  'internet',
#  'make',
#  'hard',
#  'watch',
#  'still',
#  'pretty',
#  'food',
#  'iove',
#  'disney',
#  'plus',
#  'like',
#  'watch',
#  'movie',
#  'room',
#  'see',
#  'allot',
#  'review',
#  'post',
#  'recently',
#  'google',
#  'tv',
#  'app',
#  'problem',
#  'fix',
#  'issue',
#  'last',
#  'month',
#  'year',
#  'b',
#  'lie',
#  'update',
#  'say',
#  'fixing',
#  'thing',
#  'bug',
#  'fix',
#  'update',
#  'hope',
#  'find',
#  'stream',
#  'experience',
#  'even',
#  'well',
#  'awesome',
#  'great',
#  'story',
#  'ask',
#  'birthday',
#  'b',
#  'need',
#  'work',
#  'amaze',
#  'come',
#  'life',
#  'constantly',
#  'error',
#  'wo',
#  'play',
#  'downloads',
#  'love',
#  'app',
#  'favorite',
#  'app',
#  'amaze',
#  'love',
#  'disney',
#  'plus',
#  'fun',
#  'family',
#  'everybody',
#  'else',
#  'good',
#  'age',
#  'great',
#  'show',
#  'annoy',
#  'hell',
#  'sign',
#  'especially',
#  'tv',
#  'make',
#  'change',
#  'password',
#  'even',
#  'put',
#  'correctly',
#  'logs',
#  'reason',
#  'way',
#  'remove',
#  'show',
#  'list',
#  'decide',
#  'finish',
#  'way',
#  'get',
#  'around',
#  'use',
#  'watch',
#  'list',
#  'exclusively',
#  'aside',
#  'significant',
#  'ui',
#  'failure',
#  'streaming',
#  'service',
#  'love',
#  'movie',
#  'great',
#  'content',
#  'poor',
#  'app',
#  'use',
#  'work',
#  'great',
#  'first',
#  'come',
#  'slow',
#  'laggy',
#  'unresponsive',
#  'crash',
#  'often',
#  'wake',
#  'disney',
#  'go',
#  'watch',
#  'content',
#  'make',
#  'difficult',
#  'access',
#  'poor',
#  'app',
#  'support',
#  'work',
#  'flawlessly',
#  'never',
#  'glitch',
#  'good',
#  'great',
#  'app',
#  'require',
#  'internet',
#  'connection',
#  'play',
#  'episode',
#  'download',
#  'point',
#  'feature',
#  'ux',
#  'sloppy',
#  'wish',
#  'vrains',
#  'great',
#  'app',
#  'good',
#  'wide',
#  'variety',
#  'content',
#  'download',
#  'work',
#  'even',
#  'solution',
#  'suggest',
#  'stream',
#  'offline',
#  'experience',
#  'sad',
#  'excellent',
#  'movie',
#  'good',
#  'picture',
#  'quality',
#  'awsome',
#  'app',
#  'thank',
#  'bad',
#  'movie',
#  'player',
#  'bad',
#  'netflix',
#  'change',
#  'caption',
#  'font',
#  'size',
#  'color',
#  'show',
#  'resolution',
#  'search',
#  'play',
#  'imax',
#  'properly',
#  'run',
#  'high',
#  'data',
#  'although',
#  'set',
#  'automatic',
#  'conclusion',
#  'bad',
#  'apps',
#  'platform',
#  'googletv',
#  'android',
#  'etc',
#  'work',
#  'app',
#  'doesnt',
#  'work',
#  'cant',
#  'get',
#  'movie',
#  'without',
#  'buffer',
#  'every',
#  'second',
#  'worth',
#  'even',
#  'wifi',
#  'doesnt',
#  'load',
#  'properly',
#  'delete',
#  'app',
#  'reinstall',
#  'app',
#  'clear',
#  'cache',
#  'restart',
#  'phone',
#  'nothing',
#  'work',
#  'also',
#  'date',
#  'unusable',
#  'garbage',
#  'slow',
#  'interface',
#  'downloads',
#  'work',
#  'ᏸ',
#  'iտᕼ',
#  'ᕼᗩᗪ',
#  'ℭ',
#  'ᙏoᖇᙓ',
#  'tᐯ',
#  'sᕼᓍᘺs',
#  'αρρ',
#  'pretty',
#  'good',
#  'tbh',
#  'way',
#  'expensive',
#  'grow',
#  'watch',
#  'disney',
#  'movie',
#  'child',
#  'inlove',
#  'many',
#  'animate',
#  'disney',
#  'movie',
#  'year',
#  'old',
#  'right',
#  'still',
#  'love',
#  'watch',
#  'favorite',
#  'disney',
#  'movie',
#  'excite',
#  'beacuse',
#  'remake',
#  'live',
#  'action',
#  'one',
#  'every',
#  'single',
#  'one',
#  'perfect',
#  'almost',
#  'way',
#  'like',
#  'original',
#  'animated',
#  'movie',
#  'love',
#  'enjoy',
#  'disney',
#  'plus',
#  'quite',
#  'alot',
#  'enjoy',
#  'watch',
#  'movie',
#  'show',
#  'time',
#  'inwant',
#  'excellent',
#  'material',
#  'unwanted',
#  'sneaky',
#  'app',
#  'always',
#  'love',
#  'disney',
#  'app',
#  'never',
#  'problem',
#  'stream',
#  'problem',
#  'pause',
#  'come',
#  'back',
#  'easily',
#  'bad',
#  'batch',
#  'star',
#  'review',
#  'point',
#  'though',
#  'trick',
#  'sometimes',
#  'get',
#  'late',
#  'episode',
#  'thing',
#  'play',
#  'case',
#  'use',
#  'windows',
#  'machine',
#  'wire',
#  'internet',
#  'love',
#  'okay',
#  'like',
#  'app',
#  'great',
#  'way',
#  'showcase',
#  'watch',
#  'favorite',
#  'disney',
#  'movie',
#  'democrat',
#  'good',
#  'watch',
#  'alot',
#  'brother',
#  'tell',
#  'awesome',
#  'new',
#  'documentary',
#  'host',
#  'david',
#  'letterman',
#  'bono',
#  'edge',
#  'glad',
#  'see',
#  'one',
#  'favorite',
#  'rock',
#  'band',
#  'surely',
#  'one',
#  'iconic',
#  'time',
#  'bono',
#  'incomparable',
#  'voice',
#  'group',
#  'almost',
#  'biblical',
#  'lyric',
#  'hit',
#  'song',
#  'song',
#  'decade',
#  'decade',
#  'wonderful',
#  'history',
#  'ireland',
#  'band',
#  'make',
#  'one',
#  'enjoyable',
#  'view',
#  'experience',
#  'ever',
#  'well',
#  'do',
#  'dave',
#  'bono',
#  'edge',
#  'app',
#  'need',
#  'picture',
#  'picture',
#  'feature',
#  'pop',
#  'player',
#  'like',
#  'netflix',
#  'amazon',
#  'prime',
#  'also',
#  'download',
#  'video',
#  'movie',
#  'tv',
#  'keep',
#  'download',
#  'tab',
#  'active',
#  'crawl',
#  'forward',
#  'download',
#  'mind',
#  'internet',
#  'every',
#  'ott',
#  'platform',
#  'whizz',
#  'love',
#  'show',
#  'miss',
#  'like',
#  'aaron',
#  'stone',
#  'love',
#  'apps',
#  'add',
#  'film',
#  'show',
#  'suck',
#  'mostly',
#  'late',
#  'one',
#  'go',
#  'wake',
#  'go',
#  'broke',
#  'great',
#  'little',
#  'app',
#  'luv',
#  'app',
#  'issue',
#  'apps',
#  'get',
#  'freeze',
#  'cut',
#  'happy',
#  'disney',
#  'recommend',
#  'anyone',
#  'great',
#  'app',
#  'tablet',
#  'well',
#  'mobile',
#  'work',
#  'great',
#  'many',
#  'thing',
#  'watch',
#  'luv',
#  'well',
#  'able',
#  'use',
#  'app',
#  'work',
#  'keep',
#  'jump',
#  'dont',
#  'many',
#  'time',
#  'updated',
#  'delete',
#  'still',
#  'wo',
#  'work',
#  'month',
#  'nothing',
#  'get',
#  'do',
#  'must',
#  'issue',
#  'use',
#  'anymore',
#  'still',
#  'work',
#  'sd',
#  'card',
#  'playback',
#  'still',
#  'give',
#  'blank',
#  'screen',
#  'even',
#  'update',
#  'problem',
#  'still',
#  'remain',
#  'first',
#  'time',
#  'app',
#  'good',
#  'experience',
#  'watch',
#  'something',
#  'lag',
#  'go',
#  'slow',
#  'love',
#  'awesome',
#  'awesome',
#  'good',
#  'bad',
#  'picture',
#  'picture',
#  'work',
#  'worst',
#  'phone',
#  'app',
#  'streaming',
#  'service',
#  'grey',
#  'anatomy',
#  'shut',
#  'log',
#  'tv',
#  'kid',
#  'love',
#  'honest',
#  'app',
#  'wo',
#  'open',
#  'anymore',
#  'galaxy',
#  'tab',
#  'plus',
#  'miss',
#  'pip',
#  'support',
#  'excuse',
#  'app',
#  'vpn',
#  'support',
#  'travel',
#  'group',
#  'watch',
#  'work',
#  'want',
#  'work',
#  'tv',
#  'device',
#  'device',
#  'date',
#  'love',
#  'many',
#  'option',
#  'movie',
#  'show',
#  'much',
#  'choose',
#  'yeah',
#  'would',
#  'app',
#  'star',
#  'war',
#  'buggy',
#  'ability',
#  'download',
#  'cool',
#  'downloader',
#  'garbage',
#  'unless',
#  'gigabit',
#  'network',
#  'take',
#  'forever',
#  'start',
#  'download',
#  'complain',
#  'constantly',
#  'connection',
#  'home',
#  'town',
#  'wifi',
#  'idk',
#  'man',
#  'probably',
#  'take',
#  'child',
#  'traffic',
#  'money',
#  'get',
#  'app',
#  'inline',
#  'reality',
#  'wise',
#  'im',
#  'love',
#  'star',
#  'war',
#  'stuff',
#  'thanks',
#  'gross',
#  'app',
#  'junk',
#  'load',
#  'show',
#  'could',
#  'give',
#  'zero',
#  'star',
#  'would',
#  'disney',
#  'focus',
#  'hire',
#  'decent',
#  'coder',
#  'instead',
#  'wake',
#  'fails',
#  'sometimes',
#  'keep',
#  'come',
#  'awesome',
#  'show',
#  'like',
#  'star',
#  'war',
#  'marvel',
#  'show',
#  'know',
#  'happen',
#  'start',
#  'good',
#  'wanda',
#  'vision',
#  'falcon',
#  'winter',
#  'soldier',
#  'moon',
#  'knight',
#  'get',
#  'boring',
#  'creative',
#  'option',
#  'choose',
#  'resolution',
#  'suffer',
#  'fullhd',
#  'slow',
#  'internet',
#  'speed',
#  'movie',
#  'portray',
#  'state',
#  'always',
#  'portray',
#  'hdr',
#  'even',
#  'try',
#  'play',
#  'prism',
#  'tv',
#  'please',
#  'fix',
#  'show',
#  'play',
#  'lot',
#  'bug',
#  'pretty',
#  'par',
#  'disney',
#  'product',
#  'app',
#  'year',
#  'still',
#  'ca',
#  'get',
#  'aspect',
#  'ratio',
#  'right',
#  'tablet',
#  'garbage',
#  'work',
#  'great',
#  'job',
#  'disney',
#  'video',
#  'keep',
#  'load',
#  'never',
#  'play',
#  'app',
#  'always',
#  'problem',
#  'please',
#  'fix',
#  'want',
#  'watch',
#  'movie',
#  'wo',
#  'play',
#  'netflix',
#  'seem',
#  'always',
#  'work',
#  'like',
#  'turtle',
#  'still',
#  'havent',
#  'fix',
#  'offline',
#  'download',
#  'issue',
#  'pathetic',
#  'constantly',
#  'crash',
#  'chromebook',
#  'way',
#  'go',
#  'disney',
#  'best',
#  'ever',
#  ...]

# %%
dict_words = {}

for word in lemmatized_words:
  if word in dict_words:
    dict_words[word] += 1
  else:
    dict_words[word] = 1

# %%
sorted_words_by_frequency = sorted(dict_words.items(), key=lambda x:x[1], reverse = True)
converted_dict = dict(sorted_words_by_frequency)

# %%
converted_dict
# Out:
# {'app': 75013,
#  'love': 38999,
#  'watch': 38168,
#  'movie': 36683,
#  'disney': 35157,
#  'work': 32271,
#  'great': 25293,
#  'good': 24707,
#  'show': 24199,
#  'get': 23344,
#  'like': 16551,
#  'load': 14556,
#  'time': 14190,
#  'phone': 13891,
#  'use': 13621,
#  'ca': 13399,
#  'tv': 12960,
#  'even': 12944,
#  'download': 12182,
#  'content': 12148,
#  'try': 11612,
#  'go': 10923,
#  'play': 10756,
#  'fix': 10731,
#  'would': 10534,
#  'service': 10042,
#  'star': 9855,
#  'keep': 9785,
#  'stream': 9287,
#  'issue': 9117,
#  'pay': 9001,
#  'need': 8826,
#  'say': 8678,
#  'one': 8619,
#  'really': 8603,
#  'error': 8457,
#  'wo': 8332,
#  'screen': 8021,
#  'best': 7911,
#  'want': 7697,
#  'plus': 7587,
#  'still': 7575,
#  'new': 7566,
#  'update': 7423,
#  'netflix': 7256,
#  'make': 7133,
#  'amaze': 7101,
#  'every': 7082,
#  'well': 6865,
#  'problem': 6836,
#  'thing': 6739,
#  'episode': 6662,
#  'subscription': 6498,
#  'kid': 6457,
#  'give': 6414,
#  'open': 6394,
#  'awesome': 6382,
#  'please': 6322,
#  'see': 6249,
#  'much': 6116,
#  'anything': 5994,
#  'back': 5721,
#  'cancel': 5620,
#  'never': 5448,
#  'device': 5432,
#  'take': 5351,
#  'also': 5252,
#  'could': 5190,
#  'lot': 5158,
#  'let': 5148,
#  'ever': 5122,
#  'day': 5067,
#  'buffer': 4951,
#  'log': 4935,
#  'month': 4877,
#  'everything': 4845,
#  'money': 4815,
#  'stop': 4803,
#  'able': 4794,
#  'fine': 4790,
#  'something': 4785,
#  'connect': 4674,
#  'video': 4598,
#  'bad': 4596,
#  'old': 4509,
#  'start': 4482,
#  'many': 4447,
#  'nothing': 4422,
#  'marvel': 4391,
#  'internet': 4331,
#  'way': 4246,
#  'always': 4162,
#  'android': 4162,
#  'add': 4159,
#  'family': 4006,
#  'come': 4000,
#  'war': 3947,
#  'think': 3900,
#  'series': 3897,
#  'code': 3792,
#  'cast': 3786,
#  'favorite': 3754,
#  'account': 3750,
#  'option': 3676,
#  'since': 3634,
#  'know': 3559,
#  'wifi': 3397,
#  'year': 3323,
#  'find': 3309,
#  'enjoy': 3307,
#  'cant': 3292,
#  'continue': 3207,
#  'free': 3201,
#  'worth': 3177,
#  'apps': 3150,
#  'reinstall': 3144,
#  'u': 3126,
#  'crash': 3062,
#  'without': 3038,
#  'first': 3013,
#  'connection': 2977,
#  'nice': 2951,
#  'stuff': 2933,
#  'freeze': 2925,
#  'help': 2900,
#  'far': 2892,
#  'wish': 2846,
#  'selection': 2834,
#  'sometimes': 2824,
#  'available': 2820,
#  'slow': 2817,
#  'constantly': 2736,
#  'tablet': 2712,
#  'samsung': 2700,
#  'change': 2695,
#  'wait': 2618,
#  'access': 2609,
#  'long': 2590,
#  'easy': 2557,
#  'seem': 2554,
#  'experience': 2552,
#  'sign': 2552,
#  'cool': 2538,
#  'black': 2538,
#  'chromecast': 2510,
#  'support': 2500,
#  'offline': 2487,
#  'week': 2485,
#  'people': 2466,
#  'film': 2451,
#  'quality': 2401,
#  'minute': 2386,
#  'price': 2368,
#  'put': 2352,
#  'tell': 2350,
#  'next': 2341,
#  'last': 2340,
#  'look': 2277,
#  'wont': 2245,
#  'though': 2222,
#  'unable': 2196,
#  'pretty': 2183,
#  'dont': 2180,
#  'absolutely': 2165,
#  'data': 2159,
#  'terrible': 2153,
#  'mobile': 2145,
#  'company': 2124,
#  'fun': 2114,
#  'picture': 2110,
#  'second': 2110,
#  'bug': 2102,
#  'google': 2098,
#  'recommend': 2089,
#  'hulu': 2078,
#  'right': 2073,
#  'annoy': 2069,
#  'reason': 2059,
#  'child': 2046,
#  'already': 2035,
#  'feature': 2027,
#  'delete': 2014,
#  'customer': 2005,
#  'audio': 1984,
#  'suck': 1972,
#  'charge': 1968,
#  'restart': 1944,
#  'happen': 1934,
#  'thank': 1924,
#  'excellent': 1912,
#  'downloads': 1909,
#  'little': 1907,
#  'leave': 1893,
#  'classic': 1880,
#  'childhood': 1867,
#  'im': 1862,
#  'amazing': 1858,
#  'mandalorian': 1832,
#  'run': 1818,
#  'review': 1814,
#  'yet': 1814,
#  'home': 1798,
#  'season': 1776,
#  'point': 1744,
#  'sound': 1731,
#  'big': 1720,
#  'message': 1715,
#  'happy': 1705,
#  'whole': 1705,
#  'hour': 1685,
#  'else': 1665,
#  'miss': 1662,
#  'login': 1660,
#  'smart': 1654,
#  'however': 1630,
#  'sure': 1594,
#  'waste': 1563,
#  'end': 1543,
#  'streaming': 1539,
#  'hope': 1536,
#  'wrong': 1536,
#  'turn': 1531,
#  'actually': 1525,
#  'past': 1522,
#  'allow': 1508,
#  'list': 1505,
#  'lag': 1504,
#  'anymore': 1497,
#  'different': 1489,
#  'place': 1488,
#  'perfect': 1475,
#  'almost': 1470,
#  'ok': 1466,
#  'view': 1458,
#  'trial': 1456,
#  'search': 1449,
#  'forever': 1448,
#  'uninstalled': 1448,
#  'galaxy': 1446,
#  'profile': 1430,
#  'horrible': 1419,
#  'soon': 1413,
#  'later': 1411,
#  'doesnt': 1407,
#  'button': 1392,
#  'expect': 1386,
#  'payment': 1371,
#  'either': 1368,
#  'platform': 1357,
#  'glitch': 1351,
#  'guy': 1348,
#  'another': 1329,
#  'enough': 1328,
#  'fan': 1315,
#  'fire': 1301,
#  'definitely': 1293,
#  'two': 1281,
#  'especially': 1279,
#  'thanks': 1277,
#  'everyone': 1271,
#  'de': 1270,
#  'original': 1263,
#  'user': 1260,
#  'half': 1253,
#  'stick': 1253,
#  'full': 1252,
#  'do': 1251,
#  'spin': 1250,
#  'channel': 1245,
#  'super': 1243,
#  'uninstall': 1236,
#  'multiple': 1235,
#  'password': 1228,
#  'alot': 1225,
#  'skip': 1220,
#  'often': 1209,
#  'release': 1204,
#  'pause': 1201,
#  'hard': 1199,
#  'buy': 1190,
#  'overall': 1186,
#  'call': 1174,
#  'subscribe': 1173,
#  'close': 1172,
#  'frustrate': 1164,
#  'useless': 1162,
#  'poor': 1156,
#  'wonderful': 1154,
#  'page': 1143,
#  'email': 1139,
#  'prime': 1133,
#  'etc': 1132,
#  'fantastic': 1125,
#  'bit': 1124,
#  'tried': 1123,
#  'program': 1110,
#  'amazon': 1108,
#  'feel': 1106,
#  'clear': 1104,
#  'rating': 1102,
#  'title': 1101,
#  'stay': 1095,
#  'matter': 1092,
#  'live': 1086,
#  'subtitle': 1080,
#  'ask': 1079,
#  'la': 1079,
#  'click': 1071,
#  'bring': 1069,
#  'garbage': 1068,
#  'hate': 1067,
#  'simpson': 1058,
#  'everytime': 1057,
#  'version': 1044,
#  'ago': 1041,
#  'literally': 1039,
#  'launch': 1036,
#  'que': 1024,
#  'instead': 1013,
#  'cause': 1009,
#  'least': 1000,
#  'disappointed': 996,
#  'variety': 984,
#  'constant': 983,
#  'age': 976,
#  'card': 975,
#  'loading': 972,
#  'late': 970,
#  'circle': 970,
#  'cartoon': 968,
#  'maybe': 968,
#  'section': 956,
#  'couple': 956,
#  'adult': 952,
#  'fast': 951,
#  'na': 933,
#  'several': 929,
#  'world': 924,
#  'pixar': 919,
#  'disappoint': 916,
#  'grow': 914,
#  'choice': 911,
#  'completely': 903,
#  'recently': 900,
#  'e': 899,
#  'longer': 893,
#  'contact': 892,
#  'choose': 891,
#  'finally': 889,
#  'trouble': 886,
#  'set': 878,
#  'network': 873,
#  'forward': 870,
#  'buggy': 870,
#  'offer': 869,
#  'refund': 862,
#  'force': 862,
#  'high': 861,
#  'unless': 858,
#  'perfectly': 856,
#  'remember': 855,
#  'mean': 854,
#  'properly': 852,
#  'part': 846,
#  'cache': 845,
#  'life': 842,
#  'otherwise': 841,
#  'ad': 840,
#  'monthly': 839,
#  'roku': 833,
#  'install': 833,
#  'entertainment': 830,
#  'memory': 829,
#  'check': 827,
#  'today': 825,
#  'youtube': 822,
#  'trash': 820,
#  'begin': 814,
#  'anyone': 813,
#  'except': 812,
#  'others': 809,
#  'remove': 808,
#  'function': 808,
#  'single': 807,
#  'bundle': 807,
#  'rate': 807,
#  'resume': 807,
#  'save': 805,
#  'instal': 799,
#  'glitchy': 798,
#  'due': 793,
#  'top': 790,
#  'watching': 788,
#  'house': 788,
#  'brilliant': 786,
#  'buffering': 785,
#  'hear': 781,
#  'fact': 778,
#  'interface': 774,
#  'lose': 772,
#  'ridiculous': 765,
#  'website': 764,
#  'uninstalling': 763,
#  'stuck': 759,
#  'order': 757,
#  'move': 750,
#  'speed': 749,
#  'awful': 746,
#  'language': 741,
#  'finish': 740,
#  'around': 734,
#  'edit': 733,
#  'include': 732,
#  'credit': 731,
#  'daughter': 730,
#  'huge': 729,
#  'note': 728,
#  'awsome': 726,
#  'guess': 723,
#  'extremely': 716,
#  'server': 714,
#  'laptop': 708,
#  'lack': 697,
#  'whenever': 696,
#  'amount': 695,
#  'dollar': 686,
#  'must': 682,
#  'together': 681,
#  'away': 678,
#  'stupid': 678,
#  'break': 675,
#  'friendly': 675,
#  'frustrating': 675,
#  'quite': 671,
#  'online': 671,
#  'gina': 671,
#  'favourite': 669,
#  'son': 667,
#  'control': 659,
#  'may': 657,
#  'night': 656,
#  'select': 651,
#  'pixel': 650,
#  'computer': 649,
#  'someone': 646,
#  'understand': 644,
#  'mode': 640,
#  'kind': 640,
#  'low': 640,
#  'tab': 636,
#  'okay': 631,
#  'sort': 629,
#  'highly': 626,
#  'playback': 624,
#  'refuse': 621,
#  'pick': 621,
#  'yes': 621,
#  'might': 620,
#  'five': 619,
#  'xbox': 618,
#  'setting': 617,
#  'resolve': 617,
#  'complaint': 614,
#  'blue': 609,
#  'fail': 609,
#  'main': 604,
#  'date': 603,
#  'improve': 602,
#  'chrome': 600,
#  'application': 600,
#  'reset': 595,
#  'probably': 595,
#  'idea': 592,
#  'currently': 590,
#  'episodes': 589,
#  'entire': 586,
#  'impossible': 584,
#  'spend': 584,
#  'honestly': 583,
#  'less': 581,
#  'cheap': 580,
#  'en': 577,
#  'decent': 576,
#  'totally': 574,
#  'watchlist': 571,
#  'lol': 565,
#  'sad': 565,
#  'small': 564,
#  'short': 563,
#  'cost': 563,
#  'blank': 560,
#  'game': 560,
#  'create': 555,
#  'switch': 555,
#  'care': 551,
#  'lock': 551,
#  'via': 549,
#  'renew': 548,
#  'job': 548,
#  'figure': 547,
#  'consider': 545,
#  'verizon': 542,
#  'hold': 541,
#  'certain': 540,
#  'recent': 535,
#  'purchase': 532,
#  'become': 529,
#  'ive': 529,
#  'story': 528,
#  'laggy': 528,
#  'pop': 527,
#  'compatible': 524,
#  'volume': 523,
#  'man': 521,
#  'excite': 520,
#  'min': 519,
#  'whatever': 519,
#  'read': 518,
#  'glad': 517,
#  'disappointing': 517,
#  'randomly': 515,
#  'site': 515,
#  'hopefully': 514,
#  'ui': 513,
#  'downloaded': 513,
#  'menu': 512,
#  'real': 509,
#  'three': 507,
#  'simply': 507,
#  'difficult': 506,
#  'appear': 506,
#  'library': 505,
#  'bar': 503,
#  'n': 502,
#  'deal': 502,
#  'compare': 500,
#  'store': 500,
#  'el': 500,
#  'cut': 499,
#  'se': 499,
#  'unsubscribe': 499,
#  'plan': 498,
#  'drop': 497,
#  'navigate': 497,
#  'unusable': 496,
#  'improvement': 496,
#  'talk': 495,
#  'entertain': 493,
#  'region': 491,
#  'suppose': 491,
#  'twice': 490,
#  'kick': 489,
#  'line': 488,
#  'extra': 486,
#  'friend': 483,
#  'require': 481,
#  'ultra': 481,
#  'complete': 481,
#  'none': 480,
#  'joke': 478,
#  'middle': 472,
#  'videos': 469,
#  'national': 469,
#  'chat': 468,
#  'ton': 466,
#  'seriously': 464,
#  'pin': 463,
#  'logo': 463,
#  'hit': 462,
#  'wow': 460,
#  'browser': 459,
#  'barely': 456,
#  'medium': 456,
#  'decide': 454,
#  'oh': 453,
#  'country': 451,
#  'possible': 450,
#  'share': 450,
#  'system': 449,
#  'info': 448,
#  'although': 447,
#  'despite': 447,
#  'anywhere': 443,
#  'send': 442,
#  'hop': 442,
#  'wan': 442,
#  'baby': 442,
#  'number': 441,
#  'track': 441,
#  'gon': 439,
#  'spiderman': 436,
#  'shame': 435,
#  'till': 434,
#  'better': 433,
#  'young': 429,
#  'value': 429,
#  'type': 429,
#  'zero': 428,
#  'believe': 427,
#  'auto': 425,
#  'absolute': 424,
#  'kinda': 424,
#  'provide': 423,
#  'geographic': 423,
#  'player': 419,
#  'asap': 419,
#  'espn': 418,
#  'opinion': 418,
#  'mouse': 417,
#  'major': 416,
#  'sit': 415,
#  'thats': 414,
#  'information': 413,
#  'word': 413,
#  'attempt': 407,
#  'vizio': 405,
#  'bill': 403,
#  'worst': 402,
#  'fee': 402,
#  'basically': 402,
#  'frozen': 400,
#  'luck': 398,
#  'example': 398,
#  'signal': 397,
#  'automatically': 396,
#  'box': 395,
#  'tho': 394,
#  'yeah': 392,
#  'onto': 391,
#  'icon': 391,
#  'god': 390,
#  'pc': 390,
#  'simple': 390,
#  'press': 389,
#  'lately': 387,
#  'english': 387,
#  'carano': 387,
#  'expensive': 386,
#  'sorry': 386,
#  'enter': 386,
#  'display': 384,
#  'collection': 384,
#  'rather': 383,
#  'rest': 382,
#  'binge': 380,
#  'moment': 379,
#  'firestick': 379,
#  'mostly': 378,
#  'future': 377,
#  'mess': 376,
#  'increase': 376,
#  'brand': 376,
#  'scroll': 376,
#  'wake': 375,
#  'hell': 373,
#  'alone': 371,
#  'damn': 371,
#  'product': 367,
#  'sony': 367,
#  'updated': 363,
#  'area': 363,
#  'limit': 362,
#  'enjoyable': 361,
#  'disconnect': 361,
#  'ability': 359,
#  'bunch': 359,
#  'ruin': 358,
#  'state': 357,
#  'name': 357,
#  'unfortunately': 356,
#  'walt': 355,
#  'idk': 353,
#  'starwars': 353,
#  'developer': 353,
#  'exit': 351,
#  'basic': 350,
#  'rarely': 349,
#  'usually': 349,
#  'smooth': 348,
#  'wheel': 346,
#  'manage': 345,
#  'design': 344,
#  'group': 343,
#  'para': 343,
#  'didnt': 342,
#  'rubbish': 339,
#  'fav': 339,
#  'forget': 339,
#  'membership': 339,
#  'category': 338,
#  'action': 336,
#  'parent': 336,
#  'incredible': 336,
#  'b': 334,
#  'nostalgia': 334,
#  'pls': 332,
#  'tech': 330,
#  'push': 327,
#  'frequently': 327,
#  'bother': 327,
#  'apple': 325,
#  'isnt': 325,
#  'easily': 324,
#  'mickey': 324,
#  'course': 324,
#  'cell': 324,
#  'mind': 323,
#  'reboot': 323,
#  'billion': 320,
#  'suggest': 318,
#  'sudden': 318,
#  'unavailable': 318,
#  'chromebook': 317,
#  'school': 316,
#  'watched': 316,
#  'within': 316,
#  'hdr': 315,
#  'cuz': 315,
#  'plenty': 315,
#  'large': 314,
#  'hang': 314,
#  'travel': 313,
#  'link': 312,
#  'playing': 309,
#  'chance': 309,
#  'bc': 309,
#  'correct': 308,
#  'along': 308,
#  'documentary': 306,
#  'intro': 306,
#  'suddenly': 306,
#  'broken': 305,
#  'early': 305,
#  'lg': 305,
#  'rat': 305,
#  'person': 304,
#  'l': 303,
#  'follow': 303,
#  'yesterday': 303,
#  'rewind': 302,
#  'trip': 302,
#  'background': 300,
#  'current': 299,
#  'clone': 297,
#  'premium': 296,
#  'ya': 296,
#  'upset': 296,
#  'there': 296,
#  'mirror': 296,
#  'ipad': 296,
#  'epic': 296,
#  'catch': 295,
#  'sense': 295,
#  'technical': 294,
#  'range': 293,
#  'history': 292,
#  'address': 292,
#  'immediately': 292,
#  'notification': 292,
#  'write': 292,
#  'respond': 291,
#  'hbo': 291,
#  'autoplay': 291,
#  'freezes': 291,
#  'un': 290,
#  'ready': 288,
#  'mcu': 288,
#  'progress': 288,
#  'car': 286,
#  'act': 286,
#  'woke': 284,
#  'receive': 283,
#  'pro': 283,
#  'mulan': 283,
#  'wonder': 282,
#  'non': 282,
#  'besides': 282,
#  'crazy': 281,
#  'own': 281,
#  'thought': 281,
#  'truly': 281,
#  'beyond': 280,
#  'fox': 280,
#  'dolby': 279,
#  'answer': 279,
#  'political': 279,
#  'brings': 279,
#  'wide': 278,
#  'character': 278,
#  'apparently': 277,
#  'sub': 277,
#  'omg': 277,
#  'television': 277,
#  'fall': 276,
#  'upgrade': 276,
#  'per': 276,
#  'speak': 276,
#  'space': 275,
#  'shut': 274,
#  'rid': 273,
#  'notice': 272,
#  'location': 271,
#  'king': 270,
#  'mine': 269,
#  'random': 269,
#  'hd': 269,
#  'girl': 267,
#  'storage': 267,
#  'side': 267,
#  'web': 267,
#  'step': 266,
#  'hand': 266,
#  'across': 266,
#  'helpful': 265,
#  'anytime': 264,
#  'beautiful': 262,
#  'sick': 262,
#  'fully': 261,
#  'actual': 261,
#  'nostalgic': 259,
#  'troubleshoot': 259,
#  'playstation': 259,
#  'block': 258,
#  'funny': 258,
#  'hardly': 258,
#  'functionality': 258,
#  'raise': 258,
#  'straight': 256,
#  'strong': 256,
#  'da': 255,
#  'cable': 255,
#  'não': 255,
#  'true': 254,
#  'iphone': 254,
#  'response': 253,
#  'result': 253,
#  'left': 253,
#  'scene': 252,
#  'mom': 251,
#  'sync': 251,
#  'clearly': 251,
#  'method': 250,
#  'infinite': 248,
#  'por': 248,
#  'period': 248,
#  'complain': 247,
#  'limited': 247,
#  'havent': 246,
#  'suggestion': 246,
#  'yall': 246,
#  'quick': 246,
#  'glitching': 245,
#  'mention': 245,
#  'purpose': 245,
#  'battery': 245,
#  'post': 243,
#  'nearly': 243,
#  'morning': 243,
#  'team': 243,
#  'pain': 243,
#  'business': 243,
#  'item': 243,
#  'disappear': 243,
#  'mi': 242,
#  'weird': 242,
#  'ur': 241,
#  'con': 241,
#  'similar': 241,
#  'dark': 241,
#  'appreciate': 241,
#  'subscriber': 240,
#  'gay': 239,
#  'bore': 239,
#  'whats': 239,
#  'wandavision': 239,
#  'owl': 238,
#  'base': 237,
#  'f': 237,
#  'obviously': 236,
#  'premier': 236,
#  'yearly': 235,
#  'correctly': 233,
#  'max': 233,
#  'process': 233,
#  'request': 232,
#  'road': 232,
#  'room': 231,
#  'saw': 231,
#  'mandolorian': 231,
#  'comment': 230,
#  'spot': 229,
#  'total': 228,
#  'test': 228,
#  'quickly': 228,
#  'return': 228,
#  'image': 227,
#  'everyday': 227,
#  'avenger': 227,
#  'addition': 227,
#  'manually': 227,
#  'previously': 226,
#  'afford': 226,
#  'exist': 226,
#  'anyway': 226,
#  'jump': 225,
#  'muy': 225,
#  'spanish': 224,
#  'wife': 224,
#  'atmos': 223,
#  'solution': 223,
#  'solve': 221,
#  'reinstalled': 220,
#  'layout': 220,
#  'yoda': 219,
#  'casting': 219,
#  'g': 219,
#  'performance': 218,
#  'touch': 218,
#  'detail': 218,
#  'vision': 217,
#  'learn': 216,
#  'browse': 216,
#  'culture': 216,
#  'dose': 216,
#  'sd': 215,
#  'negative': 215,
#  'die': 214,
#  'lo': 213,
#  'smoothly': 212,
#  'behind': 212,
#  'package': 212,
#  'clean': 212,
#  'ta': 211,
#  'bank': 211,
#  'whether': 211,
#  'fixed': 210,
#  'soo': 210,
#  'x': 210,
#  'hi': 209,
#  'wach': 209,
#  'rip': 209,
#  'sister': 209,
#  'interest': 209,
#  'r': 209,
#  'american': 209,
#  'tire': 208,
#  'unwatchable': 208,
#  'incredibly': 208,
#  'software': 207,
#  'dumb': 207,
#  'dream': 206,
#  'case': 205,
#  'book': 204,
#  'scam': 204,
#  'unlike': 204,
#  'death': 204,
#  'previous': 204,
#  'heart': 204,
#  'agenda': 203,
#  'pathetic': 202,
#  'endless': 202,
#  'exactly': 202,
#  'worked': 201,
#  'dvd': 201,
#  'vpn': 200,
#  'solid': 200,
#  'window': 200,
#  'listen': 200,
#  'general': 200,
#  'four': 199,
#  'upon': 199,
#  'reach': 199,
#  'happens': 198,
#  'power': 198,
#  'poorly': 198,
#  'pirate': 197,
#  'flight': 197,
#  'hamilton': 197,
#  'thru': 196,
#  'uk': 196,
#  'ver': 195,
#  'plz': 194,
#  'le': 194,
#  'reload': 194,
#  'tap': 194,
#  'consistently': 194,
#  'hey': 194,
#  'alright': 194,
#  'animate': 193,
#  'meet': 193,
#  'french': 193,
#  'airplane': 192,
#  'million': 192,
#  'theater': 191,
#  'bye': 191,
#  'center': 191,
#  'sits': 190,
#  'standard': 190,
#  'voice': 189,
#  'continuously': 189,
#  ...}

# %% [markdown]
# ## Exploration of bigrams

# %%
bigrams = [bigram for review in tokenized_reviews for bigram in nltk.bigrams(review)]

# %%
bigrams_counter = Counter(bigrams)

# %%
bigrams_counter
# Out:
# Counter({('absolutely', 'awesome'): 33,
#          ('wonder', 'software'): 1,
#          ('software', 'disney'): 6,
#          ('disney', 'plus'): 6213,
#          ('plus', 'issue'): 22,
#          ('issue', 'always'): 28,
#          ('always', 'come'): 27,
#          ('come', 'playing'): 1,
#          ('playing', 'dolby'): 2,
#          ('dolby', 'atmos'): 126,
#          ('atmos', 'movie'): 3,
#          ('movie', 'sound'): 36,
#          ('sound', 'system'): 14,
#          ('system', 'come'): 1,
#          ('come', 'thru'): 5,
#          ('thru', 'sound'): 1,
#          ('sound', 'bar'): 10,
#          ('bar', 'awhile'): 1,
#          ('awhile', 'lag'): 2,
#          ('lag', 'abit'): 2,
#          ('abit', 'watch'): 2,
#          ('watch', 'netflix'): 153,
#          ('netflix', 'platform'): 6,
#          ('platform', 'issue'): 8,
#          ('issue', 'sound'): 19,
#          ('sound', 'kindly'): 1,
#          ('kindly', 'ple'): 1,
#          ('ple', 'fixed'): 1,
#          ('fixed', 'issue'): 21,
#          ('issue', 'pay'): 39,
#          ('pay', 'monthly'): 241,
#          ('give', 'month'): 14,
#          ('month', 'premium'): 2,
#          ('like', 'show'): 140,
#          ('awesome', 'app'): 560,
#          ('app', 'love'): 804,
#          ('love', 'easy'): 56,
#          ('easy', 'use'): 1039,
#          ('awesome', 'movie'): 140,
#          ('movie', 'tv'): 1249,
#          ('tv', 'show'): 2100,
#          ('show', 'horrible'): 6,
#          ('horrible', 'app'): 215,
#          ('app', 'constantly'): 303,
#          ('constantly', 'buffer'): 388,
#          ('buffer', 'every'): 460,
#          ('every', 'netflix'): 2,
#          ('netflix', 'hulu'): 471,
#          ('hulu', 'run'): 5,
#          ('run', 'fine'): 55,
#          ('fine', 'also'): 16,
#          ('also', 'minimize'): 1,
#          ('minimize', 'screen'): 24,
#          ('screen', 'continue'): 16,
#          ('continue', 'watch'): 1780,
#          ('new', 'movie'): 931,
#          ('happy', 'nice'): 1,
#          ('nice', 'app'): 338,
#          ('honestly', 'get'): 9,
#          ('get', 'everyone'): 4,
#          ('everyone', 'hate'): 1,
#          ('hate', 'issue'): 2,
#          ('issue', 'long'): 12,
#          ('long', 'take'): 18,
#          ('take', 'rewind'): 1,
#          ('app', 'play'): 241,
#          ('play', 'download'): 268,
#          ('download', 'content'): 746,
#          ('wo', 'open'): 663,
#          ('open', 'say'): 60,
#          ('say', 'update'): 68,
#          ('update', 'play'): 21,
#          ('play', 'fine'): 80,
#          ('fine', 'tv'): 126,
#          ('always', 'buffer'): 213,
#          ('buffer', 'say'): 17,
#          ('say', 'offline'): 113,
#          ('offline', 'terrible'): 6,
#          ('terrible', 'app'): 433,
#          ('app', 'always'): 360,
#          ('always', 'say'): 214,
#          ('say', 'signal'): 7,
#          ('signal', 'offline'): 2,
#          ('offline', 'connection'): 5,
#          ('connection', 'late'): 3,
#          ('late', 'note'): 1,
#          ('note', 'bad'): 2,
#          ('bad', 'movie'): 40,
#          ('movie', 'app'): 592,
#          ('app', 'ever'): 1709,
#          ('ever', 'experience'): 29,
#          ('experience', 'update'): 3,
#          ('update', 'horrible'): 8,
#          ('horrible', 'make'): 4,
#          ('make', 'run'): 6,
#          ('run', 'smoother'): 8,
#          ('smoother', 'take'): 1,
#          ('take', 'hour'): 137,
#          ('hour', 'watch'): 89,
#          ('watch', 'min'): 33,
#          ('min', 'episode'): 20,
#          ('episode', 'much'): 5,
#          ('much', 'money'): 165,
#          ('money', 'smooth'): 1,
#          ('smooth', 'interface'): 8,
#          ('interface', 'drop'): 1,
#          ('drop', 'price'): 4,
#          ('price', 'many'): 8,
#          ('many', 'issue'): 136,
#          ('issue', 'app'): 479,
#          ('app', 'never'): 557,
#          ('never', 'experience'): 25,
#          ('experience', 'horrible'): 4,
#          ('horrible', 'stream'): 17,
#          ('stream', 'platform'): 255,
#          ('platform', 'lame'): 1,
#          ('lame', 'app'): 7,
#          ('app', 'like'): 362,
#          ('like', 'straight'): 1,
#          ('straight', 'garbage'): 7,
#          ('garbage', 'like'): 5,
#          ('like', 'trash'): 6,
#          ('trash', 'lol'): 2,
#          ('lol', 'ew'): 1,
#          ('really', 'want'): 214,
#          ('want', 'like'): 39,
#          ('like', 'break'): 3,
#          ('break', 'every'): 8,
#          ('every', 'time'): 1549,
#          ('time', 'turn'): 22,
#          ('turn', 'xbox'): 4,
#          ('xbox', 'open'): 4,
#          ('open', 'phone'): 291,
#          ('phone', 'log'): 41,
#          ('log', 'resign'): 1,
#          ('resign', 'authentication'): 1,
#          ('authentication', 'reset'): 1,
#          ('reset', 'password'): 97,
#          ('password', 'take'): 1,
#          ('take', 'current'): 3,
#          ('current', 'password'): 5,
#          ('password', 'reset'): 21,
#          ('reset', 'current'): 2,
#          ('password', 'repeat'): 1,
#          ('repeat', 'next'): 1,
#          ('next', 'day'): 119,
#          ('day', 'pay'): 28,
#          ('pay', 'ca'): 120,
#          ('ca', 'even'): 1988,
#          ('even', 'log'): 317,
#          ('great', 'movie'): 1284,
#          ('movie', 'series'): 649,
#          ('recently', 'let'): 5,
#          ('let', 'send'): 1,
#          ('send', 'movie'): 3,
#          ('tv', 'send'): 2,
#          ('send', 'get'): 3,
#          ('get', 'refund'): 148,
#          ('refund', 'tip'): 1,
#          ('tip', 'super'): 1,
#          ('super', 'long'): 10,
#          ('long', 'spring'): 1,
#          ('spring', 'break'): 2,
#          ('break', 'since'): 9,
#          ('since', 'march'): 10,
#          ('load', 'new'): 17,
#          ('new', 'film'): 68,
#          ('film', 'watch'): 72,
#          ('watch', 'love'): 129,
#          ('love', 'old'): 257,
#          ('old', 'cartoon'): 105,
#          ('cartoon', 'like'): 32,
#          ('like', 'gummie'): 1,
#          ('gummie', 'bear'): 3,
#          ('like', 'content'): 121,
#          ('content', 'two'): 6,
#          ('two', 'screen'): 2,
#          ('screen', 'availability'): 2,
#          ('availability', 'without'): 1,
#          ('without', 'pay'): 60,
#          ('pay', 'netflix'): 23,
#          ('netflix', 'however'): 10,
#          ('however', 'get'): 20,
#          ('get', 'blue'): 47,
#          ('blue', 'spin'): 31,
#          ('spin', 'ring'): 5,
#          ('ring', 'wait'): 1,
#          ('wait', 'quite'): 4,
#          ('quite', 'bit'): 28,
#          ('bit', 'canceled'): 1,
#          ('canceled', 'disney'): 1,
#          ('disney', 'thing'): 57,
#          ('thing', 'due'): 3,
#          ('due', 'behavior'): 1,
#          ('behavior', 'toward'): 1,
#          ('toward', 'child'): 2,
#          ('child', 'push'): 3,
#          ('push', 'agenda'): 18,
#          ('agenda', 'child'): 11,
#          ('child', 'indoctrinate'): 4,
#          ('dreadful', 'app'): 5,
#          ('app', 'downloads'): 50,
#          ('downloads', 'take'): 66,
#          ('take', 'much'): 49,
#          ('much', 'long'): 16,
#          ('long', 'constantly'): 2,
#          ('constantly', 'crash'): 197,
#          ('crash', 'sometimes'): 19,
#          ('sometimes', 'crash'): 18,
#          ('crash', 'delete'): 7,
#          ('delete', 'painstakingly'): 1,
#          ('painstakingly', 'download'): 1,
#          ('download', 'show'): 466,
#          ('show', 'acquire'): 4,
#          ('acquire', 'absolutely'): 1,
#          ('absolutely', 'horrific'): 2,
#          ('horrific', 'app'): 4,
#          ('lag', 'sound'): 4,
#          ('sound', 'disappears'): 1,
#          ('disappears', 'rewind'): 1,
#          ('rewind', 'definitely'): 1,
#          ('definitely', 'cancel'): 27,
#          ('cancel', 'renew'): 6,
#          ('renew', 'subscription'): 198,
#          ('mandalorian', 'play'): 7,
#          ('play', 'right'): 22,
#          ('right', 'stop'): 4,
#          ('stop', 'load'): 175,
#          ('load', 'time'): 254,
#          ('buffer', 'history'): 1,
#          ('history', 'designer'): 1,
#          ('designer', 'need'): 1,
#          ('need', 'go'): 47,
#          ('go', 'back'): 965,
#          ('back', 'ui'): 1,
#          ('ui', 'school'): 1,
#          ('internet', 'make'): 16,
#          ('make', 'hard'): 82,
#          ('hard', 'watch'): 73,
#          ('watch', 'still'): 63,
#          ('still', 'pretty'): 20,
#          ('pretty', 'food'): 1,
#          ('iove', 'disney'): 3,
#          ('plus', 'like'): 60,
#          ('like', 'watch'): 545,
#          ('watch', 'movie'): 3059,
#          ('movie', 'room'): 3,
#          ('see', 'allot'): 1,
#          ('allot', 'review'): 1,
#          ('review', 'post'): 5,
#          ('post', 'recently'): 1,
#          ('recently', 'google'): 1,
#          ('google', 'tv'): 162,
#          ('tv', 'app'): 573,
#          ('app', 'problem'): 286,
#          ('problem', 'fix'): 134,
#          ('fix', 'issue'): 708,
#          ('issue', 'last'): 26,
#          ('last', 'month'): 207,
#          ('year', 'b'): 1,
#          ('b', 'lie'): 1,
#          ('lie', 'update'): 1,
#          ('update', 'say'): 30,
#          ('say', 'fixing'): 1,
#          ('fixing', 'thing'): 3,
#          ('thing', 'bug'): 12,
#          ('bug', 'fix'): 155,
#          ('fix', 'update'): 70,
#          ('update', 'hope'): 7,
#          ('hope', 'find'): 12,
#          ('find', 'stream'): 10,
#          ('stream', 'experience'): 41,
#          ('experience', 'even'): 15,
#          ('even', 'well'): 110,
#          ('great', 'story'): 25,
#          ('ask', 'birthday'): 5,
#          ('birthday', 'b'): 1,
#          ('need', 'work'): 448,
#          ('amaze', 'come'): 3,
#          ('come', 'life'): 7,
#          ('constantly', 'error'): 19,
#          ('error', 'wo'): 42,
#          ('wo', 'play'): 822,
#          ('play', 'downloads'): 81,
#          ('love', 'app'): 5578,
#          ('favorite', 'app'): 92,
#          ('love', 'disney'): 4383,
#          ('plus', 'fun'): 17,
#          ('fun', 'family'): 37,
#          ('family', 'everybody'): 2,
#          ('everybody', 'else'): 13,
#          ('good', 'age'): 22,
#          ('great', 'show'): 722,
#          ('show', 'annoy'): 9,
#          ('annoy', 'hell'): 10,
#          ('hell', 'sign'): 1,
#          ('sign', 'especially'): 1,
#          ('especially', 'tv'): 20,
#          ('tv', 'make'): 45,
#          ('make', 'change'): 41,
#          ('change', 'password'): 185,
#          ('password', 'even'): 18,
#          ('even', 'put'): 28,
#          ('put', 'correctly'): 3,
#          ('correctly', 'logs'): 1,
#          ('logs', 'reason'): 5,
#          ('way', 'remove'): 43,
#          ('remove', 'show'): 42,
#          ('show', 'list'): 35,
#          ('list', 'decide'): 1,
#          ('decide', 'finish'): 2,
#          ('finish', 'way'): 4,
#          ('way', 'get'): 136,
#          ('get', 'around'): 28,
#          ('around', 'use'): 4,
#          ('use', 'watch'): 313,
#          ('watch', 'list'): 500,
#          ('list', 'exclusively'): 1,
#          ('exclusively', 'aside'): 1,
#          ('aside', 'significant'): 1,
#          ('significant', 'ui'): 1,
#          ('ui', 'failure'): 1,
#          ('failure', 'streaming'): 1,
#          ('streaming', 'service'): 864,
#          ('love', 'movie'): 1079,
#          ('great', 'content'): 1199,
#          ('content', 'poor'): 41,
#          ('poor', 'app'): 122,
#          ('app', 'use'): 658,
#          ('use', 'work'): 542,
#          ('work', 'great'): 1584,
#          ('great', 'first'): 87,
#          ('first', 'come'): 74,
#          ('come', 'slow'): 2,
#          ('slow', 'laggy'): 43,
#          ('laggy', 'unresponsive'): 4,
#          ('unresponsive', 'crash'): 1,
#          ('crash', 'often'): 53,
#          ('often', 'wake'): 1,
#          ('wake', 'disney'): 15,
#          ('disney', 'go'): 160,
#          ('go', 'watch'): 299,
#          ('watch', 'content'): 228,
#          ('content', 'make'): 59,
#          ('make', 'difficult'): 63,
#          ('difficult', 'access'): 4,
#          ('access', 'poor'): 5,
#          ('app', 'support'): 61,
#          ('work', 'flawlessly'): 94,
#          ('flawlessly', 'never'): 2,
#          ('never', 'glitch'): 8,
#          ('great', 'app'): 4519,
#          ('require', 'internet'): 44,
#          ('internet', 'connection'): 1068,
#          ('connection', 'play'): 15,
#          ('play', 'episode'): 121,
#          ('episode', 'download'): 48,
#          ('download', 'point'): 7,
#          ('point', 'feature'): 6,
#          ('feature', 'ux'): 2,
#          ('ux', 'sloppy'): 1,
#          ('wish', 'vrains'): 1,
#          ('good', 'wide'): 8,
#          ('wide', 'variety'): 110,
#          ('variety', 'content'): 41,
#          ('download', 'work'): 137,
#          ('work', 'even'): 212,
#          ('even', 'solution'): 1,
#          ('solution', 'suggest'): 4,
#          ('suggest', 'stream'): 3,
#          ('stream', 'offline'): 10,
#          ('offline', 'experience'): 15,
#          ('experience', 'sad'): 3,
#          ('excellent', 'movie'): 38,
#          ('movie', 'good'): 235,
#          ('good', 'picture'): 19,
#          ('picture', 'quality'): 85,
#          ('quality', 'awsome'): 1,
#          ('awsome', 'app'): 57,
#          ('app', 'thank'): 73,
#          ('movie', 'player'): 6,
#          ('player', 'bad'): 7,
#          ('bad', 'netflix'): 27,
#          ('netflix', 'change'): 3,
#          ('change', 'caption'): 5,
#          ('caption', 'font'): 2,
#          ('font', 'size'): 13,
#          ('size', 'color'): 6,
#          ('color', 'show'): 1,
#          ('show', 'resolution'): 1,
#          ('resolution', 'search'): 1,
#          ('search', 'play'): 7,
#          ('play', 'imax'): 2,
#          ('imax', 'properly'): 1,
#          ('properly', 'run'): 2,
#          ('run', 'high'): 4,
#          ('high', 'data'): 4,
#          ('data', 'although'): 1,
#          ('although', 'set'): 1,
#          ('set', 'automatic'): 3,
#          ('automatic', 'conclusion'): 1,
#          ('conclusion', 'bad'): 1,
#          ('bad', 'apps'): 30,
#          ('apps', 'platform'): 5,
#          ('platform', 'googletv'): 1,
#          ('googletv', 'android'): 1,
#          ('android', 'etc'): 1,
#          ('app', 'doesnt'): 219,
#          ('doesnt', 'work'): 463,
#          ('work', 'cant'): 47,
#          ('cant', 'get'): 280,
#          ('get', 'movie'): 193,
#          ('movie', 'without'): 237,
#          ('without', 'buffer'): 151,
#          ('every', 'second'): 557,
#          ('second', 'worth'): 6,
#          ('worth', 'even'): 17,
#          ('even', 'wifi'): 112,
#          ('wifi', 'doesnt'): 5,
#          ('doesnt', 'load'): 90,
#          ('load', 'properly'): 91,
#          ('properly', 'delete'): 1,
#          ('delete', 'app'): 447,
#          ('app', 'reinstall'): 201,
#          ('reinstall', 'app'): 713,
#          ('app', 'clear'): 73,
#          ('clear', 'cache'): 517,
#          ('cache', 'restart'): 43,
#          ('restart', 'phone'): 591,
#          ('phone', 'nothing'): 90,
#          ('nothing', 'work'): 584,
#          ('work', 'also'): 87,
#          ('also', 'date'): 2,
#          ('unusable', 'garbage'): 4,
#          ('garbage', 'slow'): 4,
#          ('slow', 'interface'): 7,
#          ('interface', 'downloads'): 2,
#          ('downloads', 'work'): 181,
#          ('ᏸ', 'iտᕼ'): 1,
#          ('iտᕼ', 'ᕼᗩᗪ'): 1,
#          ('ᕼᗩᗪ', 'ℭ'): 1,
#          ('ℭ', 'ᙏoᖇᙓ'): 1,
#          ('ᙏoᖇᙓ', 'tᐯ'): 1,
#          ('tᐯ', 'sᕼᓍᘺs'): 1,
#          ('sᕼᓍᘺs', 'αρρ'): 1,
#          ('pretty', 'good'): 763,
#          ('good', 'tbh'): 6,
#          ('way', 'expensive'): 15,
#          ('grow', 'watch'): 143,
#          ('watch', 'disney'): 1527,
#          ('disney', 'movie'): 3264,
#          ('movie', 'child'): 55,
#          ('child', 'inlove'): 1,
#          ('inlove', 'many'): 1,
#          ('many', 'animate'): 1,
#          ('animate', 'disney'): 5,
#          ('movie', 'year'): 35,
#          ('year', 'old'): 432,
#          ('old', 'right'): 2,
#          ('right', 'still'): 5,
#          ('still', 'love'): 108,
#          ('love', 'watch'): 1356,
#          ('watch', 'favorite'): 916,
#          ('favorite', 'disney'): 522,
#          ('movie', 'excite'): 11,
#          ('excite', 'beacuse'): 1,
#          ('beacuse', 'remake'): 1,
#          ('remake', 'live'): 1,
#          ('live', 'action'): 136,
#          ('action', 'one'): 4,
#          ('one', 'every'): 11,
#          ('every', 'single'): 430,
#          ('single', 'one'): 15,
#          ('one', 'perfect'): 3,
#          ('perfect', 'almost'): 1,
#          ('almost', 'way'): 2,
#          ('way', 'like'): 9,
#          ('like', 'original'): 18,
#          ('original', 'animated'): 2,
#          ('animated', 'movie'): 20,
#          ('movie', 'love'): 526,
#          ('love', 'enjoy'): 35,
#          ('enjoy', 'disney'): 203,
#          ('plus', 'quite'): 5,
#          ('quite', 'alot'): 3,
#          ('alot', 'enjoy'): 1,
#          ('enjoy', 'watch'): 352,
#          ('movie', 'show'): 3223,
#          ('show', 'time'): 78,
#          ('time', 'inwant'): 1,
#          ('excellent', 'material'): 1,
#          ('unwanted', 'sneaky'): 1,
#          ('sneaky', 'app'): 1,
#          ('always', 'love'): 117,
#          ('disney', 'app'): 820,
#          ('never', 'problem'): 281,
#          ('problem', 'stream'): 150,
#          ('stream', 'problem'): 29,
#          ('problem', 'pause'): 4,
#          ('pause', 'come'): 6,
#          ('come', 'back'): 383,
#          ('back', 'easily'): 2,
#          ('bad', 'batch'): 54,
#          ('batch', 'star'): 2,
#          ('star', 'review'): 152,
#          ('review', 'point'): 2,
#          ('point', 'though'): 4,
#          ('though', 'trick'): 1,
#          ('trick', 'sometimes'): 1,
#          ('sometimes', 'get'): 62,
#          ('get', 'late'): 17,
#          ('late', 'episode'): 11,
#          ('episode', 'thing'): 10,
#          ('thing', 'play'): 42,
#          ('play', 'case'): 4,
#          ('case', 'use'): 3,
#          ('use', 'windows'): 1,
#          ('windows', 'machine'): 2,
#          ('machine', 'wire'): 1,
#          ('wire', 'internet'): 2,
#          ('love', 'okay'): 1,
#          ('like', 'app'): 770,
#          ('great', 'way'): 156,
#          ('way', 'showcase'): 1,
#          ('showcase', 'watch'): 1,
#          ('good', 'watch'): 293,
#          ('watch', 'alot'): 49,
#          ('brother', 'tell'): 1,
#          ('tell', 'awesome'): 1,
#          ('awesome', 'new'): 15,
#          ('new', 'documentary'): 2,
#          ('documentary', 'host'): 1,
#          ('host', 'david'): 1,
#          ('david', 'letterman'): 1,
#          ('letterman', 'bono'): 1,
#          ('bono', 'edge'): 2,
#          ('edge', 'glad'): 1,
#          ('glad', 'see'): 15,
#          ('see', 'one'): 70,
#          ('one', 'favorite'): 121,
#          ('favorite', 'rock'): 1,
#          ('rock', 'band'): 1,
#          ('band', 'surely'): 1,
#          ('surely', 'one'): 3,
#          ('one', 'iconic'): 1,
#          ('iconic', 'time'): 1,
#          ('time', 'bono'): 1,
#          ('bono', 'incomparable'): 1,
#          ('incomparable', 'voice'): 1,
#          ('voice', 'group'): 1,
#          ('group', 'almost'): 1,
#          ('almost', 'biblical'): 1,
#          ('biblical', 'lyric'): 1,
#          ('lyric', 'hit'): 1,
#          ('hit', 'song'): 3,
#          ('song', 'song'): 1,
#          ('song', 'decade'): 1,
#          ('decade', 'decade'): 2,
#          ('decade', 'wonderful'): 1,
#          ('wonderful', 'history'): 1,
#          ('history', 'ireland'): 1,
#          ('ireland', 'band'): 1,
#          ('band', 'make'): 1,
#          ('make', 'one'): 34,
#          ('one', 'enjoyable'): 1,
#          ('enjoyable', 'view'): 2,
#          ('view', 'experience'): 63,
#          ('experience', 'ever'): 50,
#          ('ever', 'well'): 13,
#          ('well', 'do'): 140,
#          ('do', 'dave'): 1,
#          ('dave', 'bono'): 1,
#          ('app', 'need'): 736,
#          ('need', 'picture'): 37,
#          ('picture', 'picture'): 531,
#          ('picture', 'feature'): 33,
#          ('feature', 'pop'): 2,
#          ('pop', 'player'): 11,
#          ('player', 'like'): 12,
#          ('like', 'netflix'): 967,
#          ('netflix', 'amazon'): 400,
#          ('amazon', 'prime'): 440,
#          ('prime', 'also'): 2,
#          ('also', 'download'): 84,
#          ('download', 'video'): 301,
#          ('video', 'movie'): 17,
#          ('tv', 'keep'): 78,
#          ('keep', 'download'): 9,
#          ('download', 'tab'): 8,
#          ('tab', 'active'): 1,
#          ('active', 'crawl'): 1,
#          ('crawl', 'forward'): 1,
#          ('forward', 'download'): 4,
#          ('download', 'mind'): 1,
#          ('mind', 'internet'): 2,
#          ('internet', 'every'): 14,
#          ('every', 'ott'): 1,
#          ('ott', 'platform'): 6,
#          ('platform', 'whizz'): 1,
#          ('love', 'show'): 480,
#          ('show', 'miss'): 87,
#          ('miss', 'like'): 35,
#          ('like', 'aaron'): 1,
#          ('aaron', 'stone'): 3,
#          ('love', 'apps'): 4,
#          ('apps', 'add'): 4,
#          ('add', 'film'): 6,
#          ('show', 'suck'): 11,
#          ('suck', 'mostly'): 2,
#          ('mostly', 'late'): 1,
#          ('late', 'one'): 4,
#          ('go', 'wake'): 81,
#          ('wake', 'go'): 73,
#          ('go', 'broke'): 72,
#          ('great', 'little'): 29,
#          ('little', 'app'): 13,
#          ('luv', 'app'): 16,
#          ('app', 'issue'): 294,
#          ('issue', 'apps'): 40,
#          ('apps', 'get'): 17,
#          ('get', 'freeze'): 4,
#          ('freeze', 'cut'): 2,
#          ('cut', 'happy'): 1,
#          ('happy', 'disney'): 62,
#          ('disney', 'recommend'): 11,
#          ('recommend', 'anyone'): 110,
#          ('anyone', 'great'): 4,
#          ('app', 'tablet'): 87,
#          ('tablet', 'well'): 7,
#          ('well', 'mobile'): 15,
#          ('mobile', 'work'): 29,
#          ('great', 'many'): 51,
#          ('many', 'thing'): 130,
#          ('thing', 'watch'): 457,
#          ('watch', 'luv'): 2,
#          ('luv', 'well'): 1,
#          ('well', 'able'): 16,
#          ('able', 'use'): 469,
#          ('use', 'app'): 1800,
#          ('app', 'work'): 4481,
#          ('work', 'keep'): 252,
#          ('keep', 'jump'): 6,
#          ('jump', 'dont'): 1,
#          ('dont', 'many'): 3,
#          ('many', 'time'): 432,
#          ('time', 'updated'): 8,
#          ('updated', 'delete'): 2,
#          ('delete', 'still'): 11,
#          ('still', 'wo'): 278,
#          ('wo', 'work'): 874,
#          ('work', 'month'): 124,
#          ('month', 'nothing'): 32,
#          ('nothing', 'get'): 31,
#          ('get', 'do'): 19,
#          ('do', 'must'): 2,
#          ('must', 'issue'): 5,
#          ('issue', 'use'): 70,
#          ('use', 'anymore'): 33,
#          ('anymore', 'still'): 6,
#          ('still', 'work'): 788,
#          ('sd', 'card'): 155,
#          ('card', 'playback'): 1,
#          ('playback', 'still'): 4,
#          ('still', 'give'): 39,
#          ('give', 'blank'): 7,
#          ('blank', 'screen'): 320,
#          ('screen', 'even'): 89,
#          ('even', 'update'): 109,
#          ('update', 'problem'): 30,
#          ('problem', 'still'): 46,
#          ('still', 'remain'): 7,
#          ('first', 'time'): 291,
#          ('time', 'app'): 270,
#          ('app', 'good'): 751,
#          ('good', 'experience'): 138,
#          ('experience', 'watch'): 33,
#          ('watch', 'something'): 1084,
#          ('something', 'lag'): 6,
#          ('lag', 'go'): 5,
#          ('go', 'slow'): 10,
#          ('good', 'bad'): 36,
#          ('picture', 'work'): 52,
#          ('work', 'worst'): 8,
#          ('worst', 'phone'): 1,
#          ('phone', 'app'): 491,
#          ('app', 'streaming'): 17,
#          ('grey', 'anatomy'): 25,
#          ('shut', 'log'): 1,
#          ('log', 'tv'): 77,
#          ('kid', 'love'): 912,
#          ('love', 'honest'): 1,
#          ('app', 'wo'): 1444,
#          ('open', 'anymore'): 73,
#          ('anymore', 'galaxy'): 2,
#          ('galaxy', 'tab'): 221,
#          ('tab', 'plus'): 7,
#          ('miss', 'pip'): 3,
#          ('pip', 'support'): 9,
#          ('support', 'excuse'): 1,
#          ('excuse', 'app'): 8,
#          ('app', 'vpn'): 7,
#          ('vpn', 'support'): 1,
#          ('support', 'travel'): 1,
#          ('travel', 'group'): 1,
#          ('group', 'watch'): 194,
#          ('watch', 'work'): 79,
#          ('want', 'work'): 144,
#          ('work', 'tv'): 348,
#          ('tv', 'device'): 56,
#          ('device', 'device'): 17,
#          ('device', 'date'): 8,
#          ('love', 'many'): 154,
#          ('many', 'option'): 117,
#          ('option', 'movie'): 54,
#          ('show', 'much'): 38,
#          ('much', 'choose'): 49,
#          ('yeah', 'would'): 3,
#          ('would', 'app'): 36,
#          ('app', 'star'): 233,
#          ('star', 'war'): 3522,
#          ('war', 'buggy'): 1,
#          ('buggy', 'ability'): 1,
#          ('ability', 'download'): 40,
#          ('download', 'cool'): 2,
#          ('cool', 'downloader'): 1,
#          ('downloader', 'garbage'): 1,
#          ('garbage', 'unless'): 1,
#          ('unless', 'gigabit'): 1,
#          ('gigabit', 'network'): 1,
#          ('network', 'take'): 5,
#          ('take', 'forever'): 805,
#          ('forever', 'start'): 16,
#          ('start', 'download'): 53,
#          ('download', 'complain'): 1,
#          ('complain', 'constantly'): 2,
#          ('constantly', 'connection'): 6,
#          ('connection', 'home'): 9,
#          ('home', 'town'): 3,
#          ('town', 'wifi'): 2,
#          ('wifi', 'idk'): 4,
#          ('idk', 'man'): 2,
#          ('man', 'probably'): 1,
#          ('probably', 'take'): 5,
#          ('take', 'child'): 6,
#          ('child', 'traffic'): 5,
#          ('traffic', 'money'): 1,
#          ('money', 'get'): 56,
#          ('get', 'app'): 1344,
#          ('app', 'inline'): 1,
#          ('inline', 'reality'): 1,
#          ('reality', 'wise'): 1,
#          ('wise', 'im'): 2,
#          ('im', 'love'): 33,
#          ('love', 'star'): 257,
#          ('war', 'stuff'): 63,
#          ('stuff', 'thanks'): 3,
#          ('app', 'junk'): 17,
#          ('junk', 'load'): 2,
#          ('load', 'show'): 118,
#          ('show', 'could'): 79,
#          ('could', 'give'): 247,
#          ('give', 'zero'): 125,
#          ('zero', 'star'): 174,
#          ('star', 'would'): 185,
#          ('would', 'disney'): 35,
#          ('disney', 'focus'): 6,
#          ('focus', 'hire'): 2,
#          ('hire', 'decent'): 4,
#          ('decent', 'coder'): 1,
#          ('coder', 'instead'): 1,
#          ('instead', 'wake'): 1,
#          ('fails', 'sometimes'): 2,
#          ('keep', 'come'): 147,
#          ('come', 'awesome'): 6,
#          ('awesome', 'show'): 89,
#          ('show', 'like'): 539,
#          ('like', 'star'): 139,
#          ('war', 'marvel'): 476,
#          ('marvel', 'show'): 166,
#          ('show', 'know'): 32,
#          ('know', 'happen'): 62,
#          ('happen', 'start'): 4,
#          ('start', 'good'): 19,
#          ('good', 'wanda'): 2,
#          ('wanda', 'vision'): 88,
#          ('vision', 'falcon'): 5,
#          ('falcon', 'winter'): 93,
#          ('winter', 'soldier'): 107,
#          ('soldier', 'moon'): 1,
#          ('moon', 'knight'): 37,
#          ('knight', 'get'): 2,
#          ('get', 'boring'): 30,
#          ('boring', 'creative'): 1,
#          ('option', 'choose'): 56,
#          ('choose', 'resolution'): 8,
#          ('resolution', 'suffer'): 1,
#          ('suffer', 'fullhd'): 1,
#          ('fullhd', 'slow'): 1,
#          ('slow', 'internet'): 54,
#          ('internet', 'speed'): 138,
#          ('movie', 'portray'): 1,
#          ('portray', 'state'): 1,
#          ('state', 'always'): 1,
#          ('always', 'portray'): 1,
#          ('portray', 'hdr'): 1,
#          ('hdr', 'even'): 5,
#          ('even', 'try'): 188,
#          ('try', 'play'): 397,
#          ('play', 'prism'): 1,
#          ('prism', 'tv'): 1,
#          ('tv', 'please'): 57,
#          ('please', 'fix'): 2501,
#          ('show', 'play'): 148,
#          ('play', 'lot'): 13,
#          ('lot', 'bug'): 107,
#          ('bug', 'pretty'): 3,
#          ('pretty', 'par'): 1,
#          ('par', 'disney'): 2,
#          ('disney', 'product'): 38,
#          ('app', 'year'): 91,
#          ('year', 'still'): 42,
#          ('still', 'ca'): 239,
#          ('ca', 'get'): 1227,
#          ('get', 'aspect'): 3,
#          ('aspect', 'ratio'): 86,
#          ('ratio', 'right'): 1,
#          ('right', 'tablet'): 1,
#          ('tablet', 'garbage'): 2,
#          ('great', 'job'): 155,
#          ('job', 'disney'): 119,
#          ('video', 'keep'): 59,
#          ('keep', 'load'): 406,
#          ('load', 'never'): 120,
#          ('never', 'play'): 115,
#          ('play', 'app'): 136,
#          ('always', 'problem'): 79,
#          ('problem', 'please'): 70,
#          ('fix', 'want'): 28,
#          ('want', 'watch'): 1780,
#          ('movie', 'wo'): 147,
#          ('play', 'netflix'): 20,
#          ('netflix', 'seem'): 15,
#          ('seem', 'always'): 10,
#          ('always', 'work'): 186,
#          ('like', 'turtle'): 4,
#          ('still', 'havent'): 12,
#          ('havent', 'fix'): 5,
#          ('fix', 'offline'): 13,
#          ('offline', 'download'): 100,
#          ('download', 'issue'): 32,
#          ('issue', 'pathetic'): 2,
#          ('crash', 'chromebook'): 4,
#          ('chromebook', 'way'): 2,
#          ('way', 'go'): 128,
#          ('go', 'disney'): 182,
#          ('best', 'ever'): 192,
#          ('super', 'frustrate'): 30,
#          ('frustrate', 'almost'): 5,
#          ('almost', 'never'): 73,
#          ('never', 'count'): 3,
#          ('count', 'chrome'): 1,
#          ('chrome', 'cast'): 366,
#          ('cast', 'button'): 91,
#          ('button', 'show'): 24,
#          ('show', 'without'): 121,
#          ('without', 'restart'): 15,
#          ('restart', 'app'): 233,
#          ('like', 'time'): 73,
#          ('time', 'ca'): 132,
#          ('ca', 'hard'): 8,
#          ('hard', 'app'): 6,
#          ('app', 'crash'): 530,
#          ('crash', 'lot'): 64,
#          ('lot', 'lately'): 12,
#          ('lately', 'also'): 1,
#          ('also', 'roku'): 4,
#          ('roku', 'subscription'): 2,
#          ('subscription', 'fee'): 78,
#          ('wo', 'let'): 1307,
#          ('let', 'watch'): 720,
#          ('watch', 'roku'): 23,
#          ('roku', 'unless'): 2,
#          ('unless', 'got'): 2,
#          ('got', 'upgraded'): 1,
#          ('upgraded', 'subscription'): 1,
#          ('full', 'movie'): 66,
#          ('movie', 'best'): 85,
#          ('best', 'time'): 14,
#          ('time', 'use'): 165,
#          ('keep', 'good'): 155,
#          ('good', 'work'): 252,
#          ('work', 'cynthia'): 1,
#          ('cynthia', 'michelle'): 1,
#          ('michelle', 'brown'): 1,
#          ('well', 'cheap'): 7,
#          ('cheap', 'netflix'): 39,
#          ('netflix', 'totally'): 5,
#          ('totally', 'worth'): 110,
#          ('month', 'th'): 1,
#          ('th', 'still'): 1,
#          ('ca', 'access'): 272,
#          ('access', 'disney'): 112,
#          ('plus', 'think'): 20,
#          ('think', 'fix'): 14,
#          ('fix', 'problem'): 480,
#          ('problem', 'keep'): 39,
#          ('keep', 'tell'): 296,
#          ('tell', 'update'): 47,
#          ('update', 'available'): 35,
#          ('available', 'get'): 11,
#          ('get', 'update'): 44,
#          ('update', 'one'): 15,
#          ('one', 'let'): 4,
#          ('let', 'use'): 124,
#          ('much', 'fun'): 136,
#          ('fun', 'much'): 6,
#          ('much', 'different'): 6,
#          ('different', 'choice'): 8,
#          ('third', 'class'): 1,
#          ('class', 'rubbish'): 1,
#          ('app', 'remember'): 48,
#          ('remember', 'watched'): 16,
#          ('watched', 'episode'): 21,
#          ('episode', 'point'): 4,
#          ('point', 'episode'): 2,
#          ('episode', 'pause'): 10,
#          ('pause', 'even'): 13,
#          ('even', 'vlc'): 2,
#          ('vlc', 'good'): 1,
#          ('fine', 'guess'): 11,
#          ('poor', 'ux'): 3,
#          ('ux', 'loses'): 1,
#          ('loses', 'internet'): 2,
#          ('like', 'disney'): 840,
#          ('disney', 'problem'): 45,
#          ('problem', 'wish'): 12,
#          ('wish', 'guy'): 12,
#          ('guy', 'give'): 3,
#          ('give', 'u'): 164,
#          ('u', 'speed'): 1,
#          ('speed', 'button'): 2,
#          ('button', 'cause'): 1,
#          ('cause', 'movie'): 4,
#          ('movie', 'take'): 115,
#          ('take', 'long'): 490,
#          ('long', 'watch'): 36,
#          ('monthly', 'payment'): 56,
#          ('payment', 'expensive'): 1,
#          ('answer', 'thank'): 2,
#          ('thank', 'go'): 3,
#          ('go', 'midland'): 1,
#          ('midland', 'airport'): 1,
#          ('airport', 'august'): 1,
#          ('want', 'profile'): 1,
#          ('profile', 'luz'): 1,
#          ('absolutely', 'love'): 798,
#          ('love', 'interface'): 9,
#          ('interface', 'find'): 1,
#          ('find', 'everything'): 17,
#          ('everything', 'extremely'): 3,
#          ('extremely', 'easy'): 12,
#          ('use', 'think'): 17,
#          ('think', 'expensive'): 2,
#          ('expensive', 'available'): 1,
#          ('available', 'watch'): 80,
#          ('disney', 'channel'): 539,
#          ('keep', 'get'): 1022,
#          ('get', 'error'): 1752,
#          ('error', 'code'): 2887,
#          ('code', 'device'): 33,
#          ('device', 'try'): 86,
#          ('try', 'every'): 50,
#          ('every', 'thing'): 116,
#          ('thing', 'uninstalled'): 3,
#          ('uninstalled', 'reinstalled'): 156,
#          ('reinstalled', 'disney'): 1,
#          ('plus', 'restarted'): 1,
#          ('restarted', 'router'): 3,
#          ('router', 'bunch'): 1,
#          ('bunch', 'thing'): 11,
#          ('thing', 'google'): 5,
#          ('google', 'tell'): 14,
#          ('tell', 'nothing'): 6,
#          ('continuously', 'need'): 2,
#          ('need', 'reinstall'): 29,
#          ('reinstall', 'loses'): 1,
#          ('loses', 'setting'): 1,
#          ('hi', 'andrew'): 1,
#          ('andrew', 'never'): 1,
#          ('problem', 'offline'): 6,
#          ('offline', 'disney'): 7,
#          ('plus', 'netflix'): 22,
#          ('hulu', 'watch'): 4,
#          ('watch', 'fav'): 76,
#          ('fav', 'movie'): 103,
#          ('show', 'offline'): 55,
#          ('offline', 'videos'): 2,
#          ('videos', 'work'): 13,
#          ('work', 'good'): 276,
#          ('good', 'android'): 9,
#          ...})

# %%
sorted_bigrams_by_frequency = sorted(bigrams_counter.items(), key=lambda x:x[1], reverse = True)
converted_dict_bigrams = dict(sorted_bigrams_by_frequency)

# %%
converted_dict_bigrams
# Out:
# {('disney', 'plus'): 6213,
#  ('love', 'app'): 5578,
#  ('great', 'app'): 4519,
#  ('app', 'work'): 4481,
#  ('love', 'disney'): 4383,
#  ('star', 'war'): 3522,
#  ('disney', 'movie'): 3264,
#  ('movie', 'show'): 3223,
#  ('show', 'movie'): 3215,
#  ('watch', 'movie'): 3059,
#  ('error', 'code'): 2887,
#  ('good', 'app'): 2824,
#  ('work', 'fine'): 2683,
#  ('please', 'fix'): 2501,
#  ('watch', 'anything'): 2295,
#  ('stream', 'service'): 2119,
#  ('tv', 'show'): 2100,
#  ('cancel', 'subscription'): 2086,
#  ('ca', 'even'): 1988,
#  ('ca', 'watch'): 1949,
#  ('use', 'app'): 1800,
#  ('continue', 'watch'): 1780,
#  ('want', 'watch'): 1780,
#  ('get', 'error'): 1752,
#  ('app', 'ever'): 1709,
#  ('best', 'app'): 1695,
#  ('open', 'app'): 1661,
#  ('really', 'good'): 1587,
#  ('work', 'great'): 1584,
#  ('try', 'watch'): 1582,
#  ('every', 'time'): 1549,
#  ('watch', 'disney'): 1527,
#  ('load', 'screen'): 1498,
#  ('app', 'wo'): 1444,
#  ('able', 'watch'): 1404,
#  ('smart', 'tv'): 1359,
#  ('love', 'watch'): 1356,
#  ('get', 'app'): 1344,
#  ('give', 'star'): 1316,
#  ('wo', 'let'): 1307,
#  ('wo', 'load'): 1298,
#  ('watch', 'show'): 1291,
#  ('great', 'movie'): 1284,
#  ('stop', 'work'): 1275,
#  ('app', 'great'): 1260,
#  ('movie', 'tv'): 1249,
#  ('ca', 'get'): 1227,
#  ('black', 'screen'): 1223,
#  ('next', 'episode'): 1201,
#  ('great', 'content'): 1199,
#  ('download', 'app'): 1146,
#  ('good', 'movie'): 1132,
#  ('stream', 'app'): 1122,
#  ('customer', 'service'): 1108,
#  ('watch', 'something'): 1084,
#  ('work', 'well'): 1081,
#  ('love', 'movie'): 1079,
#  ('internet', 'connection'): 1068,
#  ('love', 'love'): 1046,
#  ('easy', 'use'): 1039,
#  ('keep', 'get'): 1022,
#  ('work', 'phone'): 1019,
#  ('download', 'movie'): 1017,
#  ('app', 'keep'): 1012,
#  ('error', 'message'): 1005,
#  ('app', 'watch'): 999,
#  ('like', 'netflix'): 967,
#  ('go', 'back'): 965,
#  ('new', 'movie'): 931,
#  ('favorite', 'movie'): 931,
#  ('movie', 'watch'): 931,
#  ('free', 'trial'): 929,
#  ('watch', 'favorite'): 916,
#  ('wo', 'even'): 915,
#  ('kid', 'love'): 912,
#  ('never', 'work'): 900,
#  ('get', 'watch'): 896,
#  ('unable', 'connect'): 892,
#  ('app', 'phone'): 891,
#  ('even', 'though'): 879,
#  ('wo', 'work'): 874,
#  ('app', 'load'): 867,
#  ('streaming', 'service'): 864,
#  ('marvel', 'movie'): 862,
#  ('keep', 'say'): 842,
#  ('like', 'disney'): 840,
#  ('wo', 'play'): 822,
#  ('disney', 'app'): 820,
#  ('amaze', 'app'): 819,
#  ('disney', 'show'): 811,
#  ('take', 'forever'): 805,
#  ('app', 'love'): 804,
#  ('absolutely', 'love'): 798,
#  ('need', 'fix'): 793,
#  ('still', 'work'): 788,
#  ('show', 'watch'): 782,
#  ('waste', 'money'): 771,
#  ('like', 'app'): 770,
#  ('would', 'like'): 770,
#  ('pretty', 'good'): 763,
#  ('app', 'open'): 753,
#  ('app', 'good'): 751,
#  ('ca', 'use'): 747,
#  ('download', 'content'): 746,
#  ('even', 'get'): 746,
#  ('stream', 'apps'): 745,
#  ('even', 'open'): 741,
#  ('app', 'need'): 736,
#  ('app', 'get'): 727,
#  ('give', 'error'): 724,
#  ('time', 'try'): 724,
#  ('great', 'show'): 722,
#  ('let', 'watch'): 720,
#  ('reinstall', 'app'): 713,
#  ('fix', 'issue'): 708,
#  ('bad', 'app'): 695,
#  ('favorite', 'show'): 692,
#  ('love', 'much'): 690,
#  ('fix', 'app'): 688,
#  ('cast', 'tv'): 687,
#  ('love', 'content'): 680,
#  ('even', 'load'): 675,
#  ('update', 'app'): 674,
#  ('wo', 'open'): 663,
#  ('great', 'selection'): 661,
#  ('android', 'phone'): 660,
#  ('would', 'give'): 660,
#  ('app', 'use'): 658,
#  ('best', 'thing'): 651,
#  ('movie', 'series'): 649,
#  ('play', 'movie'): 646,
#  ('marvel', 'star'): 640,
#  ('movie', 'like'): 633,
#  ('work', 'perfectly'): 631,
#  ('really', 'like'): 627,
#  ('good', 'show'): 624,
#  ('good', 'content'): 622,
#  ('say', 'error'): 618,
#  ('app', 'would'): 609,
#  ('pay', 'subscription'): 597,
#  ('uninstalled', 'reinstall'): 595,
#  ('movie', 'app'): 592,
#  ('restart', 'phone'): 591,
#  ('pay', 'service'): 589,
#  ('old', 'movie'): 589,
#  ('app', 'still'): 588,
#  ('google', 'play'): 586,
#  ('nothing', 'work'): 584,
#  ('tv', 'app'): 573,
#  ('uninstall', 'reinstall'): 572,
#  ('even', 'watch'): 569,
#  ('watch', 'download'): 569,
#  ('watch', 'tv'): 569,
#  ('play', 'anything'): 567,
#  ('samsung', 'galaxy'): 566,
#  ('work', 'android'): 566,
#  ('awesome', 'app'): 560,
#  ('app', 'never'): 557,
#  ('every', 'second'): 557,
#  ('bring', 'back'): 556,
#  ('try', 'later'): 554,
#  ('cant', 'even'): 551,
#  ('content', 'great'): 550,
#  ('like', 'watch'): 545,
#  ('use', 'work'): 542,
#  ('one', 'place'): 542,
#  ('show', 'like'): 539,
#  ('disney', 'channel'): 539,
#  ('last', 'update'): 537,
#  ('feel', 'like'): 535,
#  ('app', 'even'): 535,
#  ('go', 'wrong'): 534,
#  ('get', 'work'): 532,
#  ('picture', 'picture'): 531,
#  ('half', 'time'): 531,
#  ('app', 'crash'): 530,
#  ('watch', 'phone'): 530,
#  ('old', 'disney'): 529,
#  ('movie', 'love'): 526,
#  ('get', 'fix'): 524,
#  ('favorite', 'disney'): 522,
#  ('watch', 'old'): 520,
#  ('long', 'time'): 520,
#  ('content', 'app'): 518,
#  ('would', 'love'): 518,
#  ('clear', 'cache'): 517,
#  ('app', 'disney'): 517,
#  ('phone', 'tv'): 517,
#  ('app', 'suck'): 515,
#  ('multiple', 'time'): 512,
#  ('never', 'load'): 510,
#  ('cant', 'watch'): 504,
#  ('app', 'amaze'): 502,
#  ('watch', 'offline'): 501,
#  ('watch', 'list'): 500,
#  ('worth', 'money'): 493,
#  ('play', 'video'): 492,
#  ('phone', 'app'): 491,
#  ('whole', 'family'): 491,
#  ('take', 'long'): 490,
#  ('new', 'content'): 487,
#  ('even', 'download'): 482,
#  ('love', 'show'): 480,
#  ('fix', 'problem'): 480,
#  ('issue', 'app'): 479,
#  ('something', 'go'): 478,
#  ('watch', 'section'): 477,
#  ('war', 'marvel'): 476,
#  ('app', 'stop'): 476,
#  ('make', 'app'): 476,
#  ('really', 'enjoy'): 475,
#  ('app', 'ca'): 472,
#  ('would', 'nice'): 472,
#  ('netflix', 'hulu'): 471,
#  ('able', 'use'): 469,
#  ('every', 'minute'): 469,
#  ('download', 'show'): 466,
#  ('android', 'tv'): 465,
#  ('doesnt', 'work'): 463,
#  ('wont', 'let'): 463,
#  ('app', 'much'): 463,
#  ('buffer', 'every'): 460,
#  ('app', 'really'): 460,
#  ('keep', 'crash'): 459,
#  ('thing', 'watch'): 457,
#  ('let', 'log'): 452,
#  ('forever', 'load'): 451,
#  ('well', 'netflix'): 451,
#  ('need', 'work'): 448,
#  ('delete', 'app'): 447,
#  ('many', 'movie'): 445,
#  ('get', 'disney'): 443,
#  ('movie', 'disney'): 443,
#  ('amazon', 'prime'): 440,
#  ('best', 'stream'): 439,
#  ('gon', 'na'): 437,
#  ('terrible', 'app'): 433,
#  ('year', 'old'): 432,
#  ('many', 'time'): 432,
#  ('get', 'past'): 432,
#  ('ca', 'connect'): 432,
#  ('every', 'single'): 430,
#  ('could', 'watch'): 429,
#  ('pay', 'something'): 429,
#  ('wish', 'could'): 426,
#  ('mobile', 'app'): 424,
#  ('disney', 'fan'): 423,
#  ('take', 'money'): 421,
#  ('please', 'add'): 420,
#  ('apps', 'work'): 420,
#  ('try', 'download'): 419,
#  ('problem', 'app'): 418,
#  ('best', 'movie'): 418,
#  ('thing', 'ever'): 416,
#  ('wan', 'na'): 414,
#  ('would', 'recommend'): 414,
#  ('try', 'use'): 412,
#  ('waste', 'time'): 410,
#  ('work', 'properly'): 410,
#  ('connect', 'internet'): 407,
#  ('keep', 'load'): 406,
#  ('several', 'time'): 406,
#  ('national', 'geographic'): 405,
#  ('work', 'samsung'): 404,
#  ('new', 'show'): 402,
#  ('netflix', 'amazon'): 400,
#  ('try', 'play'): 397,
#  ('movie', 'want'): 396,
#  ('late', 'update'): 394,
#  ('use', 'phone'): 394,
#  ('keep', 'buffer'): 394,
#  ('highly', 'recommend'): 391,
#  ('five', 'star'): 389,
#  ('constantly', 'buffer'): 388,
#  ('everything', 'else'): 387,
#  ('selection', 'movie'): 387,
#  ('try', 'get'): 385,
#  ('go', 'black'): 384,
#  ('great', 'love'): 384,
#  ('even', 'use'): 384,
#  ('come', 'back'): 383,
#  ('one', 'best'): 383,
#  ('one', 'star'): 381,
#  ('ca', 'wait'): 380,
#  ('say', 'unable'): 377,
#  ('would', 'great'): 377,
#  ('new', 'update'): 377,
#  ('work', 'app'): 376,
#  ('app', 'say'): 376,
#  ('family', 'love'): 375,
#  ('phone', 'work'): 374,
#  ('get', 'good'): 371,
#  ('gina', 'carano'): 371,
#  ('android', 'device'): 370,
#  ('love', 'everything'): 370,
#  ('phone', 'tablet'): 369,
#  ('load', 'phone'): 368,
#  ('app', 'lot'): 367,
#  ('chrome', 'cast'): 366,
#  ('even', 'work'): 363,
#  ('disney', 'pixar'): 363,
#  ('app', 'like'): 362,
#  ('pay', 'app'): 362,
#  ('tv', 'phone'): 362,
#  ('enjoy', 'app'): 361,
#  ('app', 'always'): 360,
#  ('old', 'show'): 358,
#  ('really', 'love'): 358,
#  ('app', 'wont'): 357,
#  ('enjoy', 'watch'): 352,
#  ('netflix', 'prime'): 352,
#  ('fix', 'soon'): 351,
#  ('service', 'work'): 351,
#  ('loading', 'screen'): 351,
#  ('look', 'forward'): 350,
#  ('lot', 'movie'): 350,
#  ('connect', 'disney'): 349,
#  ('work', 'tv'): 348,
#  ('try', 'everything'): 348,
#  ('never', 'get'): 348,
#  ('app', 'download'): 346,
#  ('wont', 'load'): 344,
#  ('show', 'disney'): 342,
#  ('amaze', 'love'): 342,
#  ('old', 'new'): 342,
#  ('watch', 'new'): 341,
#  ('everything', 'disney'): 340,
#  ('log', 'back'): 340,
#  ('load', 'app'): 339,
#  ('nice', 'app'): 338,
#  ('since', 'last'): 338,
#  ('ca', 'log'): 337,
#  ('mobile', 'device'): 336,
#  ('tv', 'series'): 334,
#  ('get', 'stuck'): 334,
#  ('content', 'good'): 332,
#  ('episode', 'watch'): 332,
#  ('new', 'one'): 331,
#  ('watch', 'thing'): 330,
#  ('try', 'log'): 330,
#  ('fire', 'stick'): 330,
#  ('watch', 'kid'): 329,
#  ('one', 'thing'): 329,
#  ('download', 'anything'): 328,
#  ('even', 'let'): 326,
#  ('connect', 'wifi'): 326,
#  ('fix', 'bug'): 325,
#  ('far', 'good'): 324,
#  ('home', 'screen'): 324,
#  ('play', 'next'): 324,
#  ('plus', 'app'): 323,
#  ('seem', 'like'): 322,
#  ('wish', 'would'): 321,
#  ('thank', 'disney'): 321,
#  ('blank', 'screen'): 320,
#  ('money', 'back'): 320,
#  ('close', 'app'): 320,
#  ('try', 'open'): 319,
#  ('even', 'log'): 317,
#  ('kid', 'watch'): 316,
#  ('movie', 'play'): 316,
#  ('app', 'go'): 316,
#  ('uninstalling', 'reinstall'): 315,
#  ('every', 'month'): 315,
#  ('update', 'payment'): 315,
#  ('show', 'app'): 315,
#  ('fun', 'watch'): 314,
#  ('use', 'watch'): 313,
#  ('seem', 'work'): 313,
#  ('keep', 'freeze'): 313,
#  ('screen', 'go'): 311,
#  ('movie', 'great'): 310,
#  ('see', 'movie'): 310,
#  ('everytime', 'try'): 308,
#  ('download', 'episode'): 308,
#  ('android', 'app'): 308,
#  ('every', 'movie'): 308,
#  ('load', 'anything'): 306,
#  ('great', 'service'): 305,
#  ('great', 'watch'): 305,
#  ('app', 'tv'): 305,
#  ('app', 'kid'): 304,
#  ('mobile', 'data'): 304,
#  ('app', 'constantly'): 303,
#  ('like', 'see'): 303,
#  ('fast', 'forward'): 303,
#  ('please', 'try'): 303,
#  ('work', 'time'): 302,
#  ('download', 'video'): 301,
#  ('load', 'load'): 301,
#  ('app', 'many'): 300,
#  ('go', 'watch'): 299,
#  ('war', 'movie'): 299,
#  ('really', 'great'): 297,
#  ('keep', 'tell'): 296,
#  ('user', 'friendly'): 296,
#  ('could', 'use'): 295,
#  ('app', 'issue'): 294,
#  ('watch', 'one'): 294,
#  ('ca', 'see'): 294,
#  ('disney', 'need'): 294,
#  ('every', 'day'): 294,
#  ('good', 'watch'): 293,
#  ('auto', 'play'): 293,
#  ('work', 'device'): 293,
#  ('time', 'watch'): 292,
#  ('app', 'try'): 292,
#  ('open', 'phone'): 291,
#  ('first', 'time'): 291,
#  ('ca', 'download'): 291,
#  ('lot', 'good'): 291,
#  ('love', 'marvel'): 291,
#  ('show', 'love'): 291,
#  ('ca', 'play'): 290,
#  ('app', 'terrible'): 289,
#  ('time', 'get'): 288,
#  ('disney', 'marvel'): 288,
#  ('app', 'problem'): 286,
#  ('good', 'selection'): 286,
#  ('great', 'kid'): 286,
#  ('watch', 'series'): 284,
#  ('watch', 'app'): 283,
#  ('clone', 'war'): 283,
#  ('every', 'disney'): 282,
#  ('never', 'problem'): 281,
#  ('cant', 'get'): 280,
#  ('movie', 'one'): 280,
#  ('still', 'wo'): 278,
#  ('love', 'great'): 277,
#  ('work', 'good'): 276,
#  ('first', 'day'): 276,
#  ('way', 'watch'): 276,
#  ('tv', 'work'): 274,
#  ('app', 'could'): 274,
#  ('ca', 'access'): 272,
#  ('get', 'back'): 272,
#  ('like', 'movie'): 272,
#  ('great', 'stream'): 271,
#  ('samsung', 'tablet'): 271,
#  ('good', 'quality'): 271,
#  ('time', 'app'): 270,
#  ('ca', 'open'): 270,
#  ('want', 'see'): 270,
#  ('month', 'ago'): 270,
#  ('movie', 'would'): 270,
#  ('watch', 'marvel'): 270,
#  ('watch', 'star'): 269,
#  ('watch', 'episode'): 269,
#  ('play', 'download'): 268,
#  ('still', 'nothing'): 266,
#  ('love', 'able'): 265,
#  ('really', 'annoy'): 264,
#  ('app', 'take'): 264,
#  ('constant', 'buffering'): 263,
#  ('ever', 'since'): 263,
#  ('disney', 'great'): 263,
#  ('perfectly', 'fine'): 263,
#  ('download', 'watch'): 262,
#  ('able', 'get'): 262,
#  ('well', 'worth'): 261,
#  ('disney', 'classic'): 261,
#  ('fire', 'gina'): 261,
#  ('brand', 'new'): 260,
#  ('much', 'good'): 259,
#  ('app', 'best'): 259,
#  ('get', 'rid'): 258,
#  ('app', 'show'): 258,
#  ('watch', 'stuff'): 258,
#  ('look', 'like'): 258,
#  ('love', 'old'): 257,
#  ('love', 'star'): 257,
#  ('app', 'easy'): 257,
#  ('love', 'see'): 257,
#  ('really', 'need'): 256,
#  ('stream', 'platform'): 255,
#  ('easy', 'navigate'): 255,
#  ('need', 'update'): 255,
#  ('disney', 'content'): 255,
#  ('load', 'time'): 254,
#  ('almost', 'every'): 254,
#  ('thing', 'like'): 254,
#  ('think', 'would'): 254,
#  ('app', 'movie'): 254,
#  ('app', 'make'): 253,
#  ('come', 'disney'): 253,
#  ('go', 'app'): 253,
#  ('app', 'awesome'): 253,
#  ('work', 'keep'): 252,
#  ('good', 'work'): 252,
#  ('work', 'get'): 252,
#  ('disney', 'would'): 252,
#  ('disney', 'get'): 252,
#  ('classic', 'disney'): 252,
#  ('recent', 'update'): 252,
#  ('use', 'disney'): 251,
#  ('keep', 'go'): 251,
#  ('ca', 'find'): 251,
#  ('please', 'help'): 250,
#  ('new', 'stuff'): 249,
#  ('make', 'sure'): 249,
#  ('since', 'update'): 249,
#  ('connect', 'service'): 248,
#  ('wont', 'even'): 248,
#  ('could', 'give'): 247,
#  ('access', 'app'): 247,
#  ('disney', 'love'): 247,
#  ('love', 'get'): 247,
#  ('need', 'add'): 247,
#  ('dollar', 'company'): 246,
#  ('app', 'longer'): 245,
#  ('would', 'think'): 245,
#  ('pretty', 'much'): 245,
#  ('already', 'pay'): 245,
#  ('app', 'android'): 244,
#  ('think', 'disney'): 244,
#  ('show', 'want'): 243,
#  ('app', 'bad'): 243,
#  ('day', 'ago'): 243,
#  ('prime', 'video'): 243,
#  ('great', 'work'): 243,
#  ('could', 'get'): 243,
#  ('billion', 'dollar'): 242,
#  ('load', 'movie'): 242,
#  ('pay', 'monthly'): 241,
#  ('app', 'play'): 241,
#  ('app', 'slow'): 241,
#  ('movie', 'come'): 241,
#  ('pay', 'year'): 241,
#  ('start', 'watch'): 240,
#  ('still', 'get'): 240,
#  ('still', 'ca'): 239,
#  ('app', 'let'): 239,
#  ('good', 'disney'): 239,
#  ('play', 'store'): 239,
#  ('ever', 'use'): 239,
#  ('say', 'ca'): 239,
#  ('issue', 'stream'): 238,
#  ('stuck', 'load'): 238,
#  ('lot', 'great'): 238,
#  ('movie', 'without'): 237,
#  ('many', 'show'): 237,
#  ('connection', 'issue'): 237,
#  ('without', 'internet'): 237,
#  ('keep', 'track'): 237,
#  ('movie', 'good'): 235,
#  ('give', 'app'): 235,
#  ('watch', 'mandalorian'): 235,
#  ('owl', 'house'): 234,
#  ('app', 'star'): 233,
#  ('restart', 'app'): 233,
#  ('great', 'family'): 233,
#  ('bad', 'stream'): 232,
#  ('app', 'stream'): 232,
#  ('let', 'sign'): 232,
#  ('try', 'cancel'): 232,
#  ('time', 'open'): 232,
#  ('movie', 'even'): 232,
#  ('fix', 'asap'): 230,
#  ('movie', 'get'): 230,
#  ('thing', 'disney'): 230,
#  ('app', 'give'): 230,
#  ('disney', 'film'): 230,
#  ('disney', 'make'): 229,
#  ('reinstall', 'still'): 229,
#  ('movie', 'kid'): 229,
#  ('watch', 'content'): 228,
#  ('back', 'childhood'): 228,
#  ('app', 'update'): 228,
#  ('show', 'great'): 228,
#  ('work', 'anymore'): 228,
#  ('anything', 'app'): 228,
#  ('point', 'download'): 228,
#  ('good', 'love'): 227,
#  ('app', 'also'): 227,
#  ('one', 'movie'): 226,
#  ('fix', 'please'): 226,
#  ('get', 'star'): 226,
#  ('samsung', 'tv'): 226,
#  ('get', 'charge'): 225,
#  ('longer', 'work'): 225,
#  ('watch', 'every'): 225,
#  ('video', 'play'): 224,
#  ('worst', 'stream'): 224,
#  ('give', 'option'): 224,
#  ('year', 'subscription'): 224,
#  ('movie', 'keep'): 224,
#  ('say', 'something'): 224,
#  ('stick', 'load'): 224,
#  ('try', 'uninstalling'): 223,
#  ('app', 'app'): 223,
#  ('pay', 'watch'): 223,
#  ('work', 'try'): 223,
#  ('childhood', 'movie'): 222,
#  ('long', 'load'): 222,
#  ('galaxy', 'tab'): 221,
#  ('error', 'try'): 221,
#  ('never', 'issue'): 221,
#  ('one', 'app'): 221,
#  ('app', 'one'): 221,
#  ('app', 'freeze'): 221,
#  ('plus', 'great'): 220,
#  ('work', 'like'): 220,
#  ('app', 'doesnt'): 219,
#  ('thanks', 'disney'): 219,
#  ('last', 'week'): 219,
#  ('time', 'load'): 219,
#  ('best', 'streaming'): 219,
#  ('skip', 'intro'): 218,
#  ('samsung', 'phone'): 218,
#  ('stream', 'tv'): 217,
#  ('series', 'movie'): 217,
#  ('wont', 'play'): 216,
#  ('horrible', 'app'): 215,
#  ('nothing', 'play'): 215,
#  ('cast', 'chromecast'): 215,
#  ('la', 'app'): 215,
#  ('app', 'time'): 215,
#  ('always', 'say'): 214,
#  ('really', 'want'): 214,
#  ('past', 'loading'): 214,
#  ('always', 'buffer'): 213,
#  ('app', 'every'): 213,
#  ('something', 'watch'): 213,
#  ('app', 'start'): 213,
#  ('get', 'new'): 213,
#  ('star', 'app'): 213,
#  ('nothing', 'load'): 213,
#  ('time', 'work'): 213,
#  ('get', 'load'): 213,
#  ('work', 'even'): 212,
#  ('app', 'run'): 212,
#  ('pay', 'month'): 212,
#  ('log', 'account'): 212,
#  ('work', 'work'): 212,
#  ('definitely', 'worth'): 212,
#  ('streaming', 'app'): 212,
#  ('good', 'kid'): 212,
#  ('watch', 'feature'): 212,
#  ('something', 'ca'): 211,
#  ('watch', 'everything'): 211,
#  ('dont', 'know'): 211,
#  ('app', 'seem'): 210,
#  ('would', 'work'): 210,
#  ('service', 'ca'): 210,
#  ('star', 'rating'): 210,
#  ('update', 'still'): 209,
#  ('say', 'internet'): 209,
#  ('baby', 'yoda'): 209,
#  ('original', 'content'): 209,
#  ('love', 'kid'): 209,
#  ('recommend', 'app'): 208,
#  ('mickey', 'mouse'): 208,
#  ('movie', 'download'): 208,
#  ('last', 'month'): 207,
#  ('something', 'everyone'): 207,
#  ('keep', 'log'): 207,
#  ('new', 'disney'): 206,
#  ('hulu', 'netflix'): 206,
#  ('one', 'day'): 206,
#  ('great', 'experience'): 206,
#  ('actually', 'work'): 206,
#  ('netflix', 'work'): 206,
#  ('stuff', 'watch'): 206,
#  ('love', 'selection'): 205,
#  ('customer', 'support'): 205,
#  ('ca', 'cast'): 205,
#  ('good', 'thing'): 205,
#  ('much', 'watch'): 205,
#  ('already', 'watch'): 205,
#  ('wont', 'work'): 205,
#  ('love', 'new'): 204,
#  ('would', 'let'): 204,
#  ('enjoy', 'disney'): 203,
#  ('app', 'well'): 203,
#  ('pay', 'money'): 203,
#  ('use', 'data'): 202,
#  ('app', 'since'): 202,
#  ('new', 'phone'): 202,
#  ('phone', 'get'): 202,
#  ('message', 'say'): 202,
#  ('make', 'sense'): 202,
#  ('app', 'reinstall'): 201,
#  ('load', 'circle'): 201,
#  ('work', 'ca'): 201,
#  ('screen', 'try'): 201,
#  ('app', 'pay'): 200,
#  ('family', 'movie'): 200,
#  ('good', 'netflix'): 200,
#  ('load', 'even'): 200,
#  ('episode', 'show'): 200,
#  ('new', 'episode'): 200,
#  ('slow', 'load'): 200,
#  ('still', 'need'): 200,
#  ('watch', 'downloads'): 199,
#  ('u', 'watch'): 199,
#  ('time', 'still'): 199,
#  ('app', 'wish'): 199,
#  ('dont', 'like'): 199,
#  ('renew', 'subscription'): 198,
#  ('week', 'ago'): 198,
#  ('great', 'price'): 198,
#  ('service', 'app'): 198,
#  ('app', 'please'): 198,
#  ('buffer', 'issue'): 198,
#  ('could', 'better'): 198,
#  ('issue', 'fix'): 198,
#  ('constantly', 'crash'): 197,
#  ('work', 'tablet'): 197,
#  ('pixar', 'marvel'): 197,
#  ('keep', 'give'): 196,
#  ('show', 'error'): 196,
#  ('show', 'kid'): 196,
#  ('watch', 'like'): 196,
#  ('let', 'download'): 195,
#  ('get', 'money'): 195,
#  ('group', 'watch'): 194,
#  ('unable', 'watch'): 194,
#  ('credit', 'card'): 194,
#  ('new', 'old'): 194,
#  ('get', 'free'): 194,
#  ('get', 'movie'): 193,
#  ('time', 'want'): 193,
#  ('try', 'load'): 193,
#  ('stay', 'load'): 193,
#  ('movie', 'see'): 193,
#  ('best', 'ever'): 192,
#  ('get', 'ta'): 192,
#  ('best', 'show'): 192,
#  ('phone', 'try'): 192,
#  ('disney', 'fix'): 191,
#  ('netflix', 'youtube'): 191,
#  ('kid', 'adult'): 191,
#  ('good', 'stuff'): 190,
#  ('get', 'black'): 190,
#  ('take', 'back'): 189,
#  ('walt', 'disney'): 189,
#  ('log', 'app'): 189,
#  ('excellent', 'app'): 189,
#  ('way', 'well'): 189,
#  ('even', 'try'): 188,
#  ('wifi', 'connection'): 188,
#  ('movie', 'new'): 188,
#  ('definitely', 'recommend'): 188,
#  ('na', 'watch'): 188,
#  ('downloaded', 'movie'): 188,
#  ('anything', 'else'): 187,
#  ('constantly', 'freeze'): 187,
#  ('always', 'work'): 186,
#  ('app', 'content'): 186,
#  ('great', 'disney'): 186,
#  ('change', 'password'): 185,
#  ('star', 'would'): 185,
#  ('work', 'half'): 185,
#  ('movie', 'night'): 185,
#  ('connect', 'server'): 185,
#  ('wo', 'connect'): 185,
#  ('ca', 'stream'): 185,
#  ('awesome', 'love'): 185,
#  ('show', 'load'): 185,
#  ('binge', 'watch'): 185,
#  ('whenever', 'try'): 184,
#  ('want', 'money'): 183,
#  ('go', 'cancel'): 183,
#  ('time', 'go'): 183,
#  ('give', 'five'): 183,
#  ('say', 'available'): 183,
#  ('go', 'disney'): 182,
#  ('hope', 'fix'): 182,
#  ('payment', 'method'): 182,
#  ('war', 'fan'): 182,
#  ('classic', 'movie'): 182,
#  ('love', 'wish'): 182,
#  ('recently', 'watch'): 182,
#  ('see', 'disney'): 182,
#  ('downloads', 'work'): 181,
#  ('movie', 'go'): 181,
#  ('movie', 'ever'): 181,
#  ('lot', 'content'): 181,
#  ('watch', 'video'): 180,
#  ('everything', 'want'): 180,
#  ('get', 'together'): 179,
#  ('use', 'service'): 179,
#  ('movie', 'available'): 179,
#  ('day', 'free'): 179,
#  ('watch', 'without'): 178,
#  ('get', 'see'): 178,
#  ('user', 'interface'): 178,
#  ('hope', 'get'): 178,
#  ('watch', 'time'): 178,
#  ('movie', 'selection'): 178,
#  ('movie', 'grow'): 178,
#  ('family', 'friendly'): 177,
#  ('use', 'mobile'): 177,
#  ('use', 'chromecast'): 177,
#  ('think', 'app'): 177,
#  ('single', 'time'): 177,
#  ('couple', 'day'): 177,
#  ('watch', 'many'): 176,
#  ('home', 'page'): 176,
#  ('brings', 'back'): 176,
#  ('watch', 'go'): 176,
#  ('stop', 'load'): 175,
#  ('app', 'everything'): 175,
#  ('pay', 'disney'): 175,
#  ('spider', 'man'): 175,
#  ('lot', 'show'): 175,
#  ('show', 'would'): 175,
#  ('everything', 'work'): 175,
#  ('zero', 'star'): 174,
#  ('hulu', 'espn'): 174,
#  ('movie', 'ca'): 174,
#  ('really', 'bad'): 174,
#  ('issue', 'connect'): 174,
#  ('everyone', 'else'): 173,
#  ('able', 'download'): 173,
#  ('worth', 'every'): 173,
#  ('work', 'disney'): 173,
#  ('blue', 'screen'): 173,
#  ('great', 'quality'): 173,
#  ('love', 'favorite'): 173,
#  ('cant', 'use'): 173,
#  ('roku', 'tv'): 172,
#  ('would', 'get'): 172,
#  ('wo', 'download'): 172,
#  ('want', 'use'): 172,
#  ('spin', 'wheel'): 172,
#  ('little', 'bit'): 172,
#  ('need', 'get'): 172,
#  ('uninstall', 'app'): 171,
#  ('time', 'download'): 171,
#  ('disney', 'stuff'): 171,
#  ('work', 'please'): 171,
#  ('compare', 'netflix'): 171,
#  ('say', 'need'): 171,
#  ('multiple', 'device'): 171,
#  ('want', 'pay'): 171,
#  ('app', 'nothing'): 171,
#  ('anything', 'disney'): 170,
#  ('really', 'really'): 170,
#  ('would', 'star'): 170,
#  ('remember', 'episode'): 170,
#  ('get', 'message'): 169,
#  ('allow', 'watch'): 169,
#  ('code', 'try'): 168,
#  ('overall', 'great'): 168,
#  ('overall', 'good'): 168,
#  ('watch', 'lot'): 168,
#  ('app', 'far'): 168,
#  ('app', 'service'): 167,
#  ('worth', 'price'): 167,
#  ('enjoy', 'movie'): 167,
#  ('childhood', 'show'): 167,
#  ('thing', 'would'): 167,
#  ('marvel', 'show'): 166,
#  ('variety', 'movie'): 166,
#  ('use', 'love'): 166,
#  ('every', 'streaming'): 166,
#  ('play', 'show'): 166,
#  ('movie', 'also'): 166,
#  ('please', 'make'): 166,
#  ('watch', 'favourite'): 166,
#  ('new', 'release'): 166,
#  ('movie', 'phone'): 166,
#  ('cancel', 'culture'): 166,
#  ('spin', 'circle'): 166,
#  ('much', 'money'): 165,
#  ('time', 'use'): 165,
#  ('daughter', 'love'): 165,
#  ('work', 'say'): 165,
#  ('nothing', 'happen'): 165,
#  ('family', 'guy'): 165,
#  ('good', 'service'): 165,
#  ('subscription', 'app'): 165,
#  ('give', 'u'): 164,
#  ('would', 'make'): 164,
#  ('service', 'ever'): 164,
#  ('good', 'streaming'): 164,
#  ('add', 'new'): 164,
#  ('anything', 'phone'): 164,
#  ('tech', 'support'): 164,
#  ('call', 'customer'): 164,
#  ('never', 'open'): 164,
#  ('good', 'like'): 163,
#  ('able', 'access'): 163,
#  ('say', 'disney'): 163,
#  ('monthly', 'subscription'): 163,
#  ('childhood', 'memory'): 163,
#  ('google', 'tv'): 162,
#  ('show', 'get'): 161,
#  ('cool', 'app'): 161,
#  ('good', 'job'): 161,
#  ('subscription', 'ca'): 161,
#  ('delete', 'reinstall'): 161,
#  ('play', 'phone'): 161,
#  ('galaxy', 'note'): 161,
#  ('watch', 'option'): 161,
#  ('disney', 'go'): 160,
#  ('ca', 'login'): 160,
#  ('cast', 'phone'): 160,
#  ('even', 'play'): 159,
#  ('good', 'good'): 159,
#  ('actually', 'watch'): 159,
#  ('say', 'app'): 159,
#  ('marvel', 'disney'): 159,
#  ('good', 'need'): 159,
#  ('movie', 'really'): 159,
#  ('work', 'day'): 159,
#  ('google', 'pixel'): 159,
#  ('want', 'cancel'): 158,
#  ('disney', 'best'): 158,
#  ('app', 'pretty'): 158,
#  ('app', 'useless'): 158,
#  ('love', 'best'): 158,
#  ('show', 'one'): 157,
#  ('disney', 'ca'): 157,
#  ('stop', 'watch'): 157,
#  ('work', 'wo'): 157,
#  ('video', 'quality'): 157,
#  ('great', 'way'): 156,
#  ('uninstalled', 'reinstalled'): 156,
#  ('amazing', 'app'): 156,
#  ('pay', 'extra'): 156,
#  ('constant', 'error'): 156,
#  ('app', 'amazing'): 156,
#  ('work', 'really'): 156,
#  ('vizio', 'tv'): 156,
#  ('bug', 'fix'): 155,
#  ('sd', 'card'): 155,
#  ('great', 'job'): 155,
#  ('keep', 'good'): 155,
#  ('live', 'chat'): 155,
#  ('time', 'time'): 155,
#  ('load', 'forever'): 155,
#  ('love', 'many'): 154,
#  ('disney', 'one'): 154,
#  ('company', 'like'): 154,
#  ('app', 'log'): 154,
#  ('download', 'something'): 154,
#  ('see', 'anything'): 154,
#  ('watch', 'netflix'): 153,
#  ('netflix', 'app'): 153,
#  ('would', 'better'): 153,
#  ('much', 'content'): 153,
#  ('app', 'favorite'): 153,
#  ('need', 'lot'): 153,
#  ('expect', 'disney'): 153,
#  ('star', 'review'): 152,
#  ('star', 'could'): 152,
#  ('would', 'expect'): 152,
#  ('episode', 'button'): 152,
#  ('without', 'buffer'): 151,
#  ('cancel', 'service'): 151,
#  ('different', 'device'): 151,
#  ('app', 'want'): 151,
#  ('take', 'minute'): 151,
#  ('app', 'however'): 151,
#  ('amaze', 'movie'): 151,
#  ('try', 'cast'): 151,
#  ('ca', 'seem'): 151,
#  ('app', 'able'): 151,
#  ('install', 'app'): 151,
#  ('disney', 'please'): 151,
#  ('available', 'region'): 151,
#  ('able', 'see'): 151,
#  ('problem', 'stream'): 150,
#  ('start', 'play'): 150,
#  ('disney', 'really'): 150,
#  ('best', 'disney'): 150,
#  ('something', 'work'): 150,
#  ('always', 'get'): 150,
#  ('work', 'mobile'): 150,
#  ('disney', 'own'): 150,
#  ('hbo', 'max'): 149,
#  ('app', 'garbage'): 149,
#  ('high', 'quality'): 149,
#  ('garbage', 'app'): 149,
#  ('many', 'people'): 149,
#  ('app', 'horrible'): 149,
#  ('something', 'wrong'): 149,
#  ('load', 'try'): 149,
#  ('watch', 'even'): 149,
#  ('help', 'center'): 149,
#  ('many', 'great'): 149,
#  ('get', 'refund'): 148,
#  ('show', 'play'): 148,
#  ('audio', 'video'): 148,
#  ('uninstalled', 'app'): 148,
#  ('one', 'episode'): 148,
#  ('let', 'u'): 148,
#  ('series', 'watch'): 148,
#  ('point', 'pay'): 148,
#  ('phone', 'keep'): 148,
#  ('try', 'reinstall'): 148,
#  ('keep', 'come'): 147,
#  ('movie', 'wo'): 147,
#  ('contact', 'disney'): 147,
#  ('app', 'buffer'): 147,
#  ('many', 'bug'): 147,
#  ('apps', 'like'): 147,
#  ('download', 'phone'): 147,
#  ...}

# %% [markdown]
# ## Exploration of trigrams

# %%
trigrams = [trigram for review in tokenized_reviews for trigram in nltk.trigrams(review)]

# %%
trigrams_counter = Counter(trigrams)

# %%
sorted_trigrams_by_frequency = sorted(trigrams_counter.items(), key=lambda x:x[1], reverse = True)
converted_dict_trigrams = dict(sorted_trigrams_by_frequency)

# %%
converted_dict_trigrams
# Out:
# {('love', 'disney', 'plus'): 1131,
#  ('movie', 'tv', 'show'): 983,
#  ('best', 'app', 'ever'): 922,
#  ('get', 'error', 'code'): 730,
#  ('marvel', 'star', 'war'): 627,
#  ('keep', 'get', 'error'): 614,
#  ('ca', 'watch', 'anything'): 572,
#  ('star', 'war', 'marvel'): 470,
#  ('something', 'go', 'wrong'): 424,
#  ('take', 'forever', 'load'): 422,
#  ('love', 'disney', 'movie'): 421,
#  ('watch', 'disney', 'movie'): 415,
#  ('love', 'love', 'love'): 414,
#  ('every', 'time', 'try'): 390,
#  ('continue', 'watch', 'section'): 384,
#  ('app', 'work', 'fine'): 378,
#  ('ca', 'even', 'get'): 372,
#  ('get', 'error', 'message'): 363,
#  ('app', 'work', 'great'): 349,
#  ('best', 'thing', 'ever'): 344,
#  ('say', 'unable', 'connect'): 341,
#  ('app', 'stop', 'work'): 326,
#  ('try', 'watch', 'something'): 322,
#  ('app', 'wo', 'load'): 313,
#  ('disney', 'movie', 'show'): 309,
#  ('ca', 'even', 'watch'): 300,
#  ('give', 'error', 'code'): 298,
#  ('really', 'good', 'app'): 297,
#  ('disney', 'plus', 'app'): 293,
#  ('would', 'give', 'star'): 292,
#  ('favorite', 'disney', 'movie'): 291,
#  ('star', 'war', 'movie'): 291,
#  ('watch', 'favorite', 'movie'): 281,
#  ('app', 'wo', 'open'): 276,
#  ('love', 'app', 'much'): 272,
#  ('wo', 'even', 'load'): 268,
#  ('app', 'wo', 'even'): 267,
#  ('bad', 'app', 'ever'): 257,
#  ('since', 'last', 'update'): 257,
#  ('watch', 'movie', 'show'): 253,
#  ('play', 'next', 'episode'): 250,
#  ('watch', 'disney', 'plus'): 248,
#  ('app', 'work', 'well'): 246,
#  ('tv', 'show', 'movie'): 245,
#  ('watch', 'star', 'war'): 242,
#  ('best', 'stream', 'service'): 242,
#  ('great', 'app', 'love'): 237,
#  ('disney', 'show', 'movie'): 235,
#  ('wo', 'even', 'open'): 233,
#  ('ca', 'even', 'use'): 226,
#  ('watch', 'favorite', 'disney'): 220,
#  ('try', 'watch', 'movie'): 220,
#  ('love', 'star', 'war'): 219,
#  ('old', 'disney', 'movie'): 216,
#  ('app', 'never', 'work'): 215,
#  ('buffer', 'every', 'second'): 212,
#  ('able', 'watch', 'anything'): 212,
#  ('watch', 'favorite', 'show'): 207,
#  ('please', 'fix', 'issue'): 206,
#  ('netflix', 'amazon', 'prime'): 204,
#  ('watch', 'show', 'movie'): 201,
#  ('get', 'app', 'work'): 201,
#  ('disney', 'plus', 'great'): 200,
#  ('love', 'watch', 'disney'): 199,
#  ('stuck', 'load', 'screen'): 195,
#  ('screen', 'go', 'black'): 191,
#  ('absolutely', 'love', 'app'): 191,
#  ('time', 'try', 'watch'): 187,
#  ('ca', 'get', 'app'): 187,
#  ('wo', 'let', 'watch'): 182,
#  ('even', 'open', 'app'): 182,
#  ('let', 'watch', 'anything'): 182,
#  ('apps', 'work', 'fine'): 182,
#  ('ca', 'even', 'log'): 181,
#  ('past', 'loading', 'screen'): 181,
#  ('would', 'like', 'see'): 180,
#  ('get', 'black', 'screen'): 179,
#  ('app', 'work', 'phone'): 179,
#  ('great', 'show', 'movie'): 178,
#  ('every', 'disney', 'movie'): 177,
#  ('work', 'perfectly', 'fine'): 176,
#  ('star', 'war', 'fan'): 174,
#  ('app', 'easy', 'use'): 173,
#  ('love', 'watch', 'movie'): 172,
#  ('wan', 'na', 'watch'): 171,
#  ('great', 'movie', 'show'): 169,
#  ('app', 'wo', 'work'): 169,
#  ('fire', 'gina', 'carano'): 169,
#  ('every', 'single', 'time'): 168,
#  ('favorite', 'show', 'movie'): 168,
#  ('love', 'app', 'watch'): 167,
#  ('watch', 'download', 'content'): 166,
#  ('ca', 'even', 'open'): 166,
#  ('please', 'try', 'later'): 166,
#  ('get', 'disney', 'plus'): 165,
#  ('billion', 'dollar', 'company'): 163,
#  ('favorite', 'movie', 'show'): 163,
#  ('stick', 'load', 'screen'): 163,
#  ('like', 'disney', 'plus'): 162,
#  ('love', 'disney', 'app'): 160,
#  ('app', 'watch', 'movie'): 159,
#  ('continue', 'watch', 'list'): 159,
#  ('work', 'half', 'time'): 158,
#  ('say', 'error', 'code'): 158,
#  ('love', 'able', 'watch'): 158,
#  ('really', 'like', 'app'): 157,
#  ('pay', 'something', 'ca'): 156,
#  ('try', 'open', 'app'): 154,
#  ('even', 'get', 'app'): 154,
#  ('keep', 'say', 'error'): 154,
#  ('get', 'past', 'loading'): 154,
#  ('ca', 'open', 'app'): 153,
#  ('error', 'code', 'try'): 153,
#  ('app', 'keep', 'crash'): 153,
#  ('cant', 'watch', 'anything'): 153,
#  ('stream', 'apps', 'work'): 151,
#  ('take', 'long', 'time'): 150,
#  ('give', 'five', 'star'): 148,
#  ('connect', 'disney', 'plus'): 148,
#  ('movie', 'want', 'watch'): 147,
#  ('great', 'app', 'watch'): 147,
#  ('continue', 'watch', 'feature'): 146,
#  ('app', 'use', 'work'): 144,
#  ('unable', 'connect', 'disney'): 144,
#  ('keep', 'give', 'error'): 143,
#  ('app', 'longer', 'work'): 143,
#  ('ca', 'use', 'app'): 141,
#  ('worst', 'stream', 'app'): 140,
#  ('content', 'great', 'app'): 140,
#  ('great', 'app', 'great'): 140,
#  ('keep', 'good', 'work'): 138,
#  ('want', 'watch', 'something'): 138,
#  ('wo', 'let', 'log'): 137,
#  ('day', 'free', 'trial'): 137,
#  ('wo', 'even', 'let'): 136,
#  ('say', 'ca', 'connect'): 136,
#  ('take', 'long', 'load'): 136,
#  ('call', 'customer', 'service'): 135,
#  ('use', 'work', 'fine'): 135,
#  ('able', 'use', 'app'): 134,
#  ('say', 'something', 'go'): 134,
#  ('disney', 'pixar', 'marvel'): 133,
#  ('app', 'ever', 'use'): 133,
#  ('time', 'open', 'app'): 132,
#  ('need', 'continue', 'watch'): 131,
#  ('use', 'disney', 'plus'): 130,
#  ('buffer', 'every', 'minute'): 130,
#  ('give', 'error', 'message'): 130,
#  ('ca', 'watch', 'movie'): 130,
#  ('app', 'wo', 'let'): 129,
#  ('please', 'fix', 'app'): 129,
#  ('get', 'watch', 'favorite'): 129,
#  ('want', 'watch', 'movie'): 128,
#  ('next', 'episode', 'button'): 128,
#  ('samsung', 'smart', 'tv'): 128,
#  ('stream', 'app', 'ever'): 127,
#  ('love', 'movie', 'show'): 127,
#  ('work', 'android', 'phone'): 127,
#  ('every', 'time', 'open'): 126,
#  ('worth', 'every', 'penny'): 126,
#  ('uninstall', 'reinstall', 'app'): 125,
#  ('ca', 'get', 'past'): 125,
#  ('infinite', 'load', 'screen'): 122,
#  ('company', 'like', 'disney'): 122,
#  ('good', 'show', 'movie'): 122,
#  ('stay', 'load', 'screen'): 122,
#  ('work', 'please', 'fix'): 122,
#  ('try', 'watch', 'anything'): 121,
#  ('want', 'money', 'back'): 121,
#  ('show', 'black', 'screen'): 121,
#  ('past', 'load', 'screen'): 121,
#  ('app', 'work', 'perfectly'): 120,
#  ('love', 'watch', 'old'): 120,
#  ('bad', 'stream', 'app'): 118,
#  ('able', 'watch', 'movie'): 118,
#  ('show', 'movie', 'watch'): 118,
#  ('movie', 'one', 'place'): 118,
#  ('love', 'content', 'app'): 117,
#  ('continue', 'watch', 'option'): 117,
#  ('show', 'want', 'watch'): 116,
#  ('watch', 'old', 'disney'): 116,
#  ('watch', 'anything', 'app'): 116,
#  ('movie', 'show', 'watch'): 116,
#  ('like', 'star', 'war'): 115,
#  ('everytime', 'try', 'watch'): 114,
#  ('watch', 'tv', 'show'): 114,
#  ('love', 'app', 'love'): 114,
#  ('disney', 'plus', 'best'): 113,
#  ('even', 'watch', 'anything'): 113,
#  ('would', 'love', 'see'): 113,
#  ('watch', 'marvel', 'movie'): 113,
#  ('great', 'selection', 'movie'): 113,
#  ('love', 'app', 'great'): 113,
#  ('star', 'war', 'content'): 111,
#  ('use', 'app', 'phone'): 111,
#  ('classic', 'disney', 'movie'): 111,
#  ('good', 'movie', 'show'): 111,
#  ('disney', 'plus', 'amazing'): 111,
#  ('bring', 'back', 'childhood'): 111,
#  ('watch', 'movie', 'tv'): 110,
#  ('great', 'stream', 'service'): 109,
#  ('say', 'internet', 'connection'): 109,
#  ('work', 'fine', 'phone'): 109,
#  ('absolutely', 'love', 'disney'): 107,
#  ('every', 'streaming', 'service'): 107,
#  ('app', 'need', 'work'): 107,
#  ('every', 'time', 'want'): 106,
#  ('go', 'next', 'episode'): 106,
#  ('disney', 'plus', 'good'): 106,
#  ('selection', 'movie', 'show'): 106,
#  ('go', 'wrong', 'please'): 105,
#  ('best', 'stream', 'app'): 103,
#  ('app', 'ca', 'even'): 103,
#  ('really', 'love', 'app'): 103,
#  ('open', 'app', 'phone'): 102,
#  ('pay', 'service', 'ca'): 102,
#  ('wish', 'continue', 'watch'): 101,
#  ('disney', 'movie', 'tv'): 101,
#  ('watch', 'old', 'movie'): 101,
#  ('add', 'continue', 'watch'): 101,
#  ('download', 'movie', 'watch'): 100,
#  ('love', 'show', 'movie'): 100,
#  ('uninstalled', 'reinstall', 'app'): 99,
#  ('lot', 'good', 'movie'): 99,
#  ('wrong', 'please', 'try'): 99,
#  ('app', 'still', 'work'): 99,
#  ('movie', 'tv', 'series'): 98,
#  ('try', 'cancel', 'subscription'): 98,
#  ('uninstalled', 'reinstall', 'still'): 98,
#  ('disney', 'channel', 'show'): 97,
#  ('get', 'fix', 'soon'): 97,
#  ('stream', 'service', 'ever'): 97,
#  ('skip', 'next', 'episode'): 97,
#  ('movie', 'star', 'war'): 97,
#  ('work', 'fine', 'tv'): 97,
#  ('great', 'content', 'app'): 97,
#  ('still', 'wo', 'work'): 96,
#  ('could', 'give', 'star'): 96,
#  ('good', 'app', 'watch'): 96,
#  ('without', 'internet', 'connection'): 96,
#  ('contact', 'customer', 'service'): 96,
#  ('netflix', 'prime', 'video'): 95,
#  ('huge', 'disney', 'fan'): 95,
#  ('multi', 'billion', 'dollar'): 95,
#  ('app', 'work', 'android'): 95,
#  ('watch', 'disney', 'show'): 95,
#  ('great', 'app', 'work'): 95,
#  ('please', 'fix', 'problem'): 94,
#  ('pretty', 'good', 'app'): 94,
#  ('one', 'best', 'apps'): 93,
#  ('try', 'use', 'app'): 93,
#  ('get', 'stuck', 'load'): 93,
#  ('really', 'enjoy', 'app'): 93,
#  ('app', 'great', 'content'): 93,
#  ('give', 'app', 'star'): 93,
#  ('app', 'love', 'disney'): 93,
#  ('black', 'screen', 'audio'): 93,
#  ('cant', 'even', 'watch'): 93,
#  ('love', 'watch', 'favorite'): 92,
#  ('service', 'work', 'fine'): 92,
#  ('app', 'never', 'load'): 92,
#  ('favorite', 'disney', 'show'): 92,
#  ('show', 'use', 'watch'): 92,
#  ('wo', 'play', 'anything'): 92,
#  ('app', 'doesnt', 'work'): 91,
#  ('waste', 'time', 'money'): 91,
#  ('love', 'get', 'watch'): 91,
#  ('watch', 'anything', 'phone'): 91,
#  ('keep', 'say', 'unable'): 91,
#  ('old', 'disney', 'show'): 90,
#  ('stream', 'service', 'work'): 90,
#  ('long', 'time', 'load'): 90,
#  ('app', 'work', 'properly'): 90,
#  ('new', 'disney', 'movie'): 89,
#  ('hope', 'get', 'fix'): 89,
#  ('really', 'great', 'app'): 89,
#  ('please', 'fix', 'bug'): 88,
#  ('give', 'one', 'star'): 88,
#  ('good', 'streaming', 'service'): 88,
#  ('need', 'lot', 'work'): 88,
#  ('wo', 'let', 'sign'): 88,
#  ('try', 'uninstalling', 'reinstall'): 88,
#  ('clear', 'cache', 'data'): 88,
#  ('best', 'app', 'watch'): 88,
#  ('download', 'movie', 'show'): 87,
#  ('please', 'fix', 'asap'): 87,
#  ('app', 'really', 'good'): 87,
#  ('able', 'watch', 'disney'): 87,
#  ('ca', 'watch', 'download'): 87,
#  ('watch', 'anything', 'without'): 86,
#  ('time', 'want', 'watch'): 86,
#  ('samsung', 'galaxy', 'tab'): 86,
#  ('love', 'disney', 'love'): 86,
#  ('disney', 'star', 'war'): 86,
#  ('phone', 'smart', 'tv'): 86,
#  ('get', 'app', 'open'): 86,
#  ('cant', 'even', 'get'): 86,
#  ('falcon', 'winter', 'soldier'): 85,
#  ('disney', 'plus', 'work'): 85,
#  ('disney', 'plus', 'watch'): 84,
#  ('pixar', 'marvel', 'star'): 84,
#  ('google', 'play', 'store'): 84,
#  ('watch', 'one', 'movie'): 84,
#  ('overall', 'great', 'app'): 84,
#  ('work', 'samsung', 'galaxy'): 84,
#  ('matter', 'many', 'time'): 84,
#  ('work', 'android', 'device'): 84,
#  ('load', 'load', 'load'): 84,
#  ('app', 'keep', 'say'): 84,
#  ('error', 'message', 'say'): 84,
#  ('smart', 'tv', 'app'): 83,
#  ('star', 'war', 'national'): 83,
#  ('movie', 'disney', 'plus'): 83,
#  ('work', 'great', 'phone'): 83,
#  ('watch', 'new', 'movie'): 83,
#  ('pay', 'something', 'work'): 82,
#  ('many', 'show', 'movie'): 82,
#  ('give', 'zero', 'star'): 81,
#  ('app', 'watch', 'favorite'): 81,
#  ('app', 'watch', 'disney'): 81,
#  ('app', 'great', 'movie'): 81,
#  ('even', 'use', 'app'): 81,
#  ('disney', 'movie', 'love'): 81,
#  ('really', 'good', 'movie'): 80,
#  ('use', 'mobile', 'data'): 80,
#  ('phone', 'work', 'fine'): 80,
#  ('app', 'please', 'fix'): 80,
#  ('best', 'movie', 'app'): 80,
#  ('something', 'ca', 'use'): 80,
#  ('great', 'streaming', 'service'): 80,
#  ('love', 'everything', 'disney'): 80,
#  ('always', 'love', 'disney'): 79,
#  ('app', 'even', 'work'): 79,
#  ('picture', 'picture', 'mode'): 79,
#  ('everything', 'else', 'work'): 79,
#  ('every', 'time', 'go'): 79,
#  ('app', 'multiple', 'time'): 79,
#  ('best', 'streaming', 'app'): 79,
#  ('great', 'app', 'kid'): 78,
#  ('whole', 'family', 'love'): 78,
#  ('content', 'good', 'app'): 78,
#  ('app', 'take', 'forever'): 78,
#  ('star', 'war', 'disney'): 78,
#  ('feel', 'like', 'kid'): 78,
#  ('love', 'app', 'favorite'): 78,
#  ('like', 'watch', 'movie'): 77,
#  ('wish', 'could', 'give'): 77,
#  ('well', 'worth', 'money'): 77,
#  ('time', 'try', 'use'): 77,
#  ('update', 'payment', 'method'): 77,
#  ('get', 'app', 'load'): 77,
#  ('reason', 'give', 'star'): 77,
#  ('disney', 'plus', 'get'): 77,
#  ('try', 'watch', 'show'): 77,
#  ('wo', 'load', 'phone'): 77,
#  ('movie', 'show', 'love'): 77,
#  ('netflix', 'work', 'fine'): 77,
#  ('apps', 'like', 'netflix'): 76,
#  ('love', 'app', 'get'): 76,
#  ('app', 'even', 'open'): 76,
#  ('ca', 'wait', 'see'): 76,
#  ('uninstalling', 'reinstall', 'app'): 76,
#  ('disney', 'marvel', 'star'): 76,
#  ('use', 'work', 'great'): 75,
#  ('go', 'cancel', 'subscription'): 75,
#  ('disney', 'plus', 'really'): 75,
#  ('get', 'money', 'back'): 75,
#  ('reinstall', 'several', 'time'): 75,
#  ('vizio', 'smart', 'tv'): 75,
#  ('war', 'national', 'geographic'): 74,
#  ('download', 'watch', 'offline'): 74,
#  ('service', 'ca', 'use'): 74,
#  ('app', 'restart', 'phone'): 74,
#  ('great', 'app', 'lot'): 74,
#  ('screen', 'turn', 'black'): 74,
#  ('ca', 'download', 'anything'): 73,
#  ('pixar', 'star', 'war'): 73,
#  ('great', 'app', 'disney'): 73,
#  ('constantly', 'get', 'error'): 73,
#  ('give', 'star', 'would'): 73,
#  ('watch', 'download', 'movie'): 72,
#  ('star', 'war', 'show'): 72,
#  ('app', 'smart', 'tv'): 72,
#  ('new', 'movie', 'come'): 72,
#  ('love', 'app', 'work'): 72,
#  ('load', 'screen', 'try'): 72,
#  ('app', 'several', 'time'): 72,
#  ('kid', 'love', 'app'): 71,
#  ('able', 'watch', 'show'): 71,
#  ('amaze', 'app', 'love'): 71,
#  ('new', 'show', 'movie'): 71,
#  ('app', 'wont', 'load'): 71,
#  ('app', 'keep', 'freeze'): 70,
#  ('love', 'love', 'disney'): 70,
#  ('app', 'work', 'samsung'): 70,
#  ('really', 'want', 'watch'): 70,
#  ('dream', 'come', 'true'): 70,
#  ('work', 'smart', 'tv'): 70,
#  ('new', 'movie', 'show'): 70,
#  ('auto', 'play', 'next'): 70,
#  ('let', 'watch', 'movie'): 70,
#  ('get', 'unable', 'connect'): 70,
#  ('delete', 'app', 'reinstall'): 69,
#  ('watch', 'old', 'show'): 69,
#  ('always', 'get', 'error'): 69,
#  ('ca', 'get', 'work'): 69,
#  ('disney', 'movie', 'one'): 69,
#  ('since', 'late', 'update'): 69,
#  ('make', 'app', 'work'): 69,
#  ('high', 'school', 'musical'): 69,
#  ('take', 'money', 'account'): 68,
#  ('try', 'play', 'movie'): 68,
#  ('issue', 'stream', 'service'): 68,
#  ('error', 'code', 'ca'): 68,
#  ('even', 'let', 'log'): 68,
#  ('reinstall', 'multiple', 'time'): 68,
#  ('great', 'stream', 'app'): 68,
#  ('show', 'disney', 'plus'): 68,
#  ('wo', 'let', 'download'): 67,
#  ('like', 'netflix', 'hulu'): 67,
#  ('stop', 'work', 'phone'): 67,
#  ('since', 'new', 'update'): 67,
#  ('work', 'really', 'well'): 67,
#  ('app', 'disney', 'movie'): 67,
#  ('ca', 'play', 'anything'): 67,
#  ('many', 'movie', 'show'): 67,
#  ('ca', 'cast', 'tv'): 67,
#  ('old', 'new', 'movie'): 67,
#  ('disney', 'plus', 'much'): 66,
#  ('time', 'try', 'open'): 66,
#  ('wont', 'let', 'watch'): 66,
#  ('need', 'fix', 'asap'): 66,
#  ('new', 'star', 'war'): 66,
#  ('love', 'marvel', 'movie'): 66,
#  ('bring', 'back', 'memory'): 66,
#  ('lot', 'great', 'movie'): 66,
#  ('wake', 'go', 'broke'): 65,
#  ('pay', 'disney', 'plus'): 65,
#  ('take', 'age', 'load'): 65,
#  ('able', 'open', 'app'): 65,
#  ('best', 'streaming', 'service'): 65,
#  ('one', 'best', 'streaming'): 65,
#  ('family', 'movie', 'night'): 65,
#  ('great', 'app', 'need'): 65,
#  ('good', 'app', 'love'): 65,
#  ('movie', 'wo', 'play'): 64,
#  ('pay', 'every', 'month'): 64,
#  ('get', 'watch', 'movie'): 64,
#  ('download', 'content', 'offline'): 64,
#  ('please', 'please', 'please'): 64,
#  ('star', 'war', 'stuff'): 63,
#  ('kid', 'love', 'disney'): 63,
#  ('go', 'back', 'netflix'): 63,
#  ('app', 'work', 'anymore'): 63,
#  ('app', 'let', 'watch'): 63,
#  ('ca', 'watch', 'show'): 63,
#  ('want', 'watch', 'show'): 63,
#  ('watch', 'movie', 'phone'): 63,
#  ('amazon', 'prime', 'video'): 63,
#  ('need', 'fix', 'app'): 63,
#  ('app', 'every', 'time'): 63,
#  ('stuck', 'loading', 'screen'): 63,
#  ('use', 'watch', 'kid'): 63,
#  ('overall', 'good', 'app'): 62,
#  ('app', 'kid', 'love'): 62,
#  ('disney', 'please', 'fix'): 62,
#  ('love', 'app', 'disney'): 62,
#  ('get', 'anything', 'play'): 62,
#  ('ca', 'watch', 'phone'): 62,
#  ('selection', 'show', 'movie'): 62,
#  ('go', 'wake', 'go'): 61,
#  ('tv', 'show', 'watch'): 61,
#  ('app', 'keep', 'buffer'): 61,
#  ('app', 'love', 'watch'): 61,
#  ('watch', 'movie', 'without'): 61,
#  ('would', 'give', 'five'): 61,
#  ('streaming', 'service', 'work'): 61,
#  ('app', 'watch', 'show'): 61,
#  ('download', 'show', 'watch'): 61,
#  ('unable', 'watch', 'anything'): 61,
#  ('check', 'internet', 'connection'): 61,
#  ('great', 'movie', 'tv'): 61,
#  ('love', 'app', 'best'): 61,
#  ('wo', 'open', 'phone'): 61,
#  ('pay', 'year', 'subscription'): 61,
#  ('old', 'tv', 'show'): 61,
#  ('love', 'old', 'disney'): 60,
#  ('favorite', 'tv', 'show'): 60,
#  ('love', 'app', 'wish'): 60,
#  ('great', 'whole', 'family'): 60,
#  ('download', 'show', 'movie'): 60,
#  ('love', 'disney', 'channel'): 60,
#  ('easy', 'use', 'great'): 60,
#  ('love', 'favorite', 'movie'): 60,
#  ('app', 'wont', 'even'): 60,
#  ('way', 'well', 'netflix'): 60,
#  ('disney', 'plus', 'awesome'): 60,
#  ('love', 'love', 'app'): 60,
#  ('every', 'time', 'watch'): 59,
#  ('error', 'code', 'every'): 59,
#  ('ca', 'even', 'download'): 59,
#  ('lot', 'show', 'movie'): 59,
#  ('star', 'war', 'clone'): 59,
#  ('show', 'movie', 'like'): 59,
#  ('app', 'actually', 'work'): 59,
#  ('whenever', 'try', 'watch'): 59,
#  ('favorite', 'movie', 'tv'): 59,
#  ('app', 'even', 'load'): 59,
#  ('show', 'movie', 'love'): 59,
#  ('reinstall', 'still', 'work'): 59,
#  ('old', 'show', 'movie'): 59,
#  ('seem', 'issue', 'connect'): 59,
#  ('app', 'open', 'phone'): 59,
#  ('hope', 'fix', 'soon'): 59,
#  ('continue', 'watch', 'tab'): 59,
#  ('best', 'movie', 'ever'): 59,
#  ('app', 'love', 'movie'): 58,
#  ('war', 'clone', 'war'): 58,
#  ('good', 'app', 'need'): 58,
#  ('cast', 'smart', 'tv'): 58,
#  ('would', 'think', 'would'): 58,
#  ('really', 'enjoy', 'watch'): 58,
#  ('cancel', 'disney', 'plus'): 58,
#  ('show', 'error', 'code'): 58,
#  ('selection', 'movie', 'tv'): 58,
#  ('go', 'black', 'screen'): 58,
#  ('even', 'get', 'past'): 58,
#  ('wo', 'load', 'anything'): 57,
#  ('wo', 'work', 'phone'): 57,
#  ('even', 'watch', 'movie'): 57,
#  ('work', 'samsung', 'tablet'): 57,
#  ('watch', 'movie', 'series'): 57,
#  ('screen', 'please', 'fix'): 57,
#  ('would', 'like', 'watch'): 57,
#  ('app', 'get', 'watch'): 57,
#  ('love', 'app', 'lot'): 57,
#  ('delete', 'reinstall', 'app'): 57,
#  ('open', 'app', 'say'): 57,
#  ('get', 'error', 'try'): 57,
#  ('say', 'try', 'later'): 57,
#  ('ca', 'see', 'anything'): 57,
#  ('great', 'app', 'would'): 57,
#  ('disney', 'movie', 'app'): 57,
#  ('keep', 'track', 'episode'): 57,
#  ('play', 'movie', 'show'): 56,
#  ('great', 'way', 'watch'): 56,
#  ('variety', 'show', 'movie'): 56,
#  ('good', 'job', 'disney'): 56,
#  ('good', 'content', 'app'): 56,
#  ('pay', 'subscription', 'ca'): 56,
#  ('love', 'disney', 'show'): 56,
#  ('movie', 'show', 'disney'): 56,
#  ('open', 'app', 'get'): 56,
#  ('app', 'keep', 'load'): 56,
#  ('everything', 'want', 'watch'): 56,
#  ('love', 'app', 'many'): 56,
#  ('love', 'kid', 'love'): 56,
#  ('play', 'download', 'content'): 55,
#  ('enjoy', 'disney', 'plus'): 55,
#  ('need', 'internet', 'connection'): 55,
#  ('almost', 'every', 'time'): 55,
#  ('like', 'disney', 'movie'): 55,
#  ('disney', 'movie', 'want'): 55,
#  ('stream', 'service', 'use'): 55,
#  ('tv', 'work', 'fine'): 55,
#  ('movie', 'show', 'app'): 55,
#  ('update', 'app', 'work'): 55,
#  ('watch', 'download', 'show'): 55,
#  ('want', 'watch', 'disney'): 55,
#  ('show', 'continue', 'watch'): 55,
#  ('love', 'disney', 'much'): 55,
#  ('movie', 'bring', 'back'): 55,
#  ('cant', 'even', 'log'): 55,
#  ('great', 'app', 'easy'): 55,
#  ('wont', 'even', 'load'): 55,
#  ('watch', 'movie', 'want'): 54,
#  ('stream', 'app', 'use'): 54,
#  ('unable', 'open', 'app'): 54,
#  ('disney', 'need', 'fix'): 54,
#  ('get', 'act', 'together'): 54,
#  ('app', 'stream', 'service'): 54,
#  ('pay', 'service', 'work'): 54,
#  ('worst', 'stream', 'service'): 54,
#  ('get', 'message', 'say'): 54,
#  ('watch', 'movie', 'like'): 54,
#  ('update', 'app', 'still'): 54,
#  ('connect', 'try', 'later'): 54,
#  ('video', 'wo', 'play'): 54,
#  ('sorry', 'something', 'go'): 54,
#  ('love', 'app', 'movie'): 54,
#  ('disney', 'movie', 'like'): 54,
#  ('get', 'watch', 'disney'): 54,
#  ('cant', 'get', 'app'): 54,
#  ('marvel', 'national', 'geographic'): 54,
#  ('disney', 'plus', 'like'): 53,
#  ('get', 'together', 'disney'): 53,
#  ('suddenly', 'stop', 'work'): 53,
#  ('great', 'disney', 'movie'): 53,
#  ('big', 'disney', 'fan'): 53,
#  ('something', 'ca', 'even'): 53,
#  ('app', 'constantly', 'crash'): 53,
#  ('able', 'get', 'app'): 53,
#  ('high', 'speed', 'internet'): 53,
#  ('cast', 'phone', 'tv'): 53,
#  ('ca', 'get', 'enough'): 53,
#  ('let', 'cancel', 'subscription'): 53,
#  ('ca', 'even', 'access'): 53,
#  ('samsung', 'galaxy', 'note'): 53,
#  ('black', 'screen', 'try'): 53,
#  ('many', 'great', 'movie'): 53,
#  ('really', 'like', 'disney'): 53,
#  ('get', 'new', 'phone'): 53,
#  ('every', 'time', 'use'): 53,
#  ('movie', 'try', 'watch'): 53,
#  ('get', 'past', 'load'): 53,
#  ('old', 'new', 'disney'): 53,
#  ('never', 'work', 'phone'): 53,
#  ('make', 'feel', 'like'): 53,
#  ('available', 'chromecast', 'device'): 53,
#  ('app', 'clear', 'cache'): 52,
#  ('enjoy', 'watch', 'movie'): 52,
#  ('still', 'ca', 'get'): 52,
#  ('want', 'cancel', 'subscription'): 52,
#  ('watch', 'anything', 'disney'): 52,
#  ('great', 'app', 'good'): 52,
#  ('cant', 'even', 'use'): 52,
#  ('even', 'download', 'movie'): 52,
#  ('amazon', 'fire', 'stick'): 52,
#  ('app', 'get', 'stuck'): 52,
#  ('ca', 'even', 'login'): 52,
#  ('log', 'log', 'back'): 52,
#  ('watch', 'old', 'new'): 52,
#  ('blah', 'blah', 'blah'): 52,
#  ('wont', 'even', 'let'): 52,
#  ('movie', 'show', 'great'): 52,
#  ('great', 'app', 'wish'): 52,
#  ('show', 'watch', 'kid'): 52,
#  ('spider', 'man', 'movie'): 51,
#  ('say', 'disney', 'plus'): 51,
#  ('stop', 'work', 'android'): 51,
#  ('stream', 'service', 'app'): 51,
#  ('app', 'need', 'fix'): 51,
#  ('star', 'war', 'pixar'): 51,
#  ('able', 'watch', 'favorite'): 51,
#  ('easy', 'use', 'app'): 51,
#  ('disney', 'plus', 'phone'): 51,
#  ('good', 'selection', 'movie'): 51,
#  ('wifi', 'mobile', 'data'): 51,
#  ('work', 'fine', 'first'): 51,
#  ('get', 'stuck', 'loading'): 51,
#  ('family', 'love', 'disney'): 51,
#  ('last', 'update', 'app'): 51,
#  ('good', 'app', 'work'): 51,
#  ('fun', 'watch', 'movie'): 51,
#  ('love', 'old', 'movie'): 51,
#  ('one', 'best', 'stream'): 50,
#  ('app', 'phone', 'work'): 50,
#  ('app', 'work', 'time'): 50,
#  ('good', 'app', 'lot'): 50,
#  ('try', 'watch', 'download'): 50,
#  ('show', 'movie', 'app'): 50,
#  ('app', 'great', 'show'): 50,
#  ('say', 'available', 'region'): 50,
#  ('really', 'look', 'forward'): 50,
#  ('please', 'fix', 'disney'): 50,
#  ('watch', 'anything', 'keep'): 50,
#  ('love', 'app', 'kid'): 50,
#  ('try', 'restart', 'phone'): 50,
#  ('go', 'back', 'watch'): 50,
#  ('pay', 'monthly', 'subscription'): 50,
#  ('old', 'movie', 'show'): 50,
#  ('movie', 'app', 'ever'): 49,
#  ('app', 'android', 'phone'): 49,
#  ('take', 'forever', 'download'): 49,
#  ('star', 'war', 'series'): 49,
#  ('reinstall', 'app', 'still'): 49,
#  ('love', 'marvel', 'star'): 49,
#  ('app', 'wont', 'open'): 49,
#  ('time', 'still', 'work'): 49,
#  ('error', 'message', 'try'): 49,
#  ('even', 'download', 'app'): 49,
#  ('work', 'keep', 'say'): 49,
#  ('ca', 'even', 'load'): 49,
#  ('love', 'app', 'amaze'): 49,
#  ('never', 'work', 'always'): 49,
#  ('app', 'need', 'lot'): 49,
#  ('movie', 'show', 'want'): 49,
#  ('app', 'bring', 'back'): 49,
#  ('ca', 'cancel', 'subscription'): 49,
#  ('work', 'fine', 'app'): 49,
#  ('give', 'star', 'rating'): 49,
#  ('issue', 'connect', 'service'): 49,
#  ('lot', 'movie', 'show'): 49,
#  ('app', 'constantly', 'buffer'): 48,
#  ('without', 'buffer', 'every'): 48,
#  ('app', 'work', 'keep'): 48,
#  ('still', 'take', 'money'): 48,
#  ('bad', 'stream', 'service'): 48,
#  ('really', 'need', 'fix'): 48,
#  ('family', 'love', 'app'): 48,
#  ('great', 'app', 'use'): 48,
#  ('like', 'netflix', 'prime'): 48,
#  ('almost', 'every', 'disney'): 48,
#  ('app', 'could', 'use'): 48,
#  ('look', 'forward', 'watch'): 48,
#  ('watch', 'anything', 'want'): 48,
#  ('like', 'netflix', 'youtube'): 48,
#  ('watch', 'movie', 'disney'): 48,
#  ('whole', 'family', 'enjoy'): 48,
#  ('wont', 'even', 'open'): 48,
#  ('wont', 'let', 'log'): 48,
#  ('would', 'definitely', 'recommend'): 48,
#  ('good', 'app', 'good'): 48,
#  ('give', 'star', 'could'): 48,
#  ('try', 'uninstall', 'reinstall'): 48,
#  ('hardly', 'ever', 'work'): 48,
#  ('movie', 'show', 'like'): 48,
#  ('disney', 'movie', 'disney'): 48,
#  ('many', 'thing', 'watch'): 47,
#  ('great', 'watch', 'movie'): 47,
#  ('start', 'next', 'episode'): 47,
#  ('every', 'streaming', 'app'): 47,
#  ('variety', 'movie', 'show'): 47,
#  ('tv', 'show', 'like'): 47,
#  ('disney', 'app', 'work'): 47,
#  ('app', 'ca', 'watch'): 47,
#  ('app', 'work', 'good'): 47,
#  ('work', 'fine', 'disney'): 47,
#  ('try', 'clear', 'cache'): 47,
#  ('love', 'app', 'would'): 47,
#  ('watch', 'anything', 'get'): 47,
#  ('back', 'home', 'screen'): 47,
#  ('would', 'recommend', 'anyone'): 47,
#  ('streaming', 'app', 'ever'): 47,
#  ('download', 'app', 'phone'): 47,
#  ('try', 'play', 'anything'): 47,
#  ('bring', 'back', 'many'): 47,
#  ('see', 'long', 'time'): 47,
#  ('get', 'watch', 'show'): 47,
#  ('like', 'netflix', 'amazon'): 46,
#  ('great', 'job', 'disney'): 46,
#  ('take', 'back', 'childhood'): 46,
#  ('amazing', 'app', 'watch'): 46,
#  ('favorite', 'childhood', 'movie'): 46,
#  ('many', 'good', 'movie'): 46,
#  ('lot', 'good', 'show'): 46,
#  ('error', 'every', 'time'): 46,
#  ('time', 'try', 'play'): 46,
#  ('issue', 'stream', 'apps'): 46,
#  ('kid', 'want', 'watch'): 46,
#  ('update', 'still', 'work'): 46,
#  ('watch', 'many', 'movie'): 46,
#  ('really', 'really', 'really'): 46,
#  ('phone', 'please', 'fix'): 46,
#  ('gon', 'na', 'cancel'): 46,
#  ('movie', 'watch', 'offline'): 46,
#  ('error', 'code', 'say'): 46,
#  ('love', 'app', 'show'): 46,
#  ('app', 'able', 'watch'): 46,
#  ('everytime', 'open', 'app'): 46,
#  ('work', 'error', 'code'): 46,
#  ('wo', 'let', 'cancel'): 46,
#  ('especially', 'star', 'war'): 46,
#  ('error', 'code', 'even'): 46,
#  ('would', 'give', 'app'): 46,
#  ('lot', 'great', 'content'): 46,
#  ('get', 'load', 'screen'): 46,
#  ('work', 'keep', 'get'): 46,
#  ('ca', 'connect', 'disney'): 46,
#  ('good', 'app', 'kid'): 45,
#  ('would', 'give', 'zero'): 45,
#  ('really', 'love', 'disney'): 45,
#  ('let', 'open', 'app'): 45,
#  ('app', 'seem', 'work'): 45,
#  ('seem', 'work', 'fine'): 45,
#  ('ca', 'get', 'anything'): 45,
#  ('app', 'phone', 'tv'): 45,
#  ('try', 'download', 'movie'): 45,
#  ('watch', 'next', 'episode'): 45,
#  ('think', 'disney', 'would'): 45,
#  ('constant', 'error', 'code'): 45,
#  ('get', 'star', 'war'): 45,
#  ('black', 'screen', 'sound'): 45,
#  ('tv', 'app', 'work'): 45,
#  ('app', 'work', 'device'): 45,
#  ('customer', 'service', 'help'): 45,
#  ('keep', 'come', 'error'): 45,
#  ('wo', 'play', 'movie'): 45,
#  ('still', 'need', 'work'): 45,
#  ('open', 'app', 'keep'): 45,
#  ('boy', 'meet', 'world'): 45,
#  ('back', 'many', 'memory'): 45,
#  ('would', 'great', 'app'): 45,
#  ('last', 'episode', 'watch'): 45,
#  ('lg', 'smart', 'tv'): 45,
#  ('episode', 'already', 'watch'): 45,
#  ('service', 'please', 'try'): 45,
#  ('take', 'hour', 'watch'): 44,
#  ('great', 'movie', 'series'): 44,
#  ('picture', 'picture', 'work'): 44,
#  ('would', 'really', 'like'): 44,
#  ('try', 'download', 'app'): 44,
#  ('ca', 'download', 'app'): 44,
#  ('disney', 'movie', 'watch'): 44,
#  ('since', 'day', 'one'): 44,
#  ('movie', 'ca', 'watch'): 44,
#  ('every', 'app', 'work'): 44,
#  ('clear', 'data', 'cache'): 44,
#  ('get', 'blank', 'screen'): 44,
#  ('would', 'think', 'disney'): 44,
#  ('load', 'half', 'time'): 44,
#  ('work', 'great', 'tv'): 44,
#  ('disney', 'plus', 'disney'): 44,
#  ('use', 'love', 'app'): 44,
#  ('sony', 'android', 'tv'): 44,
#  ('work', 'every', 'time'): 44,
#  ('disney', 'plus', 'tv'): 44,
#  ('app', 'crash', 'time'): 44,
#  ('always', 'say', 'error'): 44,
#  ('pay', 'full', 'year'): 44,
#  ('watch', 'downloads', 'offline'): 44,
#  ('many', 'great', 'show'): 44,
#  ('work', 'phone', 'tablet'): 44,
#  ('work', 'wo', 'load'): 44,
#  ('good', 'movie', 'tv'): 44,
#  ('get', 'watch', 'old'): 44,
#  ('wish', 'would', 'add'): 44,
#  ('unable', 'connect', 'service'): 44,
#  ('see', 'disney', 'movie'): 44,
#  ('wo', 'let', 'use'): 44,
#  ('love', 'selection', 'movie'): 44,
#  ('keep', 'get', 'message'): 44,
#  ('disney', 'plus', 'service'): 44,
#  ('app', 'say', 'unable'): 44,
#  ('movie', 'show', 'one'): 43,
#  ('go', 'disney', 'plus'): 43,
#  ('every', 'couple', 'minute'): 43,
#  ('show', 'movie', 'disney'): 43,
#  ('movie', 'series', 'watch'): 43,
#  ('cancel', 'subscription', 'disney'): 43,
#  ('go', 'watch', 'something'): 43,
#  ('watch', 'marvel', 'star'): 43,
#  ('show', 'movie', 'one'): 43,
#  ('android', 'tv', 'box'): 43,
#  ('ca', 'watch', 'offline'): 43,
#  ('content', 'terrible', 'app'): 43,
#  ('watch', 'smart', 'tv'): 43,
#  ('say', 'need', 'update'): 43,
#  ('disney', 'plus', 'love'): 43,
#  ('still', 'get', 'charge'): 43,
#  ('subscription', 'ca', 'even'): 43,
#  ('update', 'payment', 'information'): 43,
#  ('error', 'code', 'app'): 43,
#  ('good', 'internet', 'connection'): 43,
#  ('tried', 'uninstalling', 'reinstall'): 43,
#  ('even', 'though', 'pay'): 43,
#  ('love', 'app', 'really'): 43,
#  ('app', 'load', 'phone'): 43,
#  ('sits', 'load', 'screen'): 43,
#  ('watch', 'movie', 'download'): 43,
#  ('say', 'network', 'error'): 43,
#  ('otherwise', 'great', 'app'): 43,
#  ('get', 'free', 'trial'): 43,
#  ('able', 'watch', 'old'): 43,
#  ('like', 'watch', 'disney'): 43,
#  ('watch', 'every', 'day'): 43,
#  ('love', 'app', 'good'): 43,
#  ('recently', 'watch', 'section'): 43,
#  ('think', 'disney', 'plus'): 42,
#  ('old', 'movie', 'new'): 42,
#  ('love', 'disney', 'watch'): 42,
#  ('love', 'disney', 'great'): 42,
#  ('mickey', 'mouse', 'club'): 42,
#  ('app', 'go', 'back'): 42,
#  ('company', 'big', 'disney'): 42,
#  ('go', 'wrong', 'try'): 42,
#  ('multiple', 'time', 'still'): 42,
#  ('love', 'watch', 'marvel'): 42,
#  ('love', 'app', 'easy'): 42,
#  ('app', 'like', 'netflix'): 42,
#  ('ca', 'use', 'phone'): 42,
#  ('like', 'stream', 'service'): 42,
#  ('well', 'do', 'disney'): 42,
#  ('movie', 'watch', 'kid'): 42,
#  ('go', 'watch', 'movie'): 42,
#  ('come', 'error', 'code'): 42,
#  ('disney', 'pixar', 'movie'): 42,
#  ('work', 'samsung', 'phone'): 42,
#  ('keep', 'say', 'something'): 42,
#  ('fix', 'cancel', 'subscription'): 42,
#  ('watch', 'download', 'video'): 42,
#  ('great', 'selection', 'show'): 42,
#  ('try', 'play', 'video'): 42,
#  ('go', 'past', 'loading'): 42,
#  ('thing', 'want', 'watch'): 42,
#  ('war', 'marvel', 'disney'): 42,
#  ('app', 'pretty', 'good'): 42,
#  ('back', 'childhood', 'memory'): 42,
#  ('watch', 'disney', 'channel'): 42,
#  ('everything', 'work', 'fine'): 42,
#  ('app', 'would', 'work'): 42,
#  ('watch', 'without', 'internet'): 42,
#  ('phone', 'app', 'work'): 41,
#  ('love', 'app', 'everything'): 41,
#  ('ca', 'watch', 'disney'): 41,
#  ('disney', 'pixar', 'star'): 41,
#  ('autoplay', 'next', 'episode'): 41,
#  ('apps', 'work', 'perfectly'): 41,
#  ('subscription', 'google', 'play'): 41,
#  ('get', 'app', 'watch'): 41,
#  ('app', 'wo', 'play'): 41,
#  ('movie', 'old', 'new'): 41,
#  ('great', 'app', 'get'): 41,
#  ('service', 'ca', 'even'): 41,
#  ('since', 'recent', 'update'): 41,
#  ('try', 'uninstalling', 'reinstalling'): 41,
#  ('tv', 'show', 'disney'): 41,
#  ('netflix', 'hulu', 'amazon'): 41,
#  ('lot', 'great', 'show'): 41,
#  ('unable', 'connect', 'try'): 41,
#  ('way', 'watch', 'disney'): 41,
#  ('get', 'spin', 'wheel'): 41,
#  ('work', 'ca', 'even'): 41,
#  ('like', 'netflix', 'disney'): 41,
#  ('uninstall', 'app', 'reinstall'): 41,
#  ('watch', 'favourite', 'disney'): 41,
#  ('keep', 'load', 'load'): 41,
#  ('work', 'phone', 'work'): 41,
#  ('pay', 'watch', 'movie'): 41,
#  ('highly', 'recommend', 'app'): 41,
#  ('movie', 'use', 'watch'): 41,
#  ('ca', 'access', 'app'): 41,
#  ('app', 'watch', 'anything'): 41,
#  ('disney', 'great', 'app'): 41,
#  ('app', 'good', 'movie'): 41,
#  ('app', 'work', 'month'): 40,
#  ('watch', 'one', 'episode'): 40,
#  ('try', 'everything', 'fix'): 40,
#  ('movie', 'love', 'watch'): 40,
#  ('like', 'continue', 'watch'): 40,
#  ('ca', 'connect', 'service'): 40,
#  ('disney', 'plus', 'would'): 40,
#  ('love', 'everything', 'app'): 40,
#  ('pixar', 'national', 'geographic'): 40,
#  ('disney', 'plus', 'lot'): 40,
#  ('film', 'tv', 'show'): 40,
#  ('best', 'show', 'ever'): 40,
#  ('app', 'nothing', 'work'): 40,
#  ('since', 'update', 'app'): 40,
#  ('movie', 'love', 'disney'): 40,
#  ('work', 'phone', 'tv'): 40,
#  ('enjoy', 'watch', 'disney'): 40,
#  ('need', 'new', 'content'): 40,
#  ('available', 'certain', 'region'): 40,
#  ('would', 'love', 'watch'): 40,
#  ('app', 'keep', 'get'): 40,
#  ('wo', 'go', 'past'): 40,
#  ('app', 'work', 'try'): 40,
#  ('work', 'pretty', 'well'): 40,
#  ('app', 'never', 'open'): 40,
#  ('download', 'movie', 'offline'): 40,
#  ('log', 'every', 'time'): 40,
#  ('watch', 'clone', 'war'): 40,
#  ('watch', 'downloaded', 'movie'): 40,
#  ('wo', 'let', 'login'): 40,
#  ('amazing', 'get', 'watch'): 40,
#  ('bring', 'back', 'gina'): 40,
#  ('awesome', 'app', 'love'): 39,
#  ('could', 'give', 'zero'): 39,
#  ('app', 'barely', 'work'): 39,
#  ('see', 'new', 'movie'): 39,
#  ('error', 'code', 'please'): 39,
#  ('want', 'watch', 'phone'): 39,
#  ('samsung', 'galaxy', 'ultra'): 39,
#  ('keep', 'great', 'work'): 39,
#  ('load', 'every', 'second'): 39,
#  ('say', 'something', 'wrong'): 39,
#  ('way', 'watch', 'movie'): 39,
#  ('pay', 'app', 'work'): 39,
#  ('download', 'content', 'watch'): 39,
#  ('reinstall', 'clear', 'cache'): 39,
#  ('continue', 'watch', 'show'): 39,
#  ('app', 'whole', 'family'): 39,
#  ('something', 'ca', 'watch'): 39,
#  ('try', 'cast', 'tv'): 39,
#  ('app', 'give', 'error'): 39,
#  ('disney', 'movie', 'series'): 39,
#  ('marvel', 'movie', 'show'): 39,
#  ('fast', 'forward', 'rewind'): 39,
#  ('kid', 'love', 'watch'): 39,
#  ('work', 'great', 'love'): 39,
#  ('love', 'best', 'app'): 39,
#  ('think', 'cancel', 'subscription'): 39,
#  ('load', 'screen', 'never'): 39,
#  ('app', 'stick', 'load'): 39,
#  ('new', 'old', 'movie'): 39,
#  ('app', 'ca', 'use'): 39,
#  ('movie', 'marvel', 'movie'): 39,
#  ('try', 'get', 'app'): 39,
#  ('pay', 'app', 'ca'): 39,
#  ...}

# %% [markdown]
# ## Visualization of main trigrams

# %% [markdown]
# We find the top 10 trigrams

# %%
top_trigrams = []
counter = 0

for trigram in converted_dict_trigrams:
  top_trigrams.append(trigram)
  counter += 1

  if counter >= 10:   # change if you want a different number of top reviews
    break

top_trigrams
# Out:
# [('love', 'disney', 'plus'),
#  ('movie', 'tv', 'show'),
#  ('best', 'app', 'ever'),
#  ('get', 'error', 'code'),
#  ('marvel', 'star', 'war'),
#  ('keep', 'get', 'error'),
#  ('ca', 'watch', 'anything'),
#  ('star', 'war', 'marvel'),
#  ('something', 'go', 'wrong'),
#  ('take', 'forever', 'load')]

# %% [markdown]
# We add a column with trigrams for each review to the df

# %%
trigrams_for_review = pd.Series([[trigram for trigram in nltk.trigrams(review)] for review in tokenized_reviews])

# %%
trigrams_for_review
# Out:
# 0                                                        []
# 1         [(wonder, software, disney), (software, disney...
# 2                                  [(give, month, premium)]
# 3                                                        []
# 4                                                        []
#                                 ...
# 209181    [(love, disney, awesome), (disney, awesome, app)]
# 209182    [(crash, switch, kid), (switch, kid, profile),...
# 209183    [(love, disney, happy), (disney, happy, beauti...
# 209184                                [(best, app, stream)]
# 209185    [(great, app, pretty), (app, pretty, polish), ...
# Length: 209186, dtype: object

# %%
disneyplus['trigrams'] = trigrams_for_review

# %%
disneyplus
# Out:
#         Unnamed: 0                              reviewId         userName  \
# 0                0  75affb77-43d6-4ada-9d8d-576d75a89295   William Graham
# 1                1  de8a389b-d296-484b-8049-555b31436e70       Nelson Lam
# 2                2  f0b0ef9c-5db3-44d5-9b70-2984685a55a2  Denuwan Saranga
# 3                3  f9b16c2c-6bf1-4de2-acf9-25db53feccf2  Gratien ABANJYE
# 4                4  9e483f7c-c572-4e46-a47a-f579a6d230ee     Jason Parker
# ...            ...                                   ...              ...
# 209181      209181  99bd5530-071c-46ae-8d65-f396a788805e    A Google user
# 209182      209182  866c928f-7d71-4b48-bb57-08dd93d3364e    A Google user
# 209183      209183  1c1eaa4c-c4c3-4742-8c77-e8af41458549    A Google user
# 209184      209184  c4d3a462-ac13-4fef-b21c-12e86223e1e5    A Google user
# 209185      209185  cde31be6-7adc-40d5-a5cd-89fed27a2942    A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a/AGNmyx...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a-/ACB-R...
# ...                                                   ...
# 209181  https://play-lh.googleusercontent.com/EGemoI2N...
# 209182  https://play-lh.googleusercontent.com/EGemoI2N...
# 209183  https://play-lh.googleusercontent.com/EGemoI2N...
# 209184  https://play-lh.googleusercontent.com/EGemoI2N...
# 209185  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0                                    absolutely awesome 👌      5
# 1       I wonder the software of Disney plus have an i...      1
# 2               Can you give 1 month premium free❤️Please      5
# 3                                                   Great      5
# 4                                            mandalorian!      5
# ...                                                   ...    ...
# 209181                        I love Disney! Awesome app!      5
# 209182  Crashes once when switching over to kids profi...      1
# 209183  I love Disney so I'm very happy with this (ver...      5
# 209184                        It's the best app streaming      5
# 209185  Great app, pretty polished for not even being ...      5
#
#         thumbsUpCount reviewCreatedVersion                   at  \
# 0                   0           2.18.1-rc1  2023-04-05 11:13:22
# 1                   0                  NaN  2023-04-05 11:10:55
# 2                   0                  NaN  2023-04-05 10:57:42
# 3                   0                  NaN  2023-04-05 10:40:22
# 4                   0           2.18.1-rc1  2023-04-05 10:22:27
# ...               ...                  ...                  ...
# 209181              6                1.0.0  2019-09-12 06:17:19
# 209182              5                1.0.0  2019-09-12 06:08:19
# 209183              3                1.0.0  2019-09-12 05:31:04
# 209184              1                1.0.0  2019-09-12 04:52:26
# 209185             17                1.0.0  2019-09-12 04:39:05
#
#                                              replyContent  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 209181                                                NaN
# 209182  Hello Rocco. Thanks for the feedback. Can you ...
# 209183                                                NaN
# 209184                                                NaN
# 209185                                                NaN
#
#                   repliedAt  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 209181                  NaN
# 209182  2019-09-21 17:32:41
# 209183                  NaN
# 209184                  NaN
# 209185                  NaN
#
#                                         processed_reviews  \
# 0                                      absolutely awesome
# 1       wonder software disney plus issue always come ...
# 2                                      give month premium
# 3                                                   great
# 4                                             mandalorian
# ...                                                   ...
# 209181                            love disney awesome app
# 209182  crash switch kid profile authorisation require...
# 209183          love disney happy beautiful streaming app
# 209184                                    best app stream
# 209185  great app pretty polish even officially releas...
#
#                                         tokenized_reviews  \
# 0                                   [absolutely, awesome]
# 1       [wonder, software, disney, plus, issue, always...
# 2                                  [give, month, premium]
# 3                                                 [great]
# 4                                           [mandalorian]
# ...                                                   ...
# 209181                       [love, disney, awesome, app]
# 209182  [crash, switch, kid, profile, authorisation, r...
# 209183   [love, disney, happy, beautiful, streaming, app]
# 209184                                [best, app, stream]
# 209185  [great, app, pretty, polish, even, officially,...
#
#                                                  trigrams
# 0                                                      []
# 1       [(wonder, software, disney), (software, disney...
# 2                                [(give, month, premium)]
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 209181  [(love, disney, awesome), (disney, awesome, app)]
# 209182  [(crash, switch, kid), (switch, kid, profile),...
# 209183  [(love, disney, happy), (disney, happy, beauti...
# 209184                              [(best, app, stream)]
# 209185  [(great, app, pretty), (app, pretty, polish), ...
#
# [209186 rows x 14 columns]

# %%
score_sum = np.zeros(10)   # change if you want a different number of top reviews

for j in range(len(top_trigrams)):
  for i in range(len(disneyplus.trigrams)):
    if top_trigrams[j] in disneyplus.trigrams[i]:
      score_sum[j] += disneyplus.score[i]

# %%
counter = []

for trigram in top_trigrams:
  counter.append(converted_dict_trigrams[trigram])

# %%
score_average = score_sum / np.array(counter)

# %%
score_average
# Out:
# array([4.52077807, 4.08748728, 4.9132321 , 1.36164384, 4.45295056,
#        1.38599349, 1.44230769, 4.44680851, 1.47169811, 1.70379147])

# %%
trigrams_scores = pd.DataFrame({'top_trigrams': top_trigrams, 'avg_rating': score_average, 'counter': counter})

# %%
trigrams_scores
# Out:
#              top_trigrams  avg_rating  counter
# 0    (love, disney, plus)    4.520778     1131
# 1       (movie, tv, show)    4.087487      983
# 2       (best, app, ever)    4.913232      922
# 3      (get, error, code)    1.361644      730
# 4     (marvel, star, war)    4.452951      627
# 5      (keep, get, error)    1.385993      614
# 6   (ca, watch, anything)    1.442308      572
# 7     (star, war, marvel)    4.446809      470
# 8  (something, go, wrong)    1.471698      424
# 9   (take, forever, load)    1.703791      422

# %%
trigrams_scores.avg_rating = round(trigrams_scores.avg_rating, 2)

# %%
trigrams_scores
# Out:
#              top_trigrams  avg_rating  counter
# 0    (love, disney, plus)        4.52     1131
# 1       (movie, tv, show)        4.09      983
# 2       (best, app, ever)        4.91      922
# 3      (get, error, code)        1.36      730
# 4     (marvel, star, war)        4.45      627
# 5      (keep, get, error)        1.39      614
# 6   (ca, watch, anything)        1.44      572
# 7     (star, war, marvel)        4.45      470
# 8  (something, go, wrong)        1.47      424
# 9   (take, forever, load)        1.70      422

# %%
g = sns.barplot(data=trigrams_scores, y = 'top_trigrams', x = 'avg_rating', color = 'blue', orient = 'h')
g.axes.set_xlim(1, 5)
for i in g.containers:
    g.bar_label(i,)

# %%
g = sns.barplot(data=trigrams_scores, y = 'top_trigrams', x = 'counter', color = 'blue', orient = 'h')
for i in g.containers:
    g.bar_label(i,)

# %%
trigrams_scores['top_trigrams'] = trigrams_scores['top_trigrams'].astype(str)

# %%
# Create the figure and axes objects, specify the size and the dots per inches 
fig, ax = plt.subplots(figsize=(13.33,7.5), dpi=100)

# Create a linear color map from red to green
cmap = mpl.colors.LinearSegmentedColormap.from_list('rating_map', ['#E3120B', '#00990C'], N=256)

# Normalize the ratings to the [0.0, 1.0] interval
norm = mpl.colors.Normalize(vmin=1, vmax=5)

# Compute the color for each bar based on its rating
colors = [cmap(norm(r)) for r in trigrams_scores['avg_rating']]

# Plot horizontal bars with the computed colors
bar1 = ax.barh(trigrams_scores['top_trigrams'], trigrams_scores['counter'], height=0.6, color=colors, alpha=1,zorder=3)

# Set the ticks and labels
ax.set_yticks(trigrams_scores['top_trigrams'])
ax.set_yticklabels(trigrams_scores['top_trigrams'], fontsize=10)
ax.set_xticks(range(0, 1000, 100))
ax.set_xticklabels(range(0, 1000, 100), fontsize=10)

# Invert the y-axis to show the bars in descending order
ax.invert_yaxis()

# Create the grid 
ax.grid(which='major', axis='x', color='#DAD8D7', alpha=0.7, zorder=1)
ax.grid(which='major', axis='y', color='#DAD8D7', alpha=0.7, zorder=1)

# Add labels to the bars
# Add labels to the bars
labels = [f'{e:.1f} \u2605' for e in trigrams_scores['avg_rating']]
ax.bar_label(bar1, labels=labels, padding=3, color='black', fontsize=9)


# Set x-axis formatting and tick parameters
ax.xaxis.set_label_position('bottom')
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
ax.xaxis.set_tick_params(pad=2, labelbottom=True, bottom=True, labelsize=12, labelrotation=0)
labels = ['0', '100', '200', '300', '400', '500', '600', '700', '800', '900', '1000', '1100']
ax.add_patch(plt.Rectangle((0.12,.98), 0.04, -0.02, facecolor='#1A3263', transform=fig.transFigure, clip_on=False, linewidth = 0))
ax.plot([0.12, .9], [.98, .98], transform=fig.transFigure, clip_on=False, color='#1A3263', linewidth=.6)

# Reformat y-axis
ax.yaxis.set_label_position('left')
ax.yaxis.set_tick_params(pad=2, labeltop=False, labelbottom=True, bottom=False, labelsize=12)
ax.spines[['top', 'left', 'bottom']].set_visible(False)
ax.spines['right'].set_linewidth(1.1)

# Add a color bar to the right of the plot
cbar = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax, shrink=0.8, aspect = 20, ticks=np.arange(1, 6, 1))
cbar.set_label('Average Rating', fontsize=12, labelpad=10)
cbar.ax.tick_params(labelsize=10)

# Add title and subtitle
ax.text(x=0.12, y=0.93, s='Top Trigrams Count for Disney+ on Google Play', transform=fig.transFigure, ha='left', fontsize=14, weight='bold', alpha=.8)
ax.text(x=0.12, y=0.90, s='The counter measures how many reviews contain the trigram, the colour of the bar explains the average rating of the reviews.', transform=fig.transFigure, ha='left', fontsize=11, alpha=.8)

ax.set_xlabel('Counter', fontsize=12, labelpad=10)

# Remove the right spine
ax.spines['right'].set_visible(False)


plt.subplots_adjust(left=None, bottom=0.2, right=None, top=0.85, wspace=None, hspace=None)

# %% [markdown]
# ## Creation of Word2Vec using genism

# %%
import gensim
from gensim.models import Word2Vec 
model = Word2Vec(tokenized_reviews, window=5, min_count=5)

# %%
model.wv.most_similar(positive=['service', 'positive'], negative = ['issue'], topn=10)
# Out:
# [('loyal', 0.5770540237426758),
#  ('extensive', 0.5708972811698914),
#  ('organization', 0.5703560709953308),
#  ('broad', 0.5583774447441101),
#  ('phenomenal', 0.5558179616928101),
#  ('diverse', 0.5543363094329834),
#  ('among', 0.5520614385604858),
#  ('exception', 0.5501309633255005),
#  ('mature', 0.5417293310165405),
#  ('immense', 0.5403943061828613)]
