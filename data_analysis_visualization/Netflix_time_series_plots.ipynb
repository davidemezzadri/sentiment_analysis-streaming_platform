# %% [markdown]
# ## Installing and importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Importing the reviews

# %%
netflix = pd.read_csv('Netflix_Google_Play.csv')

# %%
netflix
# Out:
#         Unnamed: 0                              reviewId  \
# 0                0  802afd00-5ce6-47a1-9517-7ab9a8ad293a
# 1                1  33e3b026-8e07-43d0-a423-691f9262d9e5
# 2                2  59cc5a19-4a28-4921-abd3-eb0e02eb6f7a
# 3                3  8ac7d5e3-8395-4dce-abf8-35c3f65f8116
# 4                4  8564f259-c895-4173-9537-b732475223dc
# ...            ...                                   ...
# 535106      535106  25c1adbc-d089-47ad-b465-29e469a555f7
# 535107      535107  156d031a-973f-4a66-bd9e-d74524e0ffbe
# 535108      535108  b3dde8ff-4618-4945-99d0-67b5b402aad5
# 535109      535109  d8141ea7-4fcf-4c47-8437-b090e7ff423e
# 535110      535110  e1395444-2041-47d5-aa07-a3fedef1b092
#
#                     userName  \
# 0                  Thug Life
# 1               muhammad ali
# 2       El-mustafeh Sebayiga
# 3                Irfan Abdul
# 4                Islamjannat
# ...                      ...
# 535106         A Google user
# 535107         A Google user
# 535108         A Google user
# 535109         A Google user
# 535110         A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 535106  https://play-lh.googleusercontent.com/EGemoI2N...
# 535107  https://play-lh.googleusercontent.com/EGemoI2N...
# 535108  https://play-lh.googleusercontent.com/EGemoI2N...
# 535109  https://play-lh.googleusercontent.com/EGemoI2N...
# 535110  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       The application isn't helpful at all, infact I...      1
# 1       Why does it start playing then give me an Erro...      1
# 2                                                    Good      5
# 3                                                  Stupid      1
# 4                                                 Helpful      5
# ...                                                   ...    ...
# 535106                                   Needs more anime      5
# 535107          Amazing app. But should have more movies.      5
# 535108                                          Excellent      5
# 535109      Great app. Love Netflix and my Greys Anatomy!      5
# 535110  When I start to watch a movie, I can't see any...      1
#
#         thumbsUpCount   reviewCreatedVersion                   at  \
# 0                   0                    NaN  2023-04-05 09:50:41
# 1                   0  8.63.0 build 16 50390  2023-04-05 09:45:45
# 2                   0  8.49.0 build 16 50315  2023-04-05 09:33:48
# 3                   0  8.63.0 build 16 50390  2023-04-05 09:31:07
# 4                   0                    NaN  2023-04-05 09:29:17
# ...               ...                    ...                  ...
# 535106              0  7.53.3 build 31 34824  2020-04-27 00:57:36
# 535107              0  7.51.1 build 26 34793  2020-04-27 00:55:23
# 535108              1  7.51.1 build 26 34793  2020-04-27 00:51:16
# 535109              0  7.40.0 build 20 34657  2020-04-27 00:49:20
# 535110              0  7.53.3 build 31 34824  2020-04-27 00:49:06
#
#         replyContent  repliedAt
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# ...              ...        ...
# 535106           NaN        NaN
# 535107           NaN        NaN
# 535108           NaN        NaN
# 535109           NaN        NaN
# 535110           NaN        NaN
#
# [535111 rows x 11 columns]

# %%
netflix.dtypes
# Out:
# Unnamed: 0                int64
# reviewId                 object
# userName                 object
# userImage                object
# content                  object
# score                     int64
# thumbsUpCount             int64
# reviewCreatedVersion     object
# at                       object
# replyContent            float64
# repliedAt               float64
# dtype: object

# %% [markdown]
# ## Labeling reviews basing on the score

# %%
netflix['label'] = 'neutral'

high_mask = netflix['score'] >= 4
netflix['label'].loc[high_mask] = 'positive'

low_mask = netflix['score'] <= 2
netflix['label'].loc[low_mask] = 'negative'
# Out:
# <ipython-input-86-8a0bdb30c288>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix['label'].loc[high_mask] = 'positive'
# <ipython-input-86-8a0bdb30c288>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix['label'].loc[low_mask] = 'negative'

# %%
netflix
# Out:
#         Unnamed: 0                              reviewId  \
# 0                0  802afd00-5ce6-47a1-9517-7ab9a8ad293a
# 1                1  33e3b026-8e07-43d0-a423-691f9262d9e5
# 2                2  59cc5a19-4a28-4921-abd3-eb0e02eb6f7a
# 3                3  8ac7d5e3-8395-4dce-abf8-35c3f65f8116
# 4                4  8564f259-c895-4173-9537-b732475223dc
# ...            ...                                   ...
# 535106      535106  25c1adbc-d089-47ad-b465-29e469a555f7
# 535107      535107  156d031a-973f-4a66-bd9e-d74524e0ffbe
# 535108      535108  b3dde8ff-4618-4945-99d0-67b5b402aad5
# 535109      535109  d8141ea7-4fcf-4c47-8437-b090e7ff423e
# 535110      535110  e1395444-2041-47d5-aa07-a3fedef1b092
#
#                     userName  \
# 0                  Thug Life
# 1               muhammad ali
# 2       El-mustafeh Sebayiga
# 3                Irfan Abdul
# 4                Islamjannat
# ...                      ...
# 535106         A Google user
# 535107         A Google user
# 535108         A Google user
# 535109         A Google user
# 535110         A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 535106  https://play-lh.googleusercontent.com/EGemoI2N...
# 535107  https://play-lh.googleusercontent.com/EGemoI2N...
# 535108  https://play-lh.googleusercontent.com/EGemoI2N...
# 535109  https://play-lh.googleusercontent.com/EGemoI2N...
# 535110  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       The application isn't helpful at all, infact I...      1
# 1       Why does it start playing then give me an Erro...      1
# 2                                                    Good      5
# 3                                                  Stupid      1
# 4                                                 Helpful      5
# ...                                                   ...    ...
# 535106                                   Needs more anime      5
# 535107          Amazing app. But should have more movies.      5
# 535108                                          Excellent      5
# 535109      Great app. Love Netflix and my Greys Anatomy!      5
# 535110  When I start to watch a movie, I can't see any...      1
#
#         thumbsUpCount   reviewCreatedVersion                   at  \
# 0                   0                    NaN  2023-04-05 09:50:41
# 1                   0  8.63.0 build 16 50390  2023-04-05 09:45:45
# 2                   0  8.49.0 build 16 50315  2023-04-05 09:33:48
# 3                   0  8.63.0 build 16 50390  2023-04-05 09:31:07
# 4                   0                    NaN  2023-04-05 09:29:17
# ...               ...                    ...                  ...
# 535106              0  7.53.3 build 31 34824  2020-04-27 00:57:36
# 535107              0  7.51.1 build 26 34793  2020-04-27 00:55:23
# 535108              1  7.51.1 build 26 34793  2020-04-27 00:51:16
# 535109              0  7.40.0 build 20 34657  2020-04-27 00:49:20
# 535110              0  7.53.3 build 31 34824  2020-04-27 00:49:06
#
#         replyContent  repliedAt     label
# 0                NaN        NaN  negative
# 1                NaN        NaN  negative
# 2                NaN        NaN  positive
# 3                NaN        NaN  negative
# 4                NaN        NaN  positive
# ...              ...        ...       ...
# 535106           NaN        NaN  positive
# 535107           NaN        NaN  positive
# 535108           NaN        NaN  positive
# 535109           NaN        NaN  positive
# 535110           NaN        NaN  negative
#
# [535111 rows x 12 columns]

# %% [markdown]
# ## Adding a column with the trimester of publication

# %%
netflix['at'] = pd.to_datetime(netflix['at'], format="%Y/%m/%d %H:%M:%S")

# %%
netflix.dtypes
# Out:
# Unnamed: 0                       int64
# reviewId                        object
# userName                        object
# userImage                       object
# content                         object
# score                            int64
# thumbsUpCount                    int64
# reviewCreatedVersion            object
# at                      datetime64[ns]
# replyContent                   float64
# repliedAt                      float64
# label                           object
# dtype: object

# %%
netflix['year'] =  netflix['at'].apply(lambda x: x.year)
netflix['month'] =  netflix['at'].apply(lambda x: x.month)

# %%
netflix['quarter'] = (netflix['month'] / 3).apply(math.ceil)

# %%
netflix['year'] = netflix['year'].astype(str)
netflix['month'] = netflix['month'].astype(str)
netflix['quarter'] = netflix['quarter'].astype(str)
netflix['quarter'] = netflix['year'].apply(lambda x: x[-2:]) + ' ' + netflix['quarter'] + 'Q'

# %%
netflix
# Out:
#         Unnamed: 0                              reviewId  \
# 0                0  802afd00-5ce6-47a1-9517-7ab9a8ad293a
# 1                1  33e3b026-8e07-43d0-a423-691f9262d9e5
# 2                2  59cc5a19-4a28-4921-abd3-eb0e02eb6f7a
# 3                3  8ac7d5e3-8395-4dce-abf8-35c3f65f8116
# 4                4  8564f259-c895-4173-9537-b732475223dc
# ...            ...                                   ...
# 535106      535106  25c1adbc-d089-47ad-b465-29e469a555f7
# 535107      535107  156d031a-973f-4a66-bd9e-d74524e0ffbe
# 535108      535108  b3dde8ff-4618-4945-99d0-67b5b402aad5
# 535109      535109  d8141ea7-4fcf-4c47-8437-b090e7ff423e
# 535110      535110  e1395444-2041-47d5-aa07-a3fedef1b092
#
#                     userName  \
# 0                  Thug Life
# 1               muhammad ali
# 2       El-mustafeh Sebayiga
# 3                Irfan Abdul
# 4                Islamjannat
# ...                      ...
# 535106         A Google user
# 535107         A Google user
# 535108         A Google user
# 535109         A Google user
# 535110         A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 535106  https://play-lh.googleusercontent.com/EGemoI2N...
# 535107  https://play-lh.googleusercontent.com/EGemoI2N...
# 535108  https://play-lh.googleusercontent.com/EGemoI2N...
# 535109  https://play-lh.googleusercontent.com/EGemoI2N...
# 535110  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       The application isn't helpful at all, infact I...      1
# 1       Why does it start playing then give me an Erro...      1
# 2                                                    Good      5
# 3                                                  Stupid      1
# 4                                                 Helpful      5
# ...                                                   ...    ...
# 535106                                   Needs more anime      5
# 535107          Amazing app. But should have more movies.      5
# 535108                                          Excellent      5
# 535109      Great app. Love Netflix and my Greys Anatomy!      5
# 535110  When I start to watch a movie, I can't see any...      1
#
#         thumbsUpCount   reviewCreatedVersion                  at  \
# 0                   0                    NaN 2023-04-05 09:50:41
# 1                   0  8.63.0 build 16 50390 2023-04-05 09:45:45
# 2                   0  8.49.0 build 16 50315 2023-04-05 09:33:48
# 3                   0  8.63.0 build 16 50390 2023-04-05 09:31:07
# 4                   0                    NaN 2023-04-05 09:29:17
# ...               ...                    ...                 ...
# 535106              0  7.53.3 build 31 34824 2020-04-27 00:57:36
# 535107              0  7.51.1 build 26 34793 2020-04-27 00:55:23
# 535108              1  7.51.1 build 26 34793 2020-04-27 00:51:16
# 535109              0  7.40.0 build 20 34657 2020-04-27 00:49:20
# 535110              0  7.53.3 build 31 34824 2020-04-27 00:49:06
#
#         replyContent  repliedAt     label  year month quarter
# 0                NaN        NaN  negative  2023     4   23 2Q
# 1                NaN        NaN  negative  2023     4   23 2Q
# 2                NaN        NaN  positive  2023     4   23 2Q
# 3                NaN        NaN  negative  2023     4   23 2Q
# 4                NaN        NaN  positive  2023     4   23 2Q
# ...              ...        ...       ...   ...   ...     ...
# 535106           NaN        NaN  positive  2020     4   20 2Q
# 535107           NaN        NaN  positive  2020     4   20 2Q
# 535108           NaN        NaN  positive  2020     4   20 2Q
# 535109           NaN        NaN  positive  2020     4   20 2Q
# 535110           NaN        NaN  negative  2020     4   20 2Q
#
# [535111 rows x 15 columns]

# %% [markdown]
# ## Plotting the counter of positive/neutral/negative comments over time

# %%
aggregated_reviews = netflix.groupby(['label', 'quarter']).count()

# %%
aggregated_reviews
# Out:
#                   Unnamed: 0  reviewId  userName  userImage  content  score  \
# label    quarter
# negative 20 2Q         11897     11897     11897      11897    11896  11897
#          20 3Q         16333     16333     16333      16333    16333  16333
#          20 4Q         15900     15900     15900      15900    15900  15900
#          21 1Q         10251     10251     10251      10251    10250  10251
#          21 2Q         11379     11379     11379      11379    11379  11379
#          21 3Q          9803      9803      9803       9803     9803   9803
#          21 4Q          9257      9257      9257       9257     9257   9257
#          22 1Q         12001     12001     12001      12001    12001  12001
#          22 2Q          9824      9824      9824       9824     9824   9824
#          22 3Q         10460     10460     10459      10460    10460  10460
#          22 4Q          9048      9048      9048       9048     9048   9048
#          23 1Q          8232      8232      8232       8232     8232   8232
#          23 2Q           339       339       339        339      339    339
# neutral  20 2Q          3315      3315      3315       3315     3314   3315
#          20 3Q          4183      4183      4183       4183     4183   4183
#          20 4Q          3743      3743      3743       3743     3743   3743
#          21 1Q          2985      2985      2985       2985     2985   2985
#          21 2Q          2534      2534      2534       2534     2534   2534
#          21 3Q          2119      2119      2119       2119     2119   2119
#          21 4Q          1992      1992      1992       1992     1992   1992
#          22 1Q          2279      2279      2279       2279     2279   2279
#          22 2Q          2164      2164      2164       2164     2164   2164
#          22 3Q          2445      2445      2445       2445     2445   2445
#          22 4Q          1631      1631      1631       1631     1631   1631
#          23 1Q          1313      1313      1313       1313     1313   1313
#          23 2Q            57        57        57         57       57     57
# positive 20 2Q         44225     44225     44225      44225    44219  44225
#          20 3Q         53573     53573     53573      53573    53569  53573
#          20 4Q         50058     50058     50058      50058    50055  50058
#          21 1Q         39934     39934     39934      39934    39931  39934
#          21 2Q         26954     26954     26954      26954    26952  26954
#          21 3Q         22548     22548     22548      22548    22547  22548
#          21 4Q         23417     23417     23417      23417    23416  23417
#          22 1Q         27424     27424     27424      27424    27420  27424
#          22 2Q         24736     24736     24736      24736    24735  24736
#          22 3Q         28029     28029     28029      28029    28028  28029
#          22 4Q         15194     15194     15194      15194    15190  15194
#          23 1Q         12956     12956     12956      12956    12954  12956
#          23 2Q           579       579       579        579      579    579
#
#                   thumbsUpCount  reviewCreatedVersion     at  replyContent  \
# label    quarter
# negative 20 2Q            11897                  8397  11897             0
#          20 3Q            16333                 12168  16333             0
#          20 4Q            15900                 11217  15900             0
#          21 1Q            10251                  7618  10251             0
#          21 2Q            11379                  8405  11379             0
#          21 3Q             9803                  7231   9803             0
#          21 4Q             9257                  6707   9257             0
#          22 1Q            12001                  8680  12001             0
#          22 2Q             9824                  7130   9824             0
#          22 3Q            10460                  7786  10460             0
#          22 4Q             9048                  7090   9048             0
#          23 1Q             8232                  6406   8232             0
#          23 2Q              339                   262    339             0
# neutral  20 2Q             3315                  2663   3315             0
#          20 3Q             4183                  3330   4183             0
#          20 4Q             3743                  2919   3743             0
#          21 1Q             2985                  2419   2985             0
#          21 2Q             2534                  1983   2534             0
#          21 3Q             2119                  1582   2119             0
#          21 4Q             1992                  1448   1992             0
#          22 1Q             2279                  1783   2279             0
#          22 2Q             2164                  1676   2164             0
#          22 3Q             2445                  1996   2445             0
#          22 4Q             1631                  1261   1631             0
#          23 1Q             1313                  1021   1313             0
#          23 2Q               57                    42     57             0
# positive 20 2Q            44225                 33857  44225             0
#          20 3Q            53573                 40916  53573             0
#          20 4Q            50058                 36813  50058             0
#          21 1Q            39934                 30656  39934             0
#          21 2Q            26954                 19136  26954             0
#          21 3Q            22548                 15240  22548             0
#          21 4Q            23417                 15842  23417             0
#          22 1Q            27424                 20475  27424             0
#          22 2Q            24736                 18959  24736             0
#          22 3Q            28029                 22153  28029             0
#          22 4Q            15194                 11164  15194             0
#          23 1Q            12956                  9434  12956             0
#          23 2Q              579                   416    579             0
#
#                   repliedAt   year  month
# label    quarter
# negative 20 2Q            0  11897  11897
#          20 3Q            0  16333  16333
#          20 4Q            0  15900  15900
#          21 1Q            0  10251  10251
#          21 2Q            0  11379  11379
#          21 3Q            0   9803   9803
#          21 4Q            0   9257   9257
#          22 1Q            0  12001  12001
#          22 2Q            0   9824   9824
#          22 3Q            0  10460  10460
#          22 4Q            0   9048   9048
#          23 1Q            0   8232   8232
#          23 2Q            0    339    339
# neutral  20 2Q            0   3315   3315
#          20 3Q            0   4183   4183
#          20 4Q            0   3743   3743
#          21 1Q            0   2985   2985
#          21 2Q            0   2534   2534
#          21 3Q            0   2119   2119
#          21 4Q            0   1992   1992
#          22 1Q            0   2279   2279
#          22 2Q            0   2164   2164
#          22 3Q            0   2445   2445
#          22 4Q            0   1631   1631
#          23 1Q            0   1313   1313
#          23 2Q            0     57     57
# positive 20 2Q            0  44225  44225
#          20 3Q            0  53573  53573
#          20 4Q            0  50058  50058
#          21 1Q            0  39934  39934
#          21 2Q            0  26954  26954
#          21 3Q            0  22548  22548
#          21 4Q            0  23417  23417
#          22 1Q            0  27424  27424
#          22 2Q            0  24736  24736
#          22 3Q            0  28029  28029
#          22 4Q            0  15194  15194
#          23 1Q            0  12956  12956
#          23 2Q            0    579    579

# %%
positive = aggregated_reviews.loc['positive'].reset_index()

# %%
neutral = aggregated_reviews.loc['neutral'].reset_index()

# %%
negative = aggregated_reviews.loc['negative'].reset_index()

# %%
negative
# Out:
#    quarter  Unnamed: 0  reviewId  userName  userImage  content  score  \
# 0    20 2Q       11897     11897     11897      11897    11896  11897
# 1    20 3Q       16333     16333     16333      16333    16333  16333
# 2    20 4Q       15900     15900     15900      15900    15900  15900
# 3    21 1Q       10251     10251     10251      10251    10250  10251
# 4    21 2Q       11379     11379     11379      11379    11379  11379
# 5    21 3Q        9803      9803      9803       9803     9803   9803
# 6    21 4Q        9257      9257      9257       9257     9257   9257
# 7    22 1Q       12001     12001     12001      12001    12001  12001
# 8    22 2Q        9824      9824      9824       9824     9824   9824
# 9    22 3Q       10460     10460     10459      10460    10460  10460
# 10   22 4Q        9048      9048      9048       9048     9048   9048
# 11   23 1Q        8232      8232      8232       8232     8232   8232
# 12   23 2Q         339       339       339        339      339    339
#
#     thumbsUpCount  reviewCreatedVersion     at  replyContent  repliedAt  \
# 0           11897                  8397  11897             0          0
# 1           16333                 12168  16333             0          0
# 2           15900                 11217  15900             0          0
# 3           10251                  7618  10251             0          0
# 4           11379                  8405  11379             0          0
# 5            9803                  7231   9803             0          0
# 6            9257                  6707   9257             0          0
# 7           12001                  8680  12001             0          0
# 8            9824                  7130   9824             0          0
# 9           10460                  7786  10460             0          0
# 10           9048                  7090   9048             0          0
# 11           8232                  6406   8232             0          0
# 12            339                   262    339             0          0
#
#      year  month
# 0   11897  11897
# 1   16333  16333
# 2   15900  15900
# 3   10251  10251
# 4   11379  11379
# 5    9803   9803
# 6    9257   9257
# 7   12001  12001
# 8    9824   9824
# 9   10460  10460
# 10   9048   9048
# 11   8232   8232
# 12    339    339

# %%
positive = positive[(positive.quarter != '20 2Q') & (positive.quarter != '23 2Q')]

# %%
neutral = neutral[(neutral.quarter != '20 2Q') & (neutral.quarter != '23 2Q')]

# %%
negative = negative[(negative.quarter != '20 2Q') & (negative.quarter != '23 2Q')]

# %%
negative
# Out:
#    quarter  Unnamed: 0  reviewId  userName  userImage  content  score  \
# 1    20 3Q       16333     16333     16333      16333    16333  16333
# 2    20 4Q       15900     15900     15900      15900    15900  15900
# 3    21 1Q       10251     10251     10251      10251    10250  10251
# 4    21 2Q       11379     11379     11379      11379    11379  11379
# 5    21 3Q        9803      9803      9803       9803     9803   9803
# 6    21 4Q        9257      9257      9257       9257     9257   9257
# 7    22 1Q       12001     12001     12001      12001    12001  12001
# 8    22 2Q        9824      9824      9824       9824     9824   9824
# 9    22 3Q       10460     10460     10459      10460    10460  10460
# 10   22 4Q        9048      9048      9048       9048     9048   9048
# 11   23 1Q        8232      8232      8232       8232     8232   8232
#
#     thumbsUpCount  reviewCreatedVersion     at  replyContent  repliedAt  \
# 1           16333                 12168  16333             0          0
# 2           15900                 11217  15900             0          0
# 3           10251                  7618  10251             0          0
# 4           11379                  8405  11379             0          0
# 5            9803                  7231   9803             0          0
# 6            9257                  6707   9257             0          0
# 7           12001                  8680  12001             0          0
# 8            9824                  7130   9824             0          0
# 9           10460                  7786  10460             0          0
# 10           9048                  7090   9048             0          0
# 11           8232                  6406   8232             0          0
#
#      year  month
# 1   16333  16333
# 2   15900  15900
# 3   10251  10251
# 4   11379  11379
# 5    9803   9803
# 6    9257   9257
# 7   12001  12001
# 8    9824   9824
# 9   10460  10460
# 10   9048   9048
# 11   8232   8232

# %%
# Create the figure and axes objects, specify the size and the dots per inches 
fig, ax = plt.subplots(figsize=(13.33,7.5), dpi=100)

# create the line graph
plt.plot(positive.quarter, positive.reviewId, label='Line Positive', color='darkgreen')
plt.plot(positive.quarter, neutral.reviewId, label='Line Neutral', color='lightseagreen')
plt.plot(positive.quarter, negative.reviewId, label='Line Negative', color='lime')
# Create the grid 
ax.grid(which='major', axis='x', color='#DAD8D7', alpha=0.7, zorder=1)
ax.grid(which='major', axis='y', color='#DAD8D7', alpha=0.7, zorder=1)
# set the title, legend, and axis labels
plt.xlabel('Time')
plt.ylabel('Number of reviews')
plt.legend()
ax.text(x=0.12, y=0.93, s='Sentiment over time', transform=fig.transFigure, ha='left', fontsize=14, weight='bold', alpha=.8)
ax.text(x=0.12, y=0.90, s='The counter measures how many reviews are positive, neutral or negative according to our sentiment analysis.', transform=fig.transFigure, ha='left', fontsize=11, alpha=.8)
ax.add_patch(plt.Rectangle((0.12,.98), 0.04, -0.02, facecolor='#E50914', transform=fig.transFigure, clip_on=False, linewidth = 0))
ax.plot([0.12, .9], [.98, .98], transform=fig.transFigure, clip_on=False, color='#E50914', linewidth=.6)

# display the graph
plt.show()

# %% [markdown]
# ## Plotting the average score over time

# %%
aggregated_reviews2 = netflix.groupby(['quarter']).score.mean()

# %%
aggregated_reviews2 = aggregated_reviews2[(aggregated_reviews2.index != '20 2Q') & (aggregated_reviews2.index != '23 2Q')]

# %%
aggregated_reviews2
# Out:
# quarter
# 20 3Q    3.935793
# 20 4Q    3.912168
# 21 1Q    4.046586
# 21 2Q    3.711797
# 21 3Q    3.690136
# 21 4Q    3.769399
# 22 1Q    3.688279
# 22 2Q    3.757652
# 22 3Q    3.801217
# 22 4Q    3.435744
# 23 1Q    3.386738
# Name: score, dtype: float64

# %%
# Create the figure and axes objects, specify the size and the dots per inches 
fig, ax = plt.subplots(figsize=(13.33,7.5), dpi=100)

# create the line graph
plt.plot(aggregated_reviews2.index, aggregated_reviews2.values, color='#E50914')
# Create the grid 
ax.grid(which='major', axis='x', color='#DAD8D7', alpha=0.7, zorder=1)
ax.grid(which='major', axis='y', color='#DAD8D7', alpha=0.7, zorder=1)
ax.set_ylim(1, 5)
# set the title, legend, and axis labels
plt.xlabel('Time')
plt.ylabel('Average score of the reviews')
plt.legend()
ax.text(x=0.12, y=0.93, s='Average score over time', transform=fig.transFigure, ha='left', fontsize=14, weight='bold', alpha=.8)
ax.text(x=0.12, y=0.90, s='The plot shows how the average score of the reviews varies overtime according to our sentiment analysis.', transform=fig.transFigure, ha='left', fontsize=11, alpha=.8)
ax.add_patch(plt.Rectangle((0.12,.98), 0.04, -0.02, facecolor='#E50914', transform=fig.transFigure, clip_on=False, linewidth = 0))
ax.plot([0.12, .9], [.98, .98], transform=fig.transFigure, clip_on=False, color='#E50914', linewidth=.6)

# display the graph
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Plotting average score vs number of subscribers over time

# %%
subscribers = pd.read_csv('Subscribers.csv')
subscribers = subscribers[['quarter','Netflix']]
subscribers
# Out:
#    quarter  Netflix
# 0    19 4Q    167.0
# 1    20 1Q    182.0
# 2    20 2Q    193.0
# 3    20 3Q    195.0
# 4    20 4Q    204.0
# 5    21 1Q    208.0
# 6    21 2Q    209.0
# 7    21 3Q    214.0
# 8    21 4Q    222.0
# 9    22 1Q    221.0
# 10   22 2Q    220.0
# 11   22 3Q    223.0
# 12   22 4Q    230.0
# 13   23 1Q      NaN

# %%
final_df = pd.merge(aggregated_reviews2, subscribers, on='quarter')
final_df
# Out:
#    quarter     score  Netflix
# 0    20 3Q  3.935793    195.0
# 1    20 4Q  3.912168    204.0
# 2    21 1Q  4.046586    208.0
# 3    21 2Q  3.711797    209.0
# 4    21 3Q  3.690136    214.0
# 5    21 4Q  3.769399    222.0
# 6    22 1Q  3.688279    221.0
# 7    22 2Q  3.757652    220.0
# 8    22 3Q  3.801217    223.0
# 9    22 4Q  3.435744    230.0
# 10   23 1Q  3.386738      NaN

# %%
final_df.rename({'Netflix': 'subscribers'}, axis = 1, inplace = True)
final_df.drop(10, inplace = True)
final_df
# Out:
#   quarter     score  subscribers
# 0   20 3Q  3.935793        195.0
# 1   20 4Q  3.912168        204.0
# 2   21 1Q  4.046586        208.0
# 3   21 2Q  3.711797        209.0
# 4   21 3Q  3.690136        214.0
# 5   21 4Q  3.769399        222.0
# 6   22 1Q  3.688279        221.0
# 7   22 2Q  3.757652        220.0
# 8   22 3Q  3.801217        223.0
# 9   22 4Q  3.435744        230.0

# %%
# Create a figure and axis object
fig, ax1 = plt.subplots(figsize=(13.33,7.5), dpi=100)

# Set the x-axis values to the quarters
x = final_df['quarter']

# Plot the score on the first y-axis
ax1.plot(x, final_df['score'], color='#E50914', label='Average score')
ax1.set_ylabel('Average score of the reviews')

# Create a second y-axis object
ax2 = ax1.twinx()

# Plot the Netflix subscribers on the second y-axis
ax2.plot(x, final_df['subscribers'], color='green', label='Number of subscribers')
ax2.set_ylabel('Netflix subscribers (millions)')

# Set the x-axis label
ax1.set_xlabel('Quarter')

# Create a legend
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines = lines_1 + lines_2
labels = labels_1 + labels_2
plt.legend(lines, labels, loc='best')

fig.text(x=0.12, y=0.93, s='Average score over time vs Number of subscribers', transform=fig.transFigure, ha='left', fontsize=14, weight='bold', alpha=.8)
fig.text(x=0.12, y=0.90, s='The plot shows how the average score of the reviews and the number of subscribers vary over time.', transform=fig.transFigure, ha='left', fontsize=11, alpha=.8)
fig.patches.append(plt.Rectangle((0.12,.98), 0.04, -0.02, facecolor='#E50914', transform=fig.transFigure, clip_on=False, linewidth = 0))
ax1.plot([0.12, .9], [.98, .98], transform=fig.transFigure, clip_on=False, color='#E50914', linewidth=.6)

# Display the chart
plt.show()
